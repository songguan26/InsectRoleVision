# %%
# !nvidia-smi
# Out:
# Thu May  8 14:10:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Install YOLOv5

# %%
# clone YOLOv5 repository
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17430, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 17430 (delta 73), reused 28 (delta 26), pack-reused 17327 (from 4)
# Receiving objects: 100% (17430/17430), 16.32 MiB | 29.52 MiB/s, done.
# Resolving deltas: 100% (11941/11941), done.

# %%
# install dependencies as necessary
# !pip install -r requirements.txt
# !pip uninstall wandb -qy  # deprecated dependency
import torch

from IPython.display import Image, clear_output  # to display images

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Setup complete. Using torch 2.6.0+cu124 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', major=8, minor=0, total_memory=40506MB, multi_processor_count=108, uuid=dbf41769-e0bb-8029-009c-471f5707eb87, L2_cache_size=40MB)

# %%
# %cd /content/yolov5
# !pip install -q roboflow==1.1.48

from roboflow import Roboflow
rf = Roboflow(api_key="q5dx0cWktqaKU3A8SD6P")
project = rf.workspace("computervisionlab").project("scanbugs1v2")
dataset = project.version(8).download("yolov5")
# Out:
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 50.3 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov5pytorch in progress : 85.0%
# Version export complete for yolov5pytorch format
# Downloading Dataset Version Zip in ScanBugS1v2-8 to yolov5pytorch:: 100%|██████████| 401335/401335 [00:04<00:00, 89053.17it/s]
# Extracting Dataset Version Zip to ScanBugS1v2-8 in yolov5pytorch:: 100%|██████████| 6458/6458 [00:01<00:00, 4506.88it/s]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **cache:** cache images for faster training

# %%
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py \
  --img 3200 \
  --batch 2 \
  --epochs 50 \
  --data {dataset.location}/data.yaml \
  --weights yolov5s.pt \
  --name yolov5s_results  \
  --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       48/49      11.8G    0.05428     0.6793          0        120       3200:  36% 549/1519 [02:52<04:43,  3.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6797          0        330       3200:  36% 550/1519 [02:53<05:38,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6796          0        167       3200:  36% 551/1519 [02:53<04:44,  3.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05427     0.6795          0        270       3200:  36% 552/1519 [02:53<05:36,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05427     0.6804          0        410       3200:  36% 553/1519 [02:54<04:42,  3.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05428       0.68          0        133       3200:  36% 554/1519 [02:54<05:31,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05428     0.6799          0        173       3200:  37% 555/1519 [02:54<04:39,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05428       0.68          0        318       3200:  37% 556/1519 [02:55<05:35,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6794          0        119       3200:  37% 557/1519 [02:55<04:42,  3.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6797          0        264       3200:  37% 558/1519 [02:55<05:31,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6794          0        142       3200:  37% 559/1519 [02:56<04:38,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05433     0.6792          0        135       3200:  37% 560/1519 [02:56<05:31,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05433     0.6789          0        153       3200:  37% 561/1519 [02:56<04:39,  3.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05434     0.6786          0        128       3200:  37% 562/1519 [02:57<05:35,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05434     0.6781          0        120       3200:  37% 563/1519 [02:57<04:41,  3.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05433     0.6776          0        155       3200:  37% 564/1519 [02:57<05:27,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6768          0         62       3200:  37% 565/1519 [02:57<04:35,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6776          0        385       3200:  37% 566/1519 [02:58<05:27,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6785          0        374       3200:  37% 567/1519 [02:58<04:35,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6785          0        277       3200:  37% 568/1519 [02:59<05:33,  2.85it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0543     0.6785          0        330       3200:  37% 569/1519 [02:59<04:40,  3.38it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6777          0         57       3200:  38% 570/1519 [02:59<05:25,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6772          0         95       3200:  38% 571/1519 [02:59<04:34,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6767          0        119       3200:  38% 572/1519 [03:00<05:23,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05429     0.6762          0        102       3200:  38% 573/1519 [03:00<04:33,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05431     0.6764          0        202       3200:  38% 574/1519 [03:00<05:25,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05431     0.6758          0         87       3200:  38% 575/1519 [03:01<04:33,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05431     0.6756          0        240       3200:  38% 576/1519 [03:01<05:23,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6757          0        207       3200:  38% 577/1519 [03:01<04:32,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6754          0        210       3200:  38% 578/1519 [03:02<05:27,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6749          0        138       3200:  38% 579/1519 [03:02<04:35,  3.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05432     0.6747          0        184       3200:  38% 580/1519 [03:02<05:23,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05433     0.6744          0        139       3200:  38% 581/1519 [03:03<04:32,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05433     0.6747          0        384       3200:  38% 582/1519 [03:03<05:24,  2.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05434     0.6745          0        109       3200:  38% 583/1519 [03:03<04:36,  3.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05434     0.6742          0        149       3200:  38% 584/1519 [03:04<05:17,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05434      0.674          0        186       3200:  39% 585/1519 [03:04<04:28,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05435     0.6746          0        250       3200:  39% 586/1519 [03:04<05:15,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05434     0.6742          0        180       3200:  39% 587/1519 [03:04<04:26,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05436     0.6754          0        417       3200:  39% 588/1519 [03:05<05:15,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05436     0.6759          0        374       3200:  39% 589/1519 [03:05<04:29,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05437     0.6751          0         56       3200:  39% 590/1519 [03:06<05:16,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05437      0.675          0        285       3200:  39% 591/1519 [03:06<04:26,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05436     0.6749          0        174       3200:  39% 592/1519 [03:06<05:10,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05437     0.6751          0        313       3200:  39% 593/1519 [03:06<04:22,  3.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6753          0        220       3200:  39% 594/1519 [03:07<05:14,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6748          0         93       3200:  39% 595/1519 [03:07<04:25,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6746          0        143       3200:  39% 596/1519 [03:07<05:05,  3.02it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439      0.676          0        584       3200:  39% 597/1519 [03:08<04:19,  3.56it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6768          0        455       3200:  39% 598/1519 [03:08<05:14,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6765          0        160       3200:  39% 599/1519 [03:08<04:25,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6769          0        281       3200:  39% 600/1519 [03:09<05:11,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6769          0        216       3200:  40% 601/1519 [03:09<04:23,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6767          0        183       3200:  40% 602/1519 [03:09<05:10,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438      0.677          0        388       3200:  40% 603/1519 [03:09<04:22,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6771          0        272       3200:  40% 604/1519 [03:10<05:11,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6765          0         99       3200:  40% 605/1519 [03:10<04:24,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6764          0        199       3200:  40% 606/1519 [03:11<05:15,  2.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6764          0        232       3200:  40% 607/1519 [03:11<04:25,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6763          0        204       3200:  40% 608/1519 [03:11<05:06,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6764          0        270       3200:  40% 609/1519 [03:11<04:18,  3.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6777          0        505       3200:  40% 610/1519 [03:12<05:09,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6776          0        174       3200:  40% 611/1519 [03:12<04:21,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6775          0        184       3200:  40% 612/1519 [03:12<05:05,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6778          0        268       3200:  40% 613/1519 [03:13<04:18,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438      0.678          0        329       3200:  40% 614/1519 [03:13<05:08,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05437     0.6779          0        269       3200:  40% 615/1519 [03:13<04:19,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438      0.678          0        221       3200:  41% 616/1519 [03:14<05:07,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05437     0.6782          0        364       3200:  41% 617/1519 [03:14<04:19,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438     0.6779          0        188       3200:  41% 618/1519 [03:14<05:04,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05438      0.678          0        232       3200:  41% 619/1519 [03:14<04:17,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6782          0        187       3200:  41% 620/1519 [03:15<05:01,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6777          0         87       3200:  41% 621/1519 [03:15<04:15,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05439     0.6773          0        125       3200:  41% 622/1519 [03:15<04:59,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6768          0        110       3200:  41% 623/1519 [03:16<04:13,  3.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6764          0        167       3200:  41% 624/1519 [03:16<05:03,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6764          0        282       3200:  41% 625/1519 [03:16<04:16,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6769          0        280       3200:  41% 626/1519 [03:17<05:07,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6763          0        121       3200:  41% 627/1519 [03:17<04:18,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441      0.676          0        169       3200:  41% 628/1519 [03:17<04:58,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6761          0        243       3200:  41% 629/1519 [03:18<04:12,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443      0.676          0        133       3200:  41% 630/1519 [03:18<04:57,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6758          0        181       3200:  42% 631/1519 [03:18<04:11,  3.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6757          0        311       3200:  42% 632/1519 [03:19<04:59,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6752          0        105       3200:  42% 633/1519 [03:19<04:13,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6753          0        191       3200:  42% 634/1519 [03:19<04:59,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6748          0        109       3200:  42% 635/1519 [03:19<04:12,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6748          0        164       3200:  42% 636/1519 [03:20<05:05,  2.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6747          0        208       3200:  42% 637/1519 [03:20<04:17,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6742          0        124       3200:  42% 638/1519 [03:21<05:00,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6742          0        167       3200:  42% 639/1519 [03:21<04:14,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442      0.674          0        181       3200:  42% 640/1519 [03:21<04:58,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6741          0        247       3200:  42% 641/1519 [03:21<04:11,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6741          0        200       3200:  42% 642/1519 [03:22<05:00,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6737          0        130       3200:  42% 643/1519 [03:22<04:13,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6742          0        417       3200:  42% 644/1519 [03:22<05:04,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442      0.674          0        151       3200:  42% 645/1519 [03:23<04:15,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6735          0         65       3200:  43% 646/1519 [03:23<05:00,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6733          0        145       3200:  43% 647/1519 [03:23<04:12,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6732          0        236       3200:  43% 648/1519 [03:24<04:55,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6728          0        102       3200:  43% 649/1519 [03:24<04:09,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443      0.674          0        519       3200:  43% 650/1519 [03:24<04:53,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6745          0        339       3200:  43% 651/1519 [03:24<04:07,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6744          0        184       3200:  43% 652/1519 [03:25<04:50,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6746          0        320       3200:  43% 653/1519 [03:25<04:08,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6743          0        142       3200:  43% 654/1519 [03:26<04:50,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6735          0         34       3200:  43% 655/1519 [03:26<04:05,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6728          0         68       3200:  43% 656/1519 [03:26<04:49,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6727          0        173       3200:  43% 657/1519 [03:26<04:04,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6741          0        644       3200:  43% 658/1519 [03:27<04:54,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6734          0         53       3200:  43% 659/1519 [03:27<04:08,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6734          0        262       3200:  43% 660/1519 [03:27<04:49,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6743          0        668       3200:  44% 661/1519 [03:28<04:04,  3.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443      0.675          0        414       3200:  44% 662/1519 [03:28<04:45,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443      0.675          0        262       3200:  44% 663/1519 [03:28<04:02,  3.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444      0.675          0        163       3200:  44% 664/1519 [03:29<04:44,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6753          0        525       3200:  44% 665/1519 [03:29<04:01,  3.54it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444      0.675          0        127       3200:  44% 666/1519 [03:29<04:44,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05445     0.6751          0        232       3200:  44% 667/1519 [03:29<04:01,  3.54it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6751          0        327       3200:  44% 668/1519 [03:30<04:46,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6749          0        199       3200:  44% 669/1519 [03:30<04:02,  3.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6747          0        168       3200:  44% 670/1519 [03:31<04:48,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6749          0        232       3200:  44% 671/1519 [03:31<04:03,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6748          0        156       3200:  44% 672/1519 [03:31<04:42,  2.99it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G     0.0544     0.6746          0        175       3200:  44% 673/1519 [03:31<03:59,  3.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6743          0        192       3200:  44% 674/1519 [03:32<04:43,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6743          0        159       3200:  44% 675/1519 [03:32<04:01,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6738          0         95       3200:  45% 676/1519 [03:32<04:49,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6737          0        177       3200:  45% 677/1519 [03:33<04:03,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6733          0        149       3200:  45% 678/1519 [03:33<04:44,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6736          0        344       3200:  45% 679/1519 [03:33<04:00,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6736          0        343       3200:  45% 680/1519 [03:34<04:47,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6736          0        282       3200:  45% 681/1519 [03:34<04:02,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6744          0        447       3200:  45% 682/1519 [03:34<04:46,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6743          0        249       3200:  45% 683/1519 [03:34<04:01,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6748          0        367       3200:  45% 684/1519 [03:35<04:49,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444      0.675          0        367       3200:  45% 685/1519 [03:35<04:03,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6749          0        161       3200:  45% 686/1519 [03:36<04:43,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6748          0        290       3200:  45% 687/1519 [03:36<03:59,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6743          0         63       3200:  45% 688/1519 [03:36<04:42,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6742          0        356       3200:  45% 689/1519 [03:36<03:58,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05445     0.6745          0        178       3200:  45% 690/1519 [03:37<04:46,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6744          0        260       3200:  45% 691/1519 [03:37<04:00,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6742          0        137       3200:  46% 692/1519 [03:37<04:37,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6746          0        463       3200:  46% 693/1519 [03:38<03:54,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6738          0         43       3200:  46% 694/1519 [03:38<04:37,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6739          0        217       3200:  46% 695/1519 [03:38<03:54,  3.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6743          0        334       3200:  46% 696/1519 [03:39<04:37,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6739          0        171       3200:  46% 697/1519 [03:39<03:54,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05442     0.6741          0        175       3200:  46% 698/1519 [03:39<04:38,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6749          0        533       3200:  46% 699/1519 [03:39<04:01,  3.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6746          0        202       3200:  46% 700/1519 [03:40<04:37,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05444     0.6747          0        234       3200:  46% 701/1519 [03:40<04:05,  3.33it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05443     0.6743          0        125       3200:  46% 702/1519 [03:41<04:41,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6741          0        187       3200:  46% 703/1519 [03:41<04:06,  3.31it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.8G    0.05441     0.6737          0        158       3200:  46% 704/1519 [03:41<04:37,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6705          0        117       3200:  97% 1471/1519 [07:43<00:13,  3.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6705          0        258       3200:  97% 1472/1519 [07:44<00:15,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6703          0        136       3200:  97% 1473/1519 [07:44<00:13,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6704          0        332       3200:  97% 1474/1519 [07:45<00:15,  2.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6704          0        198       3200:  97% 1475/1519 [07:45<00:12,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6706          0        409       3200:  97% 1476/1519 [07:45<00:14,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6705          0         96       3200:  97% 1477/1519 [07:45<00:12,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6704          0        191       3200:  97% 1478/1519 [07:46<00:13,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6704          0        325       3200:  97% 1479/1519 [07:46<00:11,  3.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6704          0        216       3200:  97% 1480/1519 [07:46<00:13,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6703          0        160       3200:  97% 1481/1519 [07:47<00:10,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6704          0        238       3200:  98% 1482/1519 [07:47<00:12,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6706          0        320       3200:  98% 1483/1519 [07:47<00:10,  3.54it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6709          0        319       3200:  98% 1484/1519 [07:48<00:11,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6715          0        442       3200:  98% 1485/1519 [07:48<00:09,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6716          0        473       3200:  98% 1486/1519 [07:48<00:11,  2.89it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05416     0.6713          0         43       3200:  98% 1487/1519 [07:48<00:09,  3.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05416     0.6717          0        633       3200:  98% 1488/1519 [07:49<00:10,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05416     0.6718          0        250       3200:  98% 1489/1519 [07:49<00:08,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6716          0        105       3200:  98% 1490/1519 [07:50<00:09,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6717          0        335       3200:  98% 1491/1519 [07:50<00:08,  3.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6717          0        217       3200:  98% 1492/1519 [07:50<00:09,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6716          0        239       3200:  98% 1493/1519 [07:50<00:07,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6714          0        127       3200:  98% 1494/1519 [07:51<00:08,  2.93it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6713          0        157       3200:  98% 1495/1519 [07:51<00:06,  3.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6712          0        243       3200:  98% 1496/1519 [07:52<00:07,  2.88it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413      0.671          0         78       3200:  99% 1497/1519 [07:52<00:06,  3.42it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6712          0        316       3200:  99% 1498/1519 [07:52<00:07,  2.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6712          0        154       3200:  99% 1499/1519 [07:52<00:05,  3.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6711          0        155       3200:  99% 1500/1519 [07:53<00:06,  2.94it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413      0.671          0        206       3200:  99% 1501/1519 [07:53<00:05,  3.48it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6714          0        706       3200:  99% 1502/1519 [07:53<00:05,  2.87it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6715          0        287       3200:  99% 1503/1519 [07:54<00:04,  3.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6716          0        207       3200:  99% 1504/1519 [07:54<00:05,  2.90it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415      0.672          0        573       3200:  99% 1505/1519 [07:54<00:04,  3.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6722          0        235       3200:  99% 1506/1519 [07:55<00:04,  2.92it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415      0.672          0        173       3200:  99% 1507/1519 [07:55<00:03,  3.40it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05415     0.6718          0         66       3200:  99% 1508/1519 [07:55<00:03,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6715          0         73       3200:  99% 1509/1519 [07:55<00:02,  3.54it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6712          0         55       3200:  99% 1510/1519 [07:56<00:03,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413      0.671          0        175       3200:  99% 1511/1519 [07:56<00:02,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05412     0.6707          0         90       3200: 100% 1512/1519 [07:57<00:02,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05412     0.6709          0        345       3200: 100% 1513/1519 [07:57<00:01,  3.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05412     0.6712          0        456       3200: 100% 1514/1519 [07:57<00:01,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05412     0.6717          0        843       3200: 100% 1515/1519 [07:57<00:01,  3.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6714          0         28       3200: 100% 1516/1519 [07:58<00:01,  2.98it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05413     0.6715          0        325       3200: 100% 1517/1519 [07:58<00:00,  3.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6715          0        229       3200: 100% 1518/1519 [07:58<00:00,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.8G    0.05414     0.6715          0        210       3200: 100% 1519/1519 [07:59<00:00,  3.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 31/31 [00:03<00:00,  9.05it/s]
#                    all        124       9424      0.915      0.884       0.93      0.542
#
# 50 epochs completed in 6.720 hours.
# Optimizer stripped from runs/train/yolov5s_results2/weights/last.pt, 18.0MB
# Optimizer stripped from runs/train/yolov5s_results2/weights/best.pt, 18.0MB
#
# Validating runs/train/yolov5s_results2/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  26% 8/31 [00:02<00:08,  2.82it/s]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 31/31 [00:10<00:00,  2.95it/s]
#                    all        124       9424      0.915      0.875      0.922      0.537
# Results saved to runs/train/yolov5s_results2
# CPU times: user 2min 52s, sys: 36.1 s, total: 3min 28s
# Wall time: 6h 44min 15s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# You can view the training graphs associated with a training job in the `/content/yolov5/runs/train/yolov5s_results/results.png` folder.
#
# Training losses and performance metrics are also saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results2/results.png', width=1000)

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results2/confusion_matrix.png', width=1000)

# %% [markdown]
# # Run Inference With Trained Weights
#
# Next, we can run inference with a pretrained checkpoint on all images in the `test/images` folder to understand how our model performs on our test set.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results2/weights
# Out:
# best.pt  last.pt

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results2/weights/best.pt --img 416 --conf 0.35 --source {dataset.location}/test/images/
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results2/weights/best.pt'], source=/content/yolov5/ScanBugS1v2-8/test/images/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC2_DATE1_004_png_jpg.rf.3e6cdcffd4fec46465196461788f5e5c.jpg: 320x416 28 Arthropods, 39.6ms
# image 2/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC3_DATE1_004_png_jpg.rf.fdb98dc64da8a746a7179ba03c943cdc.jpg: 320x416 5 Arthropods, 7.4ms
# image 3/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC3_DATE2_070_png_jpg.rf.2c16f3551fe7acac973da28510859e7c.jpg: 320x416 1 Arthropod, 7.2ms
# image 4/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC6_DATE1_012_png_jpg.rf.9abe4e12ccfa997db517e80b04ea6de6.jpg: 320x416 7 Arthropods, 7.1ms
# image 5/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC6_DATE7_213_jpg.rf.fd80f2750aba69a6e5fb37d41450e53a.jpg: 320x416 1 Arthropod, 7.7ms
# image 6/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC7_DATE4_001-copy_jpg.rf.831bfb6136e5b1bd582365e2e5690f62.jpg: 320x416 2 Arthropods, 7.0ms
# image 7/61 /content/yolov5/ScanBugS1v2-8/test/images/B_LOC8_DATE2_110_png_jpg.rf.03c23f6eaf67909018176b7da619e223.jpg: 320x416 (no detections), 7.0ms
# image 8/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC1_DATE1_002-copy_jpg.rf.a3d248e2465329e1c8c0efad696daf57.jpg: 320x416 22 Arthropods, 7.1ms
# image 9/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC2_DATE1_005_png_jpg.rf.d95894af23e5915ca123ebc9bed147a3.jpg: 320x416 15 Arthropods, 7.0ms
# image 10/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC3_DATE1_005_png_jpg.rf.04290c6df783b9f30d763af7adb43b69.jpg: 320x416 4 Arthropods, 7.2ms
# image 11/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC4_DATE5_063_jpg.rf.6d5ec2263b80755975b7c5c4a38d2e20.jpg: 320x416 2 Arthropods, 7.1ms
# image 12/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC4_DATE8_318_jpg.rf.fae948cb42c239a0fdd93eef74218e78.jpg: 320x416 (no detections), 7.1ms
# image 13/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC6_DATE7_216_jpg.rf.d277b89f73ae666011f6ff937a52f3dc.jpg: 320x416 16 Arthropods, 7.7ms
# image 14/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC9_DATE1_037_png_jpg.rf.a84b30f57cd5392fdf43738f5f744c17.jpg: 320x416 4 Arthropods, 7.2ms
# image 15/61 /content/yolov5/ScanBugS1v2-8/test/images/DB_LOC9_DATE8_308_jpg.rf.cf22c5deb4e7481c9e40a6b2490e7612.jpg: 320x416 1 Arthropod, 7.3ms
# image 16/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC1_DATE2_055_png_jpg.rf.0d1b68551b7b3ad345c479c6b149b6c8.jpg: 320x416 5 Arthropods, 7.2ms
# image 17/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC1_DATE8_303_jpg.rf.41125e4e1f3f228d35e978918089aef6.jpg: 320x416 8 Arthropods, 7.3ms
# image 18/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC2_DATE2_063_png_jpg.rf.9426fc11d6684f2298c8d9c301a3e668.jpg: 320x416 3 Arthropods, 7.2ms
# image 19/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC2_DATE5014_jpg.rf.d6e5be4835ed1ca08df6602909d496fc.jpg: 320x416 1 Arthropod, 7.4ms
# image 20/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC5_DATE6_120_jpg.rf.6ef0e0f0bf9fffaff82a33ce81ece102.jpg: 320x416 35 Arthropods, 7.5ms
# image 21/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC7_DATE8_258_jpg.rf.63c1daa0168f3c01e5c024176fc4591f.jpg: 320x416 5 Arthropods, 7.2ms
# image 22/61 /content/yolov5/ScanBugS1v2-8/test/images/UVB_LOC8_DATE7_244_jpg.rf.297fd8a57913033c1f0048bc29b9c80f.jpg: 320x416 14 Arthropods, 6.9ms
# image 23/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC2_DATE2_058_png_jpg.rf.f7314890b9ad0ea3eeaf2a650c865cd9.jpg: 320x416 4 Arthropods, 7.0ms
# image 24/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC2_DATE5009_jpg.rf.052366552f465bf3099d5a14fd8b9a76.jpg: 320x416 (no detections), 7.1ms
# image 25/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC2_DATE7_177_jpg.rf.85e49803a5530116884d211c984fba47.jpg: 320x416 6 Arthropods, 7.1ms
# image 26/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC2_DATE8_261_jpg.rf.1314b93cea66e5411b41d4c4846f58ce.jpg: 320x416 1 Arthropod, 7.1ms
# image 27/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC4_DATE3025-copy_jpg.rf.0d09e433b152f78605f520a7abf2270c.jpg: 320x416 2 Arthropods, 7.0ms
# image 28/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC5_DATE8_277_jpg.rf.0a90219e9da709dceb41eb4c4aef7183.jpg: 320x416 9 Arthropods, 6.9ms
# image 29/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC6_DATE3025-copy_jpg.rf.048c3167eead04cfeaaf803244ac51a9.jpg: 320x416 3 Arthropods, 7.0ms
# image 30/61 /content/yolov5/ScanBugS1v2-8/test/images/UVG_LOC9_DATE5_072_jpg.rf.b6a515952cd87ba96e4b9abdb308ce8b.jpg: 320x416 4 Arthropods, 7.1ms
# image 31/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC10_DATE1_041_png_jpg.rf.d789c87386556b049a6ea14d14444472.jpg: 320x416 35 Arthropods, 6.9ms
# image 32/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC2_DATE8_260_jpg.rf.c5edd9fba213e179ba8863d9bf8eb6bf.jpg: 320x416 9 Arthropods, 6.9ms
# image 33/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC3_DATE2_069_png_jpg.rf.4ccccae210ce28158281043ee7253393.jpg: 320x416 (no detections), 6.8ms
# image 34/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC3_DATE4_001-copy_jpg.rf.2edae9d1d82779b3fd763bbf8283a6d4.jpg: 320x416 (no detections), 6.8ms
# image 35/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC3_DATE5_081_jpg.rf.bef89c4bb6df5680ac369cc1837c2dcb.jpg: 320x416 1 Arthropod, 6.8ms
# image 36/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC3_DATE7_238_jpg.rf.b48bf495a5c6dcd85a01deb0412e5972.jpg: 320x416 6 Arthropods, 7.3ms
# image 37/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC4_DATE2_079_png_jpg.rf.74bfa24784570cee6b00bf09bf31fdec.jpg: 320x416 3 Arthropods, 7.2ms
# image 38/61 /content/yolov5/ScanBugS1v2-8/test/images/UVO_LOC6_DATE3025-copy_jpg.rf.a370ebb4b2004906b3af83399205d1c6.jpg: 320x416 11 Arthropods, 7.3ms
# image 39/61 /content/yolov5/ScanBugS1v2-8/test/images/UVR_LOC1_DATE4_001-copy_jpg.rf.ca74de87479623f7854cc920ba305ce7.jpg: 320x416 1 Arthropod, 7.1ms
# image 40/61 /content/yolov5/ScanBugS1v2-8/test/images/UVR_LOC1_DATE7_229_jpg.rf.64bf9997efca1f9d123f8db4d8e066fc.jpg: 320x416 3 Arthropods, 7.2ms
# image 41/61 /content/yolov5/ScanBugS1v2-8/test/images/UVR_LOC1_DATE8_304_jpg.rf.b6c88980aec99440acc535bf8c753ec9.jpg: 320x416 6 Arthropods, 7.2ms
# image 42/61 /content/yolov5/ScanBugS1v2-8/test/images/UVR_LOC2_DATE2_064_png_jpg.rf.58999568d5e25d7d4f9de36189f45772.jpg: 320x416 (no detections), 7.0ms
# image 43/61 /content/yolov5/ScanBugS1v2-8/test/images/UVR_LOC2_DATE8_266_jpg.rf.9f37394cde8589dd7c9401a7f253fecd.jpg: 320x416 2 Arthropods, 7.0ms
# image 44/61 /content/yolov5/ScanBugS1v2-8/test/images/UVR_LOC4_DATE3025-copy_jpg.rf.dee5d5359b82fcb1091625ef06dbc090.jpg: 320x416 1 Arthropod, 7.1ms
# image 45/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC10_DATE5020_jpg.rf.9f87c7c718b51aff4954fd6ff60e48b6.jpg: 320x416 6 Arthropods, 7.2ms
# image 46/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC10_DATE7_183_jpg.rf.5ae987a374ec5e611d7c35b09bc4271e.jpg: 320x416 9 Arthropods, 7.2ms
# image 47/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC1_DATE4_001-copy_jpg.rf.f99ba8feeec3231829a9112413f22dda.jpg: 320x416 3 Arthropods, 7.2ms
# image 48/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC1_DATE6_138_jpg.rf.ff1c63762636ffdbaf8c22199f7b8d35.jpg: 320x416 3 Arthropods, 7.2ms
# image 49/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC3_DATE1_007_png_jpg.rf.ec93f6af5c8c51fda22a55bd8227f251.jpg: 320x416 7 Arthropods, 7.1ms
# image 50/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC3_DATE3024-copy_jpg.rf.a48b4172580cbaa95f11937a5d75f613.jpg: 320x416 3 Arthropods, 7.2ms
# image 51/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC3_DATE3024-copy_jpg.rf.e1d09988a44e6950b50b5487093de1ff.jpg: 320x416 2 Arthropods, 7.3ms
# image 52/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC7_DATE7_209_jpg.rf.f8992a485426f84291e0837ba5791b50.jpg: 320x416 10 Arthropods, 7.3ms
# image 53/61 /content/yolov5/ScanBugS1v2-8/test/images/UVY_LOC9_DATE8_311_jpg.rf.d50a62f28101f11d77d8c4e12b07a17e.jpg: 320x416 3 Arthropods, 7.3ms
# image 54/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC1_DATE3_007-copy_jpg.rf.978bd456a740509cce00ebfc3dda6838.jpg: 320x416 16 Arthropods, 8.1ms
# image 55/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC2_DATE4_001-copy_jpg.rf.afe1781e03491890884a0392fa2110ba.jpg: 320x416 6 Arthropods, 7.2ms
# image 56/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC4_DATE4_001-copy_jpg.rf.1ee3d36dc0a097b175d81e53c65cf810.jpg: 320x416 6 Arthropods, 7.1ms
# image 57/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC5_DATE1_002-copy_jpg.rf.6537f078b148f12b3be137a9c94a79de.jpg: 320x416 42 Arthropods, 7.1ms
# image 58/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC5_DATE2_090_png_jpg.rf.61ed2fe2f6aff21ef2652e4319d62226.jpg: 320x416 (no detections), 7.1ms
# image 59/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC6_DATE6_145_jpg.rf.a4cc76ea166739a335de76f76191eb92.jpg: 320x416 23 Arthropods, 6.9ms
# image 60/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC7_DATE1_018_png_jpg.rf.4d19b162bc685fed3a9bc48421361a2e.jpg: 320x416 3 Arthropods, 6.8ms
# image 61/61 /content/yolov5/ScanBugS1v2-8/test/images/W_LOC7_DATE6_124_jpg.rf.78cca9d6d0fe9986f40b34b9d33d5723.jpg: 320x416 16 Arthropods, 7.2ms
# Speed: 0.3ms pre-process, 7.7ms inference, 3.5ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Deploy Model on Roboflow
#
# Once you have finished training your YOLOv5 model, you’ll have a set of trained weights ready for use. These weights will be in the `/content/yolov5/runs/train/yolov5s_results/` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv5 weights.
#
# **Before you run this code, make sure you create a new Version in the Roboflow dashboard following the instructions we covered earlier. Fill in your project name, workspace, and version number below.**
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov5", model_path=f"/content/yolov5/runs/train/yolov5s_results2/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/computervisionlab/scanbugs1v2/8
# Share your model with the world at: https://universe.roboflow.com/computervisionlab/scanbugs1v2/model/8

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on W_LOC5_DATE2_090_png_jpg.rf.61ed2fe2f6aff21ef2652e4319d62226.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1ba6ac5d9ae3> in <cell line: 0>()
#      10 print("running inference on " + random_test_image)
#      11
# ---> 12 pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
#      13 pred
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
# iou_threshold = 0.5
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_threshold,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

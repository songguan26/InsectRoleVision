# %%
# !nvidia-smi
# Out:
# Mon May 12 03:33:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Install YOLOv5

# %%
# clone YOLOv5 repository
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17478, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 17478 (delta 80), reused 37 (delta 32), pack-reused 17356 (from 2)
# Receiving objects: 100% (17478/17478), 16.36 MiB | 18.01 MiB/s, done.
# Resolving deltas: 100% (11981/11981), done.

# %%
# install dependencies as necessary
# !pip install -r requirements.txt
# !pip uninstall wandb -qy  # deprecated dependency
import torch

from IPython.display import Image, clear_output  # to display images

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Setup complete. Using torch 2.6.0+cu124 _CudaDeviceProperties(name='NVIDIA A100-SXM4-40GB', major=8, minor=0, total_memory=40506MB, multi_processor_count=108, uuid=6088ee86-d6f7-760f-95e8-145c9fd61c4a, L2_cache_size=40MB)

# %%
# %cd /content/yolov5
# !pip install -q roboflow==1.1.48

from roboflow import Roboflow
rf = Roboflow(api_key="q5dx0cWktqaKU3A8SD6P")
project = rf.workspace("computervisionlab").project("scanbugm1")
dataset = project.version(2).download("yolov5")
# Out:
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 49.2 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov5pytorch in progress : 85.0%
# Version export complete for yolov5pytorch format
# Downloading Dataset Version Zip in ScanBugM1-2 to yolov5pytorch:: 100%|██████████| 386194/386194 [00:23<00:00, 16396.40it/s]
# Extracting Dataset Version Zip to ScanBugM1-2 in yolov5pytorch:: 100%|██████████| 6458/6458 [00:01<00:00, 4579.87it/s]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **cache:** cache images for faster training

# %%
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py \
  --img 3200 \
  --batch 2 \
  --epochs 50 \
  --data {dataset.location}/data.yaml \
  --weights yolov5s.pt \
  --name yolov5s_results  \
  --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       48/49      11.9G     0.0354     0.4503    0.02254        202       3200:  37% 555/1519 [02:53<05:29,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4503    0.02254        219       3200:  37% 556/1519 [02:53<04:39,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4499    0.02254        129       3200:  37% 557/1519 [02:54<05:27,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4497    0.02255        161       3200:  37% 558/1519 [02:54<04:37,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4492    0.02258         76       3200:  37% 559/1519 [02:55<05:26,  2.94it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541      0.449    0.02258        146       3200:  37% 560/1519 [02:55<04:36,  3.47it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4485    0.02258         80       3200:  37% 561/1519 [02:55<05:24,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4481    0.02258         85       3200:  37% 562/1519 [02:55<04:40,  3.42it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4478    0.02257        135       3200:  37% 563/1519 [02:56<05:24,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4477    0.02258        223       3200:  37% 564/1519 [02:56<04:38,  3.43it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4473    0.02257         89       3200:  37% 565/1519 [02:56<05:20,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4477    0.02256        316       3200:  37% 566/1519 [02:57<04:33,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03537      0.448    0.02256        303       3200:  37% 567/1519 [02:57<05:22,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4487    0.02256        399       3200:  37% 568/1519 [02:57<04:34,  3.47it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4492    0.02254        395       3200:  37% 569/1519 [02:58<05:25,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4487    0.02255         62       3200:  38% 570/1519 [02:58<04:34,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4483    0.02256         84       3200:  38% 571/1519 [02:58<05:23,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4482    0.02254        173       3200:  38% 572/1519 [02:59<04:33,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4478    0.02254         90       3200:  38% 573/1519 [02:59<05:19,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4479    0.02253        204       3200:  38% 574/1519 [02:59<04:30,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4476    0.02253         94       3200:  38% 575/1519 [03:00<05:18,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4474    0.02254        205       3200:  38% 576/1519 [03:00<04:30,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4475    0.02254        227       3200:  38% 577/1519 [03:00<05:18,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4474    0.02254        266       3200:  38% 578/1519 [03:00<04:30,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4471    0.02254        111       3200:  38% 579/1519 [03:01<05:24,  2.90it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4472    0.02254        245       3200:  38% 580/1519 [03:01<04:34,  3.43it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4471    0.02254        203       3200:  38% 581/1519 [03:01<05:20,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4473    0.02255        295       3200:  38% 582/1519 [03:02<04:31,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4471    0.02255        139       3200:  38% 583/1519 [03:02<05:15,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4467    0.02255         93       3200:  38% 584/1519 [03:02<04:27,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539      0.447    0.02255        326       3200:  39% 585/1519 [03:03<05:15,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4468    0.02254        132       3200:  39% 586/1519 [03:03<04:27,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4468    0.02254        252       3200:  39% 587/1519 [03:03<05:20,  2.90it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4477    0.02253        461       3200:  39% 588/1519 [03:04<04:33,  3.40it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4484    0.02253        418       3200:  39% 589/1519 [03:04<05:22,  2.89it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4479    0.02254         53       3200:  39% 590/1519 [03:04<04:31,  3.42it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4485    0.02254        442       3200:  39% 591/1519 [03:05<05:29,  2.82it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4483    0.02254        149       3200:  39% 592/1519 [03:05<04:37,  3.34it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4481    0.02255        188       3200:  39% 593/1519 [03:05<05:18,  2.90it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539      0.449    0.02253        508       3200:  39% 594/1519 [03:05<04:34,  3.37it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4486    0.02253         96       3200:  39% 595/1519 [03:06<05:09,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4483    0.02252        113       3200:  39% 596/1519 [03:06<04:22,  3.51it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4484    0.02251        292       3200:  39% 597/1519 [03:07<05:09,  2.98it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4488    0.02251        399       3200:  39% 598/1519 [03:07<04:23,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4484    0.02252         80       3200:  39% 599/1519 [03:07<05:07,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4486    0.02252        279       3200:  39% 600/1519 [03:07<04:21,  3.51it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4487    0.02253        253       3200:  40% 601/1519 [03:08<05:07,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4488    0.02253        230       3200:  40% 602/1519 [03:08<04:20,  3.52it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4489    0.02253        239       3200:  40% 603/1519 [03:08<05:06,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4487    0.02253        179       3200:  40% 604/1519 [03:09<04:20,  3.52it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4484    0.02252        101       3200:  40% 605/1519 [03:09<05:04,  3.01it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4484    0.02251        189       3200:  40% 606/1519 [03:09<04:18,  3.53it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4482    0.02251        167       3200:  40% 607/1519 [03:10<05:07,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4483     0.0225        234       3200:  40% 608/1519 [03:10<04:20,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539      0.449    0.02249        529       3200:  40% 609/1519 [03:10<05:11,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4495    0.02249        398       3200:  40% 610/1519 [03:10<04:23,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4492    0.02249        109       3200:  40% 611/1519 [03:11<05:08,  2.94it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4487    0.02248         65       3200:  40% 612/1519 [03:11<04:20,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4488    0.02248        286       3200:  40% 613/1519 [03:12<05:08,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4496    0.02249        563       3200:  40% 614/1519 [03:12<04:23,  3.43it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4497    0.02248        266       3200:  40% 615/1519 [03:12<05:10,  2.91it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4497    0.02248        219       3200:  41% 616/1519 [03:12<04:22,  3.44it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4502    0.02247        373       3200:  41% 617/1519 [03:13<05:06,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538       0.45    0.02247        185       3200:  41% 618/1519 [03:13<04:18,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538       0.45    0.02246        177       3200:  41% 619/1519 [03:13<05:07,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4498    0.02246        136       3200:  41% 620/1519 [03:14<04:20,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4496    0.02247        133       3200:  41% 621/1519 [03:14<05:04,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4493    0.02246        100       3200:  41% 622/1519 [03:14<04:17,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4496    0.02246        280       3200:  41% 623/1519 [03:15<05:02,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4493    0.02246        183       3200:  41% 624/1519 [03:15<04:15,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4497    0.02246        322       3200:  41% 625/1519 [03:15<05:04,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4495    0.02247        178       3200:  41% 626/1519 [03:16<04:25,  3.36it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4493    0.02248        166       3200:  41% 627/1519 [03:16<05:04,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4494    0.02248        220       3200:  41% 628/1519 [03:16<04:18,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4499    0.02248        380       3200:  41% 629/1519 [03:17<05:08,  2.89it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4496    0.02247         99       3200:  41% 630/1519 [03:17<04:22,  3.39it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4492    0.02248        109       3200:  42% 631/1519 [03:17<05:04,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4495    0.02248        322       3200:  42% 632/1519 [03:17<04:17,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03537     0.4493    0.02249        141       3200:  42% 633/1519 [03:18<04:58,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03537     0.4491     0.0225        135       3200:  42% 634/1519 [03:18<04:13,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03535     0.4486    0.02251         70       3200:  42% 635/1519 [03:18<04:56,  2.98it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03535     0.4481    0.02252         62       3200:  42% 636/1519 [03:19<04:11,  3.51it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03536     0.4489    0.02253        578       3200:  42% 637/1519 [03:19<04:58,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03536     0.4484    0.02253         35       3200:  42% 638/1519 [03:19<04:12,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03537     0.4482    0.02252        136       3200:  42% 639/1519 [03:20<04:54,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03537     0.4479     0.0225        115       3200:  42% 640/1519 [03:20<04:09,  3.52it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4478    0.02252        153       3200:  42% 641/1519 [03:20<04:55,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4477    0.02252        216       3200:  42% 642/1519 [03:20<04:10,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4473    0.02252         70       3200:  42% 643/1519 [03:21<04:54,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4479    0.02252        469       3200:  42% 644/1519 [03:21<04:10,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03537     0.4476    0.02251        126       3200:  42% 645/1519 [03:22<04:55,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538      0.447    0.02252         42       3200:  43% 646/1519 [03:22<04:10,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4467    0.02254         99       3200:  43% 647/1519 [03:22<04:57,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03538     0.4472    0.02255        408       3200:  43% 648/1519 [03:22<04:11,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4469    0.02255        107       3200:  43% 649/1519 [03:23<04:52,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4479    0.02253        506       3200:  43% 650/1519 [03:23<04:09,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4479    0.02254        253       3200:  43% 651/1519 [03:23<04:56,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4476    0.02255        119       3200:  43% 652/1519 [03:24<04:11,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4476    0.02256        227       3200:  43% 653/1519 [03:24<04:54,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4474    0.02256        164       3200:  43% 654/1519 [03:24<04:10,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4469    0.02257         53       3200:  43% 655/1519 [03:25<04:50,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4467    0.02257        121       3200:  43% 656/1519 [03:25<04:06,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4465    0.02256        193       3200:  43% 657/1519 [03:25<04:52,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539      0.447    0.02256        393       3200:  43% 658/1519 [03:26<04:11,  3.42it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4465    0.02256         41       3200:  43% 659/1519 [03:26<04:49,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4465    0.02256        188       3200:  43% 660/1519 [03:26<04:05,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541      0.447    0.02255        466       3200:  44% 661/1519 [03:27<04:58,  2.88it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4474    0.02254        426       3200:  44% 662/1519 [03:27<04:11,  3.41it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4474    0.02253        242       3200:  44% 663/1519 [03:27<04:48,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4472    0.02254        129       3200:  44% 664/1519 [03:27<04:04,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4475    0.02253        493       3200:  44% 665/1519 [03:28<04:53,  2.91it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4472    0.02254        114       3200:  44% 666/1519 [03:28<04:07,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4472    0.02254        214       3200:  44% 667/1519 [03:29<04:51,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4472    0.02254        290       3200:  44% 668/1519 [03:29<04:06,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4469    0.02253        118       3200:  44% 669/1519 [03:29<04:43,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541      0.447    0.02253        218       3200:  44% 670/1519 [03:29<04:01,  3.52it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541      0.447    0.02252        150       3200:  44% 671/1519 [03:30<04:43,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4471    0.02252        228       3200:  44% 672/1519 [03:30<04:01,  3.51it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4472    0.02252        214       3200:  44% 673/1519 [03:30<04:46,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4473    0.02252        268       3200:  44% 674/1519 [03:31<04:02,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4471    0.02252        159       3200:  44% 675/1519 [03:31<04:45,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4469    0.02251        111       3200:  45% 676/1519 [03:31<04:01,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4466    0.02251        119       3200:  45% 677/1519 [03:32<04:44,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4462    0.02252         89       3200:  45% 678/1519 [03:32<04:01,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4462    0.02252        215       3200:  45% 679/1519 [03:32<04:47,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354      0.447    0.02252        467       3200:  45% 680/1519 [03:32<04:03,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4471    0.02253        291       3200:  45% 681/1519 [03:33<04:48,  2.91it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4474    0.02252        371       3200:  45% 682/1519 [03:33<04:03,  3.44it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539     0.4473    0.02252        237       3200:  45% 683/1519 [03:34<04:45,  2.93it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03539      0.448    0.02253        445       3200:  45% 684/1519 [03:34<04:01,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4487    0.02253        546       3200:  45% 685/1519 [03:34<04:47,  2.90it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4488    0.02253        203       3200:  45% 686/1519 [03:34<04:02,  3.43it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4487    0.02253        265       3200:  45% 687/1519 [03:35<04:48,  2.89it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4486    0.02253        151       3200:  45% 688/1519 [03:35<04:03,  3.42it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4488    0.02253        342       3200:  45% 689/1519 [03:35<04:44,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4483    0.02254         48       3200:  45% 690/1519 [03:36<04:04,  3.39it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4485    0.02254        262       3200:  45% 691/1519 [03:36<04:39,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4484    0.02254        145       3200:  46% 692/1519 [03:36<03:56,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4485    0.02254        293       3200:  46% 693/1519 [03:37<04:38,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4481    0.02255         64       3200:  46% 694/1519 [03:37<03:55,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4479    0.02255        130       3200:  46% 695/1519 [03:37<04:37,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03543      0.448    0.02257        232       3200:  46% 696/1519 [03:37<03:55,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03543     0.4478    0.02257        139       3200:  46% 697/1519 [03:38<04:44,  2.89it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4474    0.02257         64       3200:  46% 698/1519 [03:38<04:00,  3.41it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4474    0.02258        294       3200:  46% 699/1519 [03:39<04:44,  2.88it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4474    0.02258        267       3200:  46% 700/1519 [03:39<04:00,  3.41it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4472    0.02258        152       3200:  46% 701/1519 [03:39<04:41,  2.91it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542      0.447    0.02259        154       3200:  46% 702/1519 [03:39<03:57,  3.44it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4467    0.02261        103       3200:  46% 703/1519 [03:40<04:36,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4465    0.02261        175       3200:  46% 704/1519 [03:40<03:54,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03542     0.4472     0.0226        414       3200:  46% 705/1519 [03:40<04:35,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4471     0.0226        219       3200:  46% 706/1519 [03:41<03:53,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4474    0.02261        326       3200:  47% 707/1519 [03:41<04:33,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G    0.03541     0.4469    0.02263         62       3200:  47% 708/1519 [03:41<03:52,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354     0.4469    0.02262        185       3200:  47% 709/1519 [03:42<04:32,  2.98it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       48/49      11.9G     0.0354      0.447     0.0226        269       3200:  47% 710/1519 [03:42<03:51,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4476    0.02261        163       3200:  97% 1475/1519 [07:44<00:13,  3.38it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4476    0.02261        254       3200:  97% 1476/1519 [07:45<00:14,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4475    0.02261        101       3200:  97% 1477/1519 [07:45<00:12,  3.44it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4473    0.02261        135       3200:  97% 1478/1519 [07:45<00:13,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4475    0.02261        305       3200:  97% 1479/1519 [07:46<00:11,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4473    0.02261        130       3200:  97% 1480/1519 [07:46<00:13,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4475    0.02261        311       3200:  97% 1481/1519 [07:46<00:10,  3.47it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4476    0.02261        256       3200:  98% 1482/1519 [07:47<00:12,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4476    0.02261        230       3200:  98% 1483/1519 [07:47<00:10,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4478    0.02261        304       3200:  98% 1484/1519 [07:47<00:11,  2.98it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4479    0.02261        271       3200:  98% 1485/1519 [07:47<00:09,  3.51it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4481     0.0226        488       3200:  98% 1486/1519 [07:48<00:11,  2.94it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4479     0.0226         89       3200:  98% 1487/1519 [07:48<00:09,  3.47it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4481     0.0226        369       3200:  98% 1488/1519 [07:49<00:10,  2.94it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4482     0.0226        254       3200:  98% 1489/1519 [07:49<00:08,  3.47it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03516     0.4481     0.0226        161       3200:  98% 1490/1519 [07:49<00:09,  2.98it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4482     0.0226        271       3200:  98% 1491/1519 [07:49<00:07,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515      0.448     0.0226        122       3200:  98% 1492/1519 [07:50<00:09,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4482     0.0226        381       3200:  98% 1493/1519 [07:50<00:07,  3.50it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4482     0.0226        183       3200:  98% 1494/1519 [07:50<00:08,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4482     0.0226        179       3200:  98% 1495/1519 [07:51<00:06,  3.52it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4483     0.0226        445       3200:  98% 1496/1519 [07:51<00:07,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4482    0.02259        114       3200:  99% 1497/1519 [07:51<00:06,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4486    0.02259        569       3200:  99% 1498/1519 [07:52<00:07,  2.98it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4485    0.02258        132       3200:  99% 1499/1519 [07:52<00:05,  3.51it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4487    0.02259        262       3200:  99% 1500/1519 [07:52<00:06,  2.99it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4488    0.02259        245       3200:  99% 1501/1519 [07:52<00:05,  3.52it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4492    0.02259        817       3200:  99% 1502/1519 [07:53<00:05,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4491    0.02259        134       3200:  99% 1503/1519 [07:53<00:04,  3.44it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515      0.449    0.02258        172       3200:  99% 1504/1519 [07:54<00:05,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4493    0.02258        568       3200:  99% 1505/1519 [07:54<00:04,  3.47it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4494    0.02258        278       3200:  99% 1506/1519 [07:54<00:04,  3.02it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4492    0.02258         98       3200:  99% 1507/1519 [07:54<00:03,  3.44it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4491    0.02257         85       3200:  99% 1508/1519 [07:55<00:03,  2.97it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4493    0.02258        301       3200:  99% 1509/1519 [07:55<00:02,  3.49it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4492    0.02258        132       3200:  99% 1510/1519 [07:55<00:03,  2.92it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4491    0.02257        125       3200:  99% 1511/1519 [07:56<00:02,  3.45it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4489    0.02257         96       3200: 100% 1512/1519 [07:56<00:02,  2.96it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4491    0.02257        404       3200: 100% 1513/1519 [07:56<00:01,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4494    0.02257        475       3200: 100% 1514/1519 [07:57<00:01,  2.94it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4495    0.02256        365       3200: 100% 1515/1519 [07:57<00:01,  3.46it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03514     0.4493    0.02256         51       3200: 100% 1516/1519 [07:57<00:01,  2.95it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4494    0.02256        299       3200: 100% 1517/1519 [07:57<00:00,  3.48it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4495    0.02256        286       3200: 100% 1518/1519 [07:58<00:00,  2.87it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      11.9G    0.03515     0.4495    0.02256        236       3200: 100% 1519/1519 [07:58<00:00,  3.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 31/31 [00:05<00:00,  5.25it/s]
#                    all        124      10319      0.748      0.535      0.586      0.346
#
# 50 epochs completed in 6.770 hours.
# Optimizer stripped from runs/train/yolov5s_results2/weights/last.pt, 18.0MB
# Optimizer stripped from runs/train/yolov5s_results2/weights/best.pt, 18.0MB
#
# Validating runs/train/yolov5s_results2/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7042489 parameters, 0 gradients, 15.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  10% 3/31 [00:01<00:18,  1.51it/s]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 31/31 [00:14<00:00,  2.12it/s]
#                    all        124      10319      0.731       0.53      0.577      0.341
#              Arachnida        124        187      0.873     0.0369      0.176      0.118
#             Coleoptera        124        273      0.621      0.527      0.567      0.325
#     Diptera_Brachycera        124       4817      0.843      0.822      0.876      0.547
#     Diptera_Nematocera        124       2202      0.688      0.735      0.727      0.367
#      Diptera_Syrphidae        124        225      0.708      0.831      0.824       0.61
# Hemiptera_Aphidomorpha        124        296      0.746      0.218      0.405      0.201
#  Hemiptera_Heteroptera        124        184      0.397      0.375       0.37      0.214
# Hemiptera_Membracoidea        124        408      0.743       0.75       0.81      0.404
#   Hymenoptera_Apocrita        124       1113      0.592      0.523      0.569      0.342
# Hymenoptera_Formicidae        124        413      0.811       0.78      0.744      0.411
#            Lepidotpera        124         99      0.753      0.768      0.795      0.523
#               Psocodea        124        102          1          0     0.0617     0.0287
# Results saved to runs/train/yolov5s_results2
# CPU times: user 2min 45s, sys: 38 s, total: 3min 23s
# Wall time: 6h 47min 23s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# You can view the training graphs associated with a training job in the `/content/yolov5/runs/train/yolov5s_results/results.png` folder.
#
# Training losses and performance metrics are also saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results2/results.png', width=1000)

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results2/confusion_matrix.png', width=1000)

# %% [markdown]
# # Run Inference With Trained Weights
#
# Next, we can run inference with a pretrained checkpoint on all images in the `test/images` folder to understand how our model performs on our test set.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_results2/weights
# Out:
# best.pt  last.pt

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results2/weights/best.pt --img 416 --conf 0.35 --source {dataset.location}/test/images/
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results2/weights/best.pt'], source=/content/yolov5/ScanBugM1-2/test/images/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-418-ga493afe1 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7042489 parameters, 0 gradients, 15.9 GFLOPs
# image 1/61 /content/yolov5/ScanBugM1-2/test/images/B_LOC2_DATE5007_jpg.rf.e26b44c49fa44020320ac35dbec61eb3.jpg: 320x416 (no detections), 46.5ms
# image 2/61 /content/yolov5/ScanBugM1-2/test/images/B_LOC5_DATE8_279_jpg.rf.388675d1f535c2a50acff3184dbdf947.jpg: 320x416 11 Diptera_Brachyceras, 2 Diptera_Nematoceras, 8.2ms
# image 3/61 /content/yolov5/ScanBugM1-2/test/images/B_LOC8_DATE2_110_png_jpg.rf.53991b2ba7ef8057feed61a22a6654a8.jpg: 320x416 1 Hymenoptera_Apocrita, 7.7ms
# image 4/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC10_DATE2_124_png_jpg.rf.372c41ae6e4fc101c2e222cab14c9302.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 8.1ms
# image 5/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC10_DATE3_025-copy_jpg.rf.b6cf28117dc9410f617baae63f68564f.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 7.8ms
# image 6/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC3_DATE8_273_jpg.rf.6beb37b7f4bce8469ad424709d1ad0c8.jpg: 320x416 (no detections), 7.9ms
# image 7/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC4_DATE8_318_jpg.rf.53bc6682c3f45358e69107e50ea4e597.jpg: 320x416 (no detections), 8.1ms
# image 8/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC5_DATE8_281_jpg.rf.aaf60bcde1aa962402ae3399ee9d04f0.jpg: 320x416 1 Coleoptera, 7 Diptera_Brachyceras, 2 Diptera_Nematoceras, 7.6ms
# image 9/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC7_DATE4_001-copy_jpg.rf.6fb77201d682be127b31c63a4bfdd34e.jpg: 320x416 (no detections), 7.5ms
# image 10/61 /content/yolov5/ScanBugM1-2/test/images/DB_LOC8_DATE2_108_png_jpg.rf.0022dbb84ddb512fa524f3e784a2e441.jpg: 320x416 (no detections), 7.4ms
# image 11/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC10_DATE1_043_png_jpg.rf.661956dce03d0bc1e6477d50bc352b28.jpg: 320x416 3 Diptera_Brachyceras, 7.7ms
# image 12/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC10_DATE4_001-copy_jpg.rf.1aa143c7c49d9c29c2ed248ab83cb712.jpg: 320x416 3 Diptera_Brachyceras, 2 Diptera_Nematoceras, 7.5ms
# image 13/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC2_DATE6_165_jpg.rf.71c23ab74b085fb80f1b55e8e14ced5e.jpg: 320x416 1 Coleoptera, 7.5ms
# image 14/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC3_DATE2_072_png_jpg.rf.affccb80443056bd05353fdb06b67acf.jpg: 320x416 1 Diptera_Brachycera, 7.4ms
# image 15/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC3_DATE4_001-copy_jpg.rf.c7c7cb68b6bc797ff27ecdcbfccdc73d.jpg: 320x416 1 Diptera_Brachycera, 7.3ms
# image 16/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC4_DATE2_082_png_jpg.rf.21c7d96e7a87cbaeffa898031b5b7686.jpg: 320x416 2 Diptera_Nematoceras, 7.4ms
# image 17/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC4_DATE6_149_jpg.rf.ae2767eb982e45c9506dfe314f577dfd.jpg: 320x416 1 Diptera_Brachycera, 8.9ms
# image 18/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC5_DATE6_120_jpg.rf.8aaf5a27fd030e20bad0b26d8fe516f2.jpg: 320x416 19 Diptera_Brachyceras, 1 Diptera_Nematocera, 7.4ms
# image 19/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC7_DATE1_019_png_jpg.rf.49cc035fd45bf6b35fc9aa8de075d091.jpg: 320x416 1 Diptera_Brachycera, 7.5ms
# image 20/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC7_DATE5028_jpg.rf.494c76bafca6b2d87dc3a5c8340092b4.jpg: 320x416 11 Diptera_Nematoceras, 7.5ms
# image 21/61 /content/yolov5/ScanBugM1-2/test/images/UVB_LOC9_DATE5_071_jpg.rf.4a3218e6cabd9560fa3e9e60fa1ab21d.jpg: 320x416 2 Diptera_Brachyceras, 7.6ms
# image 22/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC10_DATE4_001-copy_jpg.rf.307cf1e83d4e4537be1467ec3836a2f7.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 7.4ms
# image 23/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC10_DATE6_100_jpg.rf.02c08aabafe0a5cdb13be66f898462c9.jpg: 320x416 6 Diptera_Brachyceras, 7.4ms
# image 24/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC2_DATE3_009-copy_jpg.rf.3ec55463c9849fbe774a3f0ddca6b150.jpg: 320x416 1 Diptera_Nematocera, 7.5ms
# image 25/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC4_DATE7_225_jpg.rf.b36f7f956818caeafadc1ffc1f347ffe.jpg: 320x416 3 Diptera_Brachyceras, 7.3ms
# image 26/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC4_DATE8_321_jpg.rf.3b328167f66cc299945fd7c9c7ccc35f.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 7.8ms
# image 27/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC6_DATE5_042_jpg.rf.6488528dbd76c625390aa9e0702cb863.jpg: 320x416 3 Diptera_Brachyceras, 1 Diptera_Nematocera, 7.5ms
# image 28/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC6_DATE6_142_jpg.rf.2c86755d824cc09182fb9f4c493f00f2.jpg: 320x416 (no detections), 7.4ms
# image 29/61 /content/yolov5/ScanBugM1-2/test/images/UVG_LOC7_DATE7_207_jpg.rf.2dc5d3392fcdb4a64ce23281b361cfae.jpg: 320x416 1 Diptera_Brachycera, 4 Diptera_Nematoceras, 7.5ms
# image 30/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC1_DATE3_006-copy_jpg.rf.be3a2fee960100c98cd59255e47c1e89.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 7.5ms
# image 31/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC1_DATE8_300_jpg.rf.589ef23a908a2103eecc47c75cedab5a.jpg: 320x416 3 Diptera_Brachyceras, 2 Diptera_Nematoceras, 7.5ms
# image 32/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC2_DATE6_166_jpg.rf.a2201e38bb86ea3ecd0d696b49c2fa63.jpg: 320x416 (no detections), 7.7ms
# image 33/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC3_DATE3022-copy_jpg.rf.adcfa92478ea00d350dd1bab18179b98.jpg: 320x416 (no detections), 7.5ms
# image 34/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC5_DATE5_035_jpg.rf.edafe7db65d8fb83db5f128d9b3f336c.jpg: 320x416 17 Diptera_Brachyceras, 1 Diptera_Nematocera, 7.5ms
# image 35/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC6_DATE1_009_png_jpg.rf.58b308ac4aa34bf4d3791e60283b731f.jpg: 320x416 12 Diptera_Brachyceras, 7.6ms
# image 36/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC6_DATE4_001-copy_jpg.rf.f549fdb055bfdedf019bd4781a1eb597.jpg: 320x416 2 Diptera_Brachyceras, 1 Diptera_Nematocera, 7.5ms
# image 37/61 /content/yolov5/ScanBugM1-2/test/images/UVO_LOC9_DATE5_066_jpg.rf.e3abc3b30052e00847582edb2fcb689d.jpg: 320x416 3 Diptera_Nematoceras, 8.9ms
# image 38/61 /content/yolov5/ScanBugM1-2/test/images/UVR_LOC1_DATE2_056_png_jpg.rf.9f91ffe7088e4bb9949bc341ba749ead.jpg: 320x416 2 Diptera_Nematoceras, 7.3ms
# image 39/61 /content/yolov5/ScanBugM1-2/test/images/UVR_LOC2_DATE1_008_png_jpg.rf.fb5d18e469e4951a53dce822abd12c69.jpg: 320x416 3 Diptera_Brachyceras, 7.2ms
# image 40/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC2_DATE6_169_jpg.rf.16811d16d5244e8012d38584baa649fd.jpg: 320x416 1 Diptera_Brachycera, 1 Diptera_Nematocera, 7.2ms
# image 41/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC2_DATE8_264_jpg.rf.da186fc51b08c8d5284e7643874a2638.jpg: 320x416 1 Diptera_Brachycera, 7.2ms
# image 42/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC3_DATE2_071_png_jpg.rf.f256248cf72e38b74ab8f36edb49e189.jpg: 320x416 1 Diptera_Brachycera, 7.3ms
# image 43/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC3_DATE5_084_jpg.rf.812b9656065fe0ced67879778fee0dd6.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 7.1ms
# image 44/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC4_DATE7_223_jpg.rf.036843be8857251ab94de2a7fce6722a.jpg: 320x416 4 Diptera_Brachyceras, 7.4ms
# image 45/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC5_DATE4_001-copy_jpg.rf.403a09e1cb02216fbe11285b6d43091b.jpg: 320x416 1 Diptera_Brachycera, 1 Diptera_Nematocera, 7.3ms
# image 46/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC5_DATE6_122_jpg.rf.8cd2b3199d20a994643a0b165b759bc2.jpg: 320x416 8 Diptera_Brachyceras, 3 Diptera_Nematoceras, 7.2ms
# image 47/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC6_DATE3_025-copy_jpg.rf.0e1e70e3e12bc46e8f348e194674af85.jpg: 320x416 2 Diptera_Brachyceras, 3 Diptera_Nematoceras, 7.6ms
# image 48/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC7_DATE6_123_jpg.rf.c5e9b5f7de0d0e7b290c273d4954f4db.jpg: 320x416 6 Diptera_Brachyceras, 1 Diptera_Nematocera, 1 Hymenoptera_Apocrita, 7.2ms
# image 49/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC9_DATE1_039_png_jpg.rf.f3322e6e832f5be9fe2a5ea34da910db.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 1 Hymenoptera_Apocrita, 7.4ms
# image 50/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC9_DATE6_112_jpg.rf.c49626ce2d0f0e9b31cc335e2acdf441.jpg: 320x416 2 Diptera_Brachyceras, 7.5ms
# image 51/61 /content/yolov5/ScanBugM1-2/test/images/UVY_LOC9_DATE7_195_jpg.rf.322a74661f163ed098c11acc2a403d05.jpg: 320x416 12 Diptera_Brachyceras, 1 Diptera_Nematocera, 7.3ms
# image 52/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC10_DATE1_042-copy_jpg.rf.d28a94704da834b52de1fe74e597287e.jpg: 320x416 1 Diptera_Nematocera, 7.4ms
# image 53/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC1_DATE7_231_jpg.rf.83a7be7bcc42a5567cfadbc24e1743ab.jpg: 320x416 3 Diptera_Nematoceras, 7.3ms
# image 54/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC2_DATE3_015-copy_jpg.rf.fa2022200a56aada59f6c6be25b3b9bc.jpg: 320x416 2 Diptera_Nematoceras, 7.3ms
# image 55/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC2_DATE6_167_jpg.rf.22dbd584fb565c420b8f8dccd18d4605.jpg: 320x416 1 Diptera_Brachycera, 2 Diptera_Nematoceras, 7.4ms
# image 56/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC3_DATE4_001-copy_jpg.rf.4bfec85877e38e5e17c1e782b275314c.jpg: 320x416 (no detections), 7.5ms
# image 57/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC3_DATE5_083_jpg.rf.1764a0814e9540b562f50e59638d31dc.jpg: 320x416 (no detections), 7.7ms
# image 58/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC3_DATE7_237_jpg.rf.8eee084264c245db2cc20de1b8b7b104.jpg: 320x416 (no detections), 7.5ms
# image 59/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC6_DATE3025-copy_jpg.rf.eb20b66b997421e1d01a4478d7155aa3.jpg: 320x416 (no detections), 7.6ms
# image 60/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC8_DATE6_160_jpg.rf.848202be5a3fda0e8a30ec5fcc9ac8f0.jpg: 320x416 3 Diptera_Brachyceras, 7.8ms
# image 61/61 /content/yolov5/ScanBugM1-2/test/images/W_LOC8_DATE7_250_jpg.rf.48b5160c2b38658199a493a558fa4fab.jpg: 320x416 2 Diptera_Brachyceras, 7.7ms
# Speed: 0.4ms pre-process, 8.2ms inference, 3.3ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Deploy Model on Roboflow
#
# Once you have finished training your YOLOv5 model, you’ll have a set of trained weights ready for use. These weights will be in the `/content/yolov5/runs/train/yolov5s_results/` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv5 weights.
#
# **Before you run this code, make sure you create a new Version in the Roboflow dashboard following the instructions we covered earlier. Fill in your project name, workspace, and version number below.**
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov5", model_path=f"/content/yolov5/runs/train/yolov5s_results2/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/computervisionlab/scanbugm1/2
# Share your model with the world at: https://universe.roboflow.com/computervisionlab/scanbugm1/model/2

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on W_LOC5_DATE2_090_png_jpg.rf.61ed2fe2f6aff21ef2652e4319d62226.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1ba6ac5d9ae3> in <cell line: 0>()
#      10 print("running inference on " + random_test_image)
#      11
# ---> 12 pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
#      13 pred
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
# iou_threshold = 0.5
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_threshold,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

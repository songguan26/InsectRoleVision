# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue May 13 03:40:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             45W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 42.5/235.7 GB disk)

# %% [markdown]
# **NOTE:** When training YOLOv11, make sure your data is located in `datasets`. If you'd like to change the default location of the data you want to use for fine-tuning, you can do so through Ultralytics' `settings.json`. In this tutorial, we will use one of the [datasets](https://universe.roboflow.com/liangdianzhong/-qvdww) available on [Roboflow Universe](https://universe.roboflow.com/). When downloading, make sure to select the `yolov11` export format.

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
from roboflow import Roboflow
rf = Roboflow(api_key="XXXX")

workspace = rf.workspace("computervisionlab")
project = workspace.project("scanbugm1")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# Downloading Dataset Version Zip in ScanBugM1-4 to yolov11:: 100%|██████████| 387203/387203 [00:22<00:00, 17040.79it/s]
# Extracting Dataset Version Zip to ScanBugM1-4 in yolov11:: 100%|██████████| 6458/6458 [00:01<00:00, 4567.88it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=50 imgsz=3200 batch=2 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt'...
# 100% 18.4M/18.4M [00:00<00:00, 323MB/s]
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=2, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/datasets/ScanBugM1-4/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=3200, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 155MB/s]
# Overriding model.yaml nc=80 with nc=12
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    824052  ultralytics.nn.modules.head.Detect           [12, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,432,436 parameters, 9,432,420 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 310MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2238.7±996.0 MB/s, size: 124.8 KB)
# train: Scanning /content/datasets/ScanBugM1-4/train/labels... 3038 images, 0 backgrounds, 0 corrupt: 100% 3038/3038 [00:02<00:00, 1168.47it/s]
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.0ab3759296dd41ddf6358d730e6b8fbc.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.48dabf6f06a8ad08d9f835a6f024703e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.5989d5f4451990071f17f5a68152ed6e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.6e12d499ce759d1bd9cc25c484cf3221.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.c229715928fc44385042b6712cf527f2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.e8e9af94d58614da69027bcb011070ff.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE1_044_png_jpg.rf.fadff2fe10d0e24ca577c20369ef457a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.098f0c2889735b323efef646680321a0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.0da2c382a847927368777dfb93e5a338.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.0f1b1ebfcad56dc378e2d11a86942326.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.8086995cc928400c6bb9ec48092b397b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.8325a9e0376a3eacd3ec337c3f82b8d6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.cc7de9ae502ecf11c785602d36480093.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC10_DATE2_126_png_jpg.rf.f9d0fc8d5abd5c4717e3ec328155f6de.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.1112179ac00b5c92532ff3323d2afe1f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.403ab88692b8d32cf320c7e1e7d832f1.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.53057145c0d6551820901b8449e853db.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.647efed7d642dec2e35baf8553e16372.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.88de7f7bbd360b954441956c1738b317.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.af54cebc77c324bb45539f07a2f61491.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC2_DATE2_068_png_jpg.rf.d73859903bef80c16f04fd3dda441b58.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.23c87aabd266349b68cf6461329ce434.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.387163d55c7777868aaff786ec884647.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.5f55419bc9817b5bbb58ad79c5d188b3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.81423e09881d2fed27769a00a633dfc8.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.aad69cd95555d50e58ca993ea0b12fa6.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.b97776e09af052231a05c7a71a7fbfbc.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC3_DATE1_004_png_jpg.rf.d6e4ab994271aea8f663602e97efd0d6.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.0738ab0015664976c021d224c618ad48.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.24dfd6993021a86844c9fce0d72d0d60.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.69e0b2fc0e31131f0666d327977449b0.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.b271371216dd774b2d98e0f630ccc4e0.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.b68a9b16e0d0668949651536500503c3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.cdda22eacc98f79d44a6cb75fd8baa78.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC5_DATE2_086_png_jpg.rf.e8135d51b79c24cf1e68ff7c3215ef85.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.2a03f44032d9f674262c000eb908ac3a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.48b1f87ba38af46311863e845d6b51d9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.7209d97d773951a65a20dad8595fd0ab.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.8a5e549ca8c9a5e2b461de95b2e024d1.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.d6dc0cb1f914a29df670074daa87992f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.f0fc7fbfbca0abb6b2bfd9a767adf054.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/B_LOC6_DATE2_094_png_jpg.rf.fcb2e03a3b52d6201550ebfa9f70edac.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.0af1ec3c68f55578c090054a4c313d5d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.7dbf6fb96ae3ee708389892042b2377d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.9b5b4be6de1da8d6bd85d6aaf9cd4bd1.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.a01b4bdce2edbd73b33d4d4631dcd144.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.eb5dd359e7226a8c5bc8cb16d7da1cc3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.f58948f2ae59993f57d537e6813d0c8b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC1_DATE2_051_png_jpg.rf.fae96d05484865a28a6cfabf1910c57b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC2_DATE1_005_png_jpg.rf.39de738d4ffa50520b5bbc1d74727613.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC2_DATE1_005_png_jpg.rf.5a941a90931fc5d94131f167c6255d36.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC2_DATE1_005_png_jpg.rf.bf28755553f7554d5690291645417c69.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC2_DATE1_005_png_jpg.rf.f2352227c9032ede4365d3bbcbec2940.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.0d191ee875b9b2a96ee95372b001fa6e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.41364c3f4cae333f328ffcafc1e6045a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.484f7f54377d07f2c2f865e7e7f57f29.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.74af533390c0e4c7899e033d4a91b206.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.7ea566c4bd40cab35093f3c6e96e7e19.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.d86f97d04e6e2e06d01d1da1bcd1e417.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC3_DATE1_005_png_jpg.rf.e89c51f8800f6c281503ea674b50b6c5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.04fd74c2876187156bbc83fade1e45f9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.870a0837dd69eab28ee51a854cf6b062.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.9353c1e07faa246ee48c48a16cb574a7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.9cf3aab7a27ebfa6bec42c454326245a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.df6534ce000732fa3393ed582e1733a6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.f92e0624dd4fdd0df9b066b728bfea48.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC5_DATE1_005_png_jpg.rf.fda8ef9a38d87b7b1ad7fcdf2ea1c70c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.7547861367522129f4696a604dbe9838.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.7d9cb232b9b67b41c61105550469ea19.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.8adfa272b745a11e23f6ac41cfa8f6d4.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.9ac04397e5af3e327dc07dac00ce3d0a.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.b74f281074590edd6b91e4aa13c3b1c3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.d44e5f846918e4e4f9d105afe09ffb7b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC6_DATE2_092_png_jpg.rf.f2e418c4282e93da685016e826d166a6.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.0d502a1aedac6ea7e91572607af13d53.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.0ed1b7f7f2e7d548d639c2244c795721.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.3a840cf1eabda3c2e2d9fb8fdbe35372.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.6f3a710c27c9eecee71c70984342d282.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.7e5782ebc727a70bb6383c2ff746e971.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.88499e015b1f1d9d8c28f9d41a8f99b3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC7_DATE2_100_png_jpg.rf.d6a3a93c595432059a9ef40d0224a7c4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.04fec93bda3249de6becb33b05236834.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.08d3f5072594593c0e436906890af7a9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.12552e7f90a64e4a582ba730c6d8c9a6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.23215533470afdd32ee2e10cd78f36d5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.7135de4943a516142b9c72fd66e5e638.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.75061abde60d002189f3f66978dd5e36.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC8_DATE1_029_png_jpg.rf.f7fd51f9dff023995e414fd7369317b0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.0778cb0dfcf072c34fa0d284de88428f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.3332395846b4f7d3aeaac57d8c993fc9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.6f350a96357718a8b3a860552694afb7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.6fdf8c0a803b306eea22c0c78c09a44b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.a569a4b5050c579a330dcc121cf21f12.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.ad09931fb0825791f019664b6ffaf2a6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/DB_LOC9_DATE1_037_png_jpg.rf.d186884cfa44e9140ade48efb6ab1e1b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.02eeb79679d753be00c8acf3efb36c12.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.05ba86e2a93c6f8ede8aec2f928e88c0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.5641c0e5f9adac291db033da4c92a87d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.8d992b69d6e6f996a39637a3448ff4cb.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.8ec7681fe3804615da4ebaa543de1646.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.d02fdcd26c48f36045545c29c2b0e899.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC1_DATE2_055_png_jpg.rf.d7a87c69bddbd7a9dc6787f83b1b1af7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.0fce9bd3b35b60e149b5f8cc53a82c97.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.1a10156dd2554ec76288d3135d54f83d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.2647035921c345b0e48673f81e35f699.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.4e0273ac6cdfd950244ce67125ed1ac3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.8598dd1d5298fcdd1cbbc67a16d44fc1.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.8d4e1f750e089efd73b0672470d1659c.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.c73ae1afc0ec3bcdd4ffda4fb20dfcac.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.764e36a86488e33a7eb4bd94246362bc.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.aba5c0abb599087138f162137cf60162.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.af221b51d1c7a1e457e9ebd2aa3a343b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.b1269ceb1472f7b02af2f9d1a4e9787b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.c92f5b9a54cfa4e4ea36a51e3b9519ef.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.c95e28871037f38dad9dbaf692bd5de7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.f0b7c827a2448bbd8bbc40f53d8fbb5e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.0aaf0b282eac89e9588829121214a6ea.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.1fd566adb17dfd6be09aecfc2326d502.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.2dbf4d31feceef5fe58cf2b757e3274c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.4755aed104876594a8725b2026ff0c73.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.7982bb5997a9b99955648754e605ef7c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.879d4c35d978b4277e88ec5ff54189ec.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.a82b04582852e793b9415b5132531734.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.257e0b434cab4e46707d0d5a1eeaa224.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.44ecbdb90779b5b8dfbdb8b2b01eff32.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.5940ab3a0d8f5a7ade698cfd71091263.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.5a89a07ecbdc8e4a257b89ef9b0c76aa.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.75b5ed449e9cbcf686d66bb82092442a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.838474b6a03a2fe127841c77014b3aa0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.9965af7c9090d7194b8d5d6ba9bb06b0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.b975c359ca58fd0442100047192db2e0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.c6a395db599966076f4d3e38f7b2d0d4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.d125ed6a8da2310d11fa35b0f277a452.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.dbaa526a175622b6f2b747434d3aad1f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.e20842e29ff6d599af28ab2e509413ae.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.e25eca490b5cfb56b6394a0204161b61.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.f84fc60f2d3816746918b5a2303e83d2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE7_218_jpg.rf.4f319f51296eb981f7e6b44f51eeaa18.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC6_DATE7_218_jpg.rf.8992158a54e4a557bd56e983ea3395cd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.111d139f08b90863e785ad3695273c28.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.5745adc2abb1572d4865fa302cf0ad15.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.abfdfaca42467bad1439e890e5ba270f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.c100645fde8f83fbd639ec1ed2d60ea7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.c542df35f689b38e31879ddc9e98d043.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.c6575dd688cf00b9ab40edd486f153d2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.dfc897d28d72822ecf01c61cfbb4d74c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.0bcc2a796e081a696a18178d9a83f543.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.66df798b34670ab74de4cbbba0d22c85.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.671f09d5010369a705c82216be466090.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.8f25906b0740bf2cb5eda527a00ccf68.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.9e2f50adb9c9550b899e3691134d8aae.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.cd01c7acd9a73b04c6acf53dbc62617e.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.f5e9aeba15ab75eebc4cddac675dcd8f.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.0778ae6dc184d8385c3e362863050a18.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.1f721e66bd46fca00fcc7d203b64ee70.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.27ff9c69ef94bc34352ebc0557dcca5f.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.4b15baddb2003c86cfb98db17e9d2fe3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.68789b5574b7e45d47a3c8da1e5d24dd.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.7ae7cfda73bee95b2c73cb343a02cb32.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC1_DATE2_050_png_jpg.rf.ffd6520e08395c229a316f48b606a5a0.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.10095cedf3318251c041bba2cb34cf27.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.11134b33038c2108a307d50aafc512aa.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.2a1261fc4128fa39c4da1fce8970c9cc.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.7b61489a0c2a9911c64f5b05f67a3a02.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.aceba837bdd7bc4a2309bb2977ffaba1.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.c29409048755e925430d82db488b3795.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.c79f8ca9dea59df5623de118bfebf59d.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.20b52e576dfa45835670777471f721cd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.24f6b23d913cdbfb9a8b8bba92fd87da.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.9adb7874cfc4d7cc72c335a660f7ae85.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.a0620de0a7346e52ab4cf02136838930.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.b0c2ed72f2d365ad21db0f124b1d7150.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.ba221383feef9b8c32619b23b6f44f54.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVG_LOC6_DATE2_091_png_jpg.rf.ee588c1ca767f2f5b72d7866c1385a14.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.0b3fe3ac795a78ab7d1bdb438a5c8b56.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.5b496eacd9019b44296435762d8ef8c6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.677f17b0d942440fff7e7c8bdbafa467.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.b4b20b5ec6e056600fcc528a34ca7e91.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.c5c2f08f19ed95e2ad1c25ee9227c285.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.e0ed65136028385b7fa99d742ab20241.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC10_DATE1_041_png_jpg.rf.ec0d36a38357648575f2f062b67830a7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.0133ae05333d298a22efd9b5f706e838.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.2811bdf414d8cc131ae8caa65094d63b.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.3c7b029c3dae5f5ac5128f3b68a22ea8.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.409e8021294547cf99d71e87641a5050.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.412922520ed1fdf74a4f6289c50e2557.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.75bfa82899983c80e3e1f6e1b144d091.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.d817d87e6e0acf2ea24ee84da42b456a.jpg: 4 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.127d7be96671073f04eef5c8abef8c9f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.4fc99a76a1a598957a0900668c68af97.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.5711dcfc2cf3ab00641ca2f28a34077e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.65d523ff90582638e03c0140ad53c51b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.a9e084643ac15f13c136b615224ccbc9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.bce36779103f093bc1fe51106d35421e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.c29f09144a5b0692c2af7713efa38a9b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.00bbf8c018f5e59b5acb5747f50ee0cb.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.04fc48586480eac17b4442eee2cc8539.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.18e026459c667c994b7b7694d8e81bd7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.1cd0a7d72dc6a40a197e78aec9e8cbf9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.238dc2458cc6844673308dbb10a23ed2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.494b57b34fd3aac9b50166e69ae5a0bc.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC2_DATE2_060_png_jpg.rf.ccfc8cc9f16046a2b4951e0939f66376.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.2e541f5bd98fbef3247790a268c28719.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.319e7b88b55b9d3cac03ea7fdc17a897.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.3b37d9d5509a274748008b368f79a93b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.4aca870e33eff38c4f515e3a481045b7.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.7caecaa3f2fd0bf72c86a8c79668aa86.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.7db1c9e31bc4ffa142b16da9805298c7.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.9649511de3e4f222ab8ce5755e6d91db.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.274e4b8885928c668bf13b57955f1ffe.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.4346483bc603f7b4dbefead5b47ccbe9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.50efc5d618aaa4464113da6512540385.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.58bd9eebabeb75ab286708171123c930.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.6960841ad5738f624386835484e62b73.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.d5ff448ef5c263f5f09654505bcb6a66.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.fe07ccfa676825d1d7daec22b43841cd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.074a4b1cedb9e925d3183446430e88de.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.1b4ce26d2827cbaefe5642a81be210fa.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.3d7f4a781b04fca27981bf8e816781d6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.4502eef44bb8b834df0c6ddcafbb2f41.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.451e28c13fea813946c880880f5a1ee9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.65cf439c3b2a35ee3e83cf85a1e70b30.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.6dfb526a195a06b239105c92ac06ff3b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.0da1486de4d9bf6bc08b62f63317e0f2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.2927b74b887084253ca4e6b05e745f9d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.4db8f91440abb88d1fbca6d494a01342.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.630adc8fbc8868dba540ef0b89afc0c0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.94ffaa1ac58fd5d513c7115c4f8c9bff.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.afb01cf5736c31f6a3b2b7dee21b0f46.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVO_LOC9_DATE2_117_png_jpg.rf.e0c8ed484d75a63cb8b91f60eece1eab.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.14cf6415ea7acc254f73c36677996285.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.1e8ab63aff3b7f1de31312a57324b74d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.34a1b33817b1b54d752fa660f0035fff.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.46cd260954af12770fdf0c8913edf243.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.77bea52bad68d23ec021c5dc3ed35d6e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.b919f656ce1a3ec7854f35ff6dbf8b80.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE1_049_png_jpg.rf.f98bd96fecce31ff1ead1b6ca539db63.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.2197d01c28d02061917f787d25ffcf56.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.2d67cb85fd14bfe5195bb5bbfa5812fd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.31ec015abdae69dfd985d5fb81d44840.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.34ccb6465a0087aa4e6691410c27e144.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.584493ec31533821d49125c7784aa5c8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.62086610490a85e9e72f44d97d5649b5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.a0fb5cedc5dc7a9312574620d528c0c3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.1c9e13ea2f37b8d460f33e00089bb347.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.35ad62cb1fd286231869f8a0ce1ae885.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.47442434e9246ef4d7c3c8513a6f0da2.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.5c725e72c31edba0210678ac1abea9a9.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.6ec6e876e0de0fa3cc2f1ceb307ad7ea.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.6ef1e7c0aa0a78a77ff3aeabcf3cf2e3.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC2_DATE2_064_png_jpg.rf.8ac51a54cfd3a678d2da864d75703f72.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.19ecde7b9fa1de9928e3ebd2b58c1ac3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.3020afe9bda94b04fe5a3cd9829cab6e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.3265e813ffd5b93dd0190be7088aacd9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.46307586898f422c7af156cb4b28ca60.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.61c83a8d5fc90d073db735c0a18acd1f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.981f3422537549c7446e2ec14c693c6a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.dfe6314d225d47b3160831351d16ae8b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE1_024_png_jpg.rf.cee130a655f191c8e774e643a2d6499b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.3b84a572bb795c0e259930d6fe13ce26.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.5b5e889a0386304162cc0a2b76c2ec3b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.9008aaf1db3fd590b36efe48e32595f7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.9d05d90d22893ebb3dba80857faf9ae0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.b13231e8771d4c0e6f6007cf0dd7404c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.c67836fdb04c6dbc18d506dc773a7a3a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.eb34dc3f5704639a17154f778284ddb6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.135654721fa5a846bee4e748499ce33d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.6ba1dd3a79578ade1cfbb8f36f98bc17.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.7aa1e4696d55ad0f45eee8fb73e1eaac.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.8af0c67a5fa59f42c47dbdace99160ca.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.9289130c60515d86636db34ca9c9512e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.df1cb9b6dbc46c888e4bd629ddbdff82.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.f73106a26d275baf31b4db6031db4524.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.136af2d5eede58f6a17282602e3ef91d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.19d5f5dcc3672b9188443385b56653a9.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.350d77057788d76ae467377ce5951ac8.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.b944b70aa51b3046b3162e7fa45fcae0.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.be4a66b98c58f912602e6c56a2b23f67.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.f2eb8b1ae27136adacc0f7f34ce5e75d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.fa6b4ad5839c1c9a9e01d8948d885197.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.16514d5960290b05534c424d1f205998.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.353bab0f97433d6ae03d1148ce6fe8fb.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.4043caab91c260d71b010c84dbd6a253.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.5a36b376ecc6f35f1d565556a26583b0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.77543edb01455813e0de83b726a78d5a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.819aace5092646d4c2857ead42d01d35.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC3_DATE1_007_png_jpg.rf.dc4179c3a1e37d5b2593574ec631992d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.07d731337d8dd68f0ab81e49a9e57824.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.481876b6b8099f377a236f240dca1856.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.56cf8a4753cce42b6d2ef63294e8b4a1.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.86225a2290955b797a3030e317bc2f4b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.a94473519188ade0bf924f5cfd054f10.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.c1bc9a1b360ff02ef47380d2296123c8.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugM1-4/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.cf894354478b3787711c52101d936062.jpg: 2 duplicate labels removed
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.53it/s]
#                    all        124      10319      0.755      0.705      0.752      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      26.9G      1.559     0.9745      1.138        107       3200: 100% 1519/1519 [06:52<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.48it/s]
#                    all        124      10319       0.77      0.725      0.766      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50        28G      1.547     0.9677      1.139        162       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.54it/s]
#                    all        124      10319      0.802      0.698      0.759       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      38.1G      1.546      0.955      1.138        398       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.51it/s]
#                    all        124      10319       0.79      0.717      0.767      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      26.8G      1.536     0.9402       1.13        257       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.45it/s]
#                    all        124      10319      0.793      0.712      0.769      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      35.7G      1.533     0.9309       1.13        222       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.53it/s]
#                    all        124      10319      0.805      0.706      0.768      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      36.4G       1.52     0.9153      1.123         83       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.63it/s]
#                    all        124      10319      0.772      0.729      0.765      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      36.9G      1.524     0.9128      1.123        379       3200: 100% 1519/1519 [06:52<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.48it/s]
#                    all        124      10319      0.804      0.725      0.779      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      35.4G      1.518      0.904      1.119        246       3200: 100% 1519/1519 [06:53<00:00,  3.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.57it/s]
#                    all        124      10319      0.795      0.733      0.777      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      32.3G      1.508     0.8835      1.117        303       3200: 100% 1519/1519 [06:52<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.49it/s]
#                    all        124      10319      0.794      0.721      0.773      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      38.6G      1.504     0.8839      1.118        174       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.47it/s]
#                    all        124      10319      0.805      0.725      0.779      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      33.1G      1.504     0.8751      1.114        223       3200: 100% 1519/1519 [06:52<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.56it/s]
#                    all        124      10319      0.792       0.73      0.779      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      36.7G      1.491     0.8569      1.109        212       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.61it/s]
#                    all        124      10319      0.797      0.727      0.774       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      26.9G      1.494     0.8514      1.112         86       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.58it/s]
#                    all        124      10319      0.805      0.731      0.776      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      37.3G      1.491     0.8406      1.108        237       3200: 100% 1519/1519 [06:52<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.60it/s]
#                    all        124      10319      0.799      0.731      0.775      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      38.6G      1.474     0.8287      1.101        121       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.58it/s]
#                    all        124      10319      0.816      0.707      0.774       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50        35G      1.481     0.8274      1.104        261       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.66it/s]
#                    all        124      10319      0.806      0.727      0.781      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      37.3G      1.468     0.8089      1.098        155       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.58it/s]
#                    all        124      10319      0.809      0.719      0.777      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      30.8G      1.463      0.805      1.094        371       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.60it/s]
#                    all        124      10319      0.804      0.726      0.775       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      37.5G      1.467     0.8039        1.1        160       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.59it/s]
#                    all        124      10319      0.805      0.723      0.772      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      26.9G      1.452     0.7897      1.091        336       3200: 100% 1519/1519 [06:51<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.62it/s]
#                    all        124      10319      0.793      0.723      0.773      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      33.4G      1.452     0.7801       1.09         86       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.63it/s]
#                    all        124      10319      0.789      0.726      0.772       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      27.4G      1.441     0.7702      1.085        317       3200: 100% 1519/1519 [06:52<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.68it/s]
#                    all        124      10319      0.799      0.724      0.775      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      30.1G      1.439     0.7624      1.085        157       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.67it/s]
#                    all        124      10319      0.802      0.723      0.771      0.474
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50        28G       1.41     0.7411      1.084        152       3200: 100% 1519/1519 [06:39<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.59it/s]
#                    all        124      10319      0.803      0.719      0.768      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      28.2G      1.402     0.7233      1.083         33       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.69it/s]
#                    all        124      10319      0.797      0.715      0.767      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      26.5G      1.387     0.7093      1.076         89       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.67it/s]
#                    all        124      10319      0.794      0.729       0.77      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      27.1G      1.389     0.7099      1.071         63       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.67it/s]
#                    all        124      10319      0.793      0.723       0.77       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      27.3G      1.376     0.6918      1.068        191       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.68it/s]
#                    all        124      10319      0.813      0.707      0.768      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      26.8G      1.375     0.6892       1.07         45       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.74it/s]
#                    all        124      10319      0.796      0.722      0.767      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      26.6G      1.359      0.674      1.061         66       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.69it/s]
#                    all        124      10319      0.777      0.731      0.766      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50        27G      1.359     0.6689      1.065        116       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.74it/s]
#                    all        124      10319      0.798       0.72      0.769      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      27.3G      1.354     0.6641       1.06        198       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.75it/s]
#                    all        124      10319      0.795      0.717      0.767      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      26.7G      1.348     0.6596       1.06         50       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.72it/s]
#                    all        124      10319      0.809      0.706      0.765      0.464
#
# 50 epochs completed in 5.763 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 20.1MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 20.1MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,417,444 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:10<00:00,  3.02it/s]
#                    all        124      10319        0.8      0.733      0.776      0.476
#              Arachnida         79        187      0.752      0.615      0.719      0.461
#             Coleoptera         88        273       0.74      0.708      0.754      0.478
#     Diptera_Brachycera        124       4817      0.893       0.86      0.915      0.578
#     Diptera_Nematocera        123       2202      0.781      0.721      0.773      0.405
#      Diptera_Syrphidae         41        225      0.862       0.88      0.892       0.71
# Hemiptera_Aphidomorpha         87        296      0.749      0.649      0.715      0.404
#  Hemiptera_Heteroptera         64        184      0.692      0.674      0.669      0.404
# Hemiptera_Membracoidea         77        408      0.835      0.814      0.828      0.445
#   Hymenoptera_Apocrita        119       1113      0.753      0.577      0.685      0.421
# Hymenoptera_Formicidae         17        413      0.843       0.85       0.81      0.498
#            Lepidotpera         47         99      0.894      0.808      0.866      0.572
#               Psocodea         57        102      0.804      0.645      0.689      0.342
# Speed: 2.4ms preprocess, 17.2ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `{HOME}/runs/detect/train/`. Let's examine them.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml			 R_curve.png	       train_batch60762.jpg
# confusion_matrix_normalized.png  results.csv	       val_batch0_labels.jpg
# confusion_matrix.png		 results.png	       val_batch0_pred.jpg
# F1_curve.png			 train_batch0.jpg      val_batch1_labels.jpg
# labels_correlogram.jpg		 train_batch1.jpg      val_batch1_pred.jpg
# labels.jpg			 train_batch2.jpg      val_batch2_labels.jpg
# P_curve.png			 train_batch60760.jpg  val_batch2_pred.jpg
# PR_curve.png			 train_batch60761.jpg  weights

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=1000)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=1000)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=1000)

# %% [markdown]
# ## Validate fine-tuned model

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,417,444 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3109.3±652.4 MB/s, size: 145.8 KB)
# val: Scanning /content/datasets/ScanBugM1-4/valid/labels.cache... 124 images, 0 backgrounds, 0 corrupt: 100% 124/124 [00:00<?, ?it/s]
# val: /content/datasets/ScanBugM1-4/valid/images/DB_LOC10_DATE1_045_png_jpg.rf.15272d51caa63c80de9fd4a144a9b4b1.jpg: 2 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/DB_LOC2_DATE2_059_png_jpg.rf.1b6764059742ee6bb23d5c00a0e004af.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/DB_LOC7_DATE1_021_png_jpg.rf.51103ccd6bae81ece41adc2315414ab3.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVB_LOC6_DATE2_096_png_jpg.rf.8a58a306b33ad388255ec6816230a7aa.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVG_LOC3_DATE1_006_png_jpg.rf.369de675e78839f9c6cfc245cc59a14e.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVG_LOC7_DATE1_022_png_jpg.rf.8e6000386e48d7fe344ba87cf6b49359.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVG_LOC8_DATE1_030_png_jpg.rf.17fd22eee9192e1b3c35d5465eb4933a.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVG_LOC9_DATE2_115_png_jpg.rf.25ca856ce5002ce2e933f8ccf370bf16.jpg: 2 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVR_LOC5_DATE1_008_png_jpg.rf.36229d76ed70cbeac85cd31278103a16.jpg: 4 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVR_LOC5_DATE2_089_png_jpg.rf.0326f6075abd419302419499f517ced2.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVR_LOC8_DATE1_032_png_jpg.rf.6cbb7cfd0d5aad73a7cf071bb68a4542.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVY_LOC10_DATE1_048_png_jpg.rf.cdbf6d86ad7485e15032d8e6c6e8c753.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/UVY_LOC2_DATE1_007_png_jpg.rf.3b68f4e7c91bc1b6d6d7b0104783b0ac.jpg: 3 duplicate labels removed
# val: /content/datasets/ScanBugM1-4/valid/images/W_LOC1_DATE2_057_png_jpg.rf.2d0dc1eb42f39d1f39b5507876707856.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  12% 1/8 [00:05<00:38,  5.43s/it]
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 981, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 630, in val
#     validator(model=self.model)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/validator.py", line 214, in __call__
#     preds = model(batch["img"], augment=augment)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/autobackend.py", line 592, in forward
#     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 115, in forward
#     return self.predict(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 133, in predict
#     return self._predict_once(x, profile, visualize, embed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 154, in _predict_once
#     x = m(x)  # run
#         ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py", line 1495, in forward
#     b = self.m(b)
#         ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py", line 250, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py", line 1378, in forward
#     x = x + self.attn(x) if self.add else self.attn(x)
#             ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py", line 1323, in forward
#     attn = (q.transpose(-2, -1) @ k) * self.scale
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 13.32 GiB. GPU 0 has a total capacity of 39.56 GiB of which 6.86 GiB is free. Process 1589780 has 32.67 GiB memory in use. Of the allocated memory 19.09 GiB is allocated by PyTorch, and 13.07 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ## Inference with custom model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv11 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv11 weights.

# %%
project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{HOME}/runs/detect/train/")

# %%
# !pip install inference
# Out:
# Collecting inference
#   Downloading inference-0.49.1-py3-none-any.whl.metadata (24 kB)
# Collecting aiortc~=1.9.0 (from inference)
#   Downloading aiortc-1.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting APScheduler<4.0.0,>=3.10.1 (from inference)
#   Downloading APScheduler-3.11.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting asyncua~=1.1.5 (from inference)
#   Downloading asyncua-1.1.6-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: cachetools<6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (5.5.2)
# Requirement already satisfied: cython~=3.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (3.0.12)
# Collecting python-dotenv~=1.0.0 (from inference)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting fastapi<0.111,>=0.100 (from inference)
#   Downloading fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (2.0.2)
# Collecting opencv-python<=4.10.0.84,>=4.8.1.78 (from inference)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opencv-contrib-python<=4.10.0.84,>=4.8.1.78 (from inference)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow<12.0,>=11.0 in /usr/local/lib/python3.11/dist-packages (from inference) (11.2.1)
# Collecting prometheus-fastapi-instrumentator<=6.0.0 (from inference)
#   Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl.metadata (13 kB)
# Collecting redis~=5.0.0 (from inference)
#   Downloading redis-5.0.8-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.11/dist-packages (from inference) (2.32.3)
# Requirement already satisfied: rich<13.10.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (13.9.4)
# Requirement already satisfied: supervision<=0.30.0,>=0.25.1 in /usr/local/lib/python3.11/dist-packages (from inference) (0.25.1)
# Collecting pybase64~=1.0.0 (from inference)
#   Downloading pybase64-1.0.2.tar.gz (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 9.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-image<=0.25.2,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from inference) (0.25.2)
# Requirement already satisfied: requests-toolbelt~=1.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (1.0.0)
# Requirement already satisfied: wheel<=0.45.1,>=0.38.1 in /usr/local/lib/python3.11/dist-packages (from inference) (0.45.1)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (75.2.0)
# Requirement already satisfied: networkx<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (3.4.2)
# Requirement already satisfied: pydantic<2.12.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from inference) (2.11.4)
# Collecting pydantic-settings<2.8 (from inference)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: openai<2.0.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from inference) (1.77.0)
# Collecting structlog<25.0.0,>=24.1.0 (from inference)
#   Downloading structlog-24.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting zxing-cpp~=2.2.0 (from inference)
#   Downloading zxing_cpp-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting boto3<=1.35.60 (from inference)
#   Downloading boto3-1.35.60-py3-none-any.whl.metadata (6.7 kB)
# Collecting typing_extensions<=4.12.2,>=4.8.0 (from inference)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pydot~=2.0.0 (from inference)
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting shapely<2.1.0,>=2.0.4 (from inference)
#   Downloading shapely-2.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting tldextract~=5.1.2 (from inference)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from inference) (24.2)
# Collecting anthropic~=0.49.0 (from inference)
#   Downloading anthropic-0.49.0-py3-none-any.whl.metadata (24 kB)
# Collecting pandas<3.0.0,>=2.2.3 (from inference)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.8 MB/s eta 0:00:00
# Collecting paho-mqtt~=1.6.1 (from inference)
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (8.3.5)
# Requirement already satisfied: tokenizers<0.22.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from inference) (0.21.1)
# Collecting slack-sdk~=3.33.4 (from inference)
#   Downloading slack_sdk-3.33.5-py2.py3-none-any.whl.metadata (15 kB)
# Collecting twilio~=9.3.7 (from inference)
#   Downloading twilio-9.3.8-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: httpx~=0.28.1 in /usr/local/lib/python3.11/dist-packages (from inference) (0.28.1)
# Collecting pylogix==1.0.5 (from inference)
#   Downloading pylogix-1.0.5-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting pymodbus<=3.8.3,>=3.6.9 (from inference)
#   Downloading pymodbus-3.8.3-py3-none-any.whl.metadata (15 kB)
# Collecting backoff~=2.2.0 (from inference)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting filelock<=3.17.0,>=3.12.0 (from inference)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting onnxruntime<1.22.0,>=1.15.1 (from inference)
#   Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: nvidia-ml-py<13.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (12.575.51)
# Collecting docker<8.0.0,>=7.0.0 (from inference)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting typer<=0.12.5,>=0.9.0 (from inference)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML~=6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (6.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (4.67.1)
# Requirement already satisfied: py-cpuinfo~=9.0.0 in /usr/local/lib/python3.11/dist-packages (from inference) (9.0.0)
# Collecting aiohttp<=3.10.11,>=3.9.0 (from inference)
#   Downloading aiohttp-3.10.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting rich<13.10.0,>=13.0.0 (from inference)
#   Downloading rich-13.0.1-py3-none-any.whl.metadata (18 kB)
# Collecting dataclasses-json~=0.6.0 (from inference)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.20.0)
# Collecting aioice<1.0.0,>=0.9.0 (from aiortc~=1.9.0->inference)
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<13.0.0,>=9.0.0 (from aiortc~=1.9.0->inference)
#   Downloading av-12.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (1.17.1)
# Requirement already satisfied: cryptography>=42.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (43.0.3)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (1.7.1)
# Collecting pyee>=9.0.0 (from aiortc~=1.9.0->inference)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc~=1.9.0->inference)
#   Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pyopenssl>=24.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference) (24.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference) (1.3.1)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.11/dist-packages (from APScheduler<4.0.0,>=3.10.1->inference) (5.3.1)
# Collecting aiofiles (from asyncua~=1.1.5->inference)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiosqlite (from asyncua~=1.1.5->inference)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference) (2.9.0.post0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference) (2025.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference) (2.4.0)
# Collecting wait-for2==0.3.2 (from asyncua~=1.1.5->inference)
#   Downloading wait_for2-0.3.2.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting botocore<1.36.0,>=1.35.60 (from boto3<=1.35.60->inference)
#   Downloading botocore-1.35.99-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<=1.35.60->inference)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<=1.35.60->inference)
#   Downloading s3transfer-0.10.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json~=0.6.0->inference)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json~=0.6.0->inference)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8.0.0,>=7.0.0->inference) (2.4.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<0.111,>=0.100->inference)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx~=0.28.1->inference) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx~=0.28.1->inference) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx~=0.28.1->inference) (3.7)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx~=0.28.1->inference) (0.16.0)
# Collecting coloredlogs (from onnxruntime<1.22.0,>=1.15.1->inference)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (1.13.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.3->inference) (2025.2)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.21.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12.0,>=2.8.0->inference) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12.0,>=2.8.0->inference) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12.0,>=2.8.0->inference) (0.4.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.11/dist-packages (from pydot~=2.0.0->inference) (3.2.3)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest<9.0.0,>=8.0.0->inference) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.0->inference) (3.4.2)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich<13.10.0,>=13.0.0->inference)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from rich<13.10.0,>=13.0.0->inference) (2.19.1)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (1.15.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (0.4)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference) (1.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference) (3.10.0)
# Collecting requests-file>=1.4 (from tldextract~=5.1.2->inference)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers<0.22.0,>=0.19.0->inference) (0.31.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from twilio~=9.3.7->inference) (2.10.1)
# Collecting aiohttp-retry==2.8.3 (from twilio~=9.3.7->inference)
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<=0.12.5,>=0.9.0->inference) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<=0.12.5,>=0.9.0->inference) (1.5.4)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.0->aiortc~=1.9.0->inference) (2.22)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.22.0,>=0.19.0->inference) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.22.0,>=0.19.0->inference) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference) (1.4.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->asyncua~=1.1.5->inference) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<=3.10.11,>=3.9.0->inference) (0.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<1.22.0,>=1.15.1->inference)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime<1.22.0,>=1.15.1->inference) (1.3.0)
# Downloading inference-0.49.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.0 MB/s eta 0:00:00
# Downloading pylogix-1.0.5-py2.py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 8.6 MB/s eta 0:00:00
# Downloading aiohttp-3.10.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.9 MB/s eta 0:00:00
# Downloading aiortc-1.9.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 89.5 MB/s eta 0:00:00
# Downloading anthropic-0.49.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 25.2 MB/s eta 0:00:00
# Downloading APScheduler-3.11.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 6.7 MB/s eta 0:00:00
# Downloading asyncua-1.1.6-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.8 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading boto3-1.35.60-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 13.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 16.0 MB/s eta 0:00:00
# Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 9.8 MB/s eta 0:00:00
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading onnxruntime-1.21.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 95.7 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 35.6 MB/s eta 0:00:00
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 38.9 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 119.6 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-6.0.0-py3-none-any.whl (18 kB)
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Downloading pymodbus-3.8.3-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.7/160.7 kB 16.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading redis-5.0.8-py3-none-any.whl (255 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.6/255.6 kB 25.3 MB/s eta 0:00:00
# Downloading rich-13.0.1-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 kB 22.6 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 101.2 MB/s eta 0:00:00
# Downloading slack_sdk-3.33.5-py2.py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.3/292.3 kB 26.5 MB/s eta 0:00:00
# Downloading structlog-24.4.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 7.2 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 11.7 MB/s eta 0:00:00
# Downloading twilio-9.3.8-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.3 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 4.8 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading zxing_cpp-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (941 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 941.4/941.4 kB 67.3 MB/s eta 0:00:00
# Downloading aioice-0.10.1-py3-none-any.whl (24 kB)
# Downloading av-12.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 65.3 MB/s eta 0:00:00
# Downloading botocore-1.35.99-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 128.9 MB/s eta 0:00:00
# Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 4.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.5 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 82.6 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 9.4 MB/s eta 0:00:00
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.6 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 29.7 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.0 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: wait-for2, paho-mqtt, pybase64
#   Building wheel for wait-for2 (setup.py) ... done
#   Created wheel for wait-for2: filename=wait_for2-0.3.2-py3-none-any.whl size=10491 sha256=f1ab7fdb68d75ddf00715c535eb51b0ce18903fe4c9c28081616cb0c30f58abe
#   Stored in directory: /root/.cache/pip/wheels/ac/cb/01/822df6dee993980ee967de65e69427f5dee2362e85484632a4
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62116 sha256=5eb5937de38b52ed58a78f1e39cb30a3f6ffb4dcf5799154010a923cd9fb89fd
#   Stored in directory: /root/.cache/pip/wheels/29/ea/a5/ba9a63aaf4cd4e16e8a87ee31fb4d11b04ff5e1735d312619a
#   Building wheel for pybase64 (pyproject.toml) ... done
#   Created wheel for pybase64: filename=pybase64-1.0.2-cp311-cp311-linux_x86_64.whl size=146816 sha256=b97324e4cd2b1d804b7fab94664c82948868ee954e85832a67408204abf101fe
#   Stored in directory: /root/.cache/pip/wheels/3d/c0/15/5e79fe7fd3f97ebaf4c080e7c337fb06c1d01bc61905dcb26b
# Successfully built wait-for2 paho-mqtt pybase64
# Installing collected packages: wait-for2, pylogix, paho-mqtt, ifaddr, commonmark, zxing-cpp, typing_extensions, structlog, slack-sdk, shapely, rich, redis, python-dotenv, pymodbus, pydot, pybase64, opencv-python, opencv-contrib-python, mypy-extensions, marshmallow, jmespath, humanfriendly, filelock, dnspython, backoff, av, APScheduler, aiofiles, typing-inspect, typer, requests-file, pylibsrtp, pyee, pandas, docker, coloredlogs, botocore, aiosqlite, aioice, aiohttp, tldextract, starlette, s3transfer, onnxruntime, dataclasses-json, aiohttp-retry, twilio, pydantic-settings, fastapi, boto3, asyncua, anthropic, aiortc, prometheus-fastapi-instrumentator, inference
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.1.0
#     Uninstalling shapely-2.1.0:
#       Successfully uninstalled shapely-2.1.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.0
#     Uninstalling python-dotenv-1.1.0:
#       Successfully uninstalled python-dotenv-1.1.0
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.4
#     Uninstalling pydot-3.0.4:
#       Successfully uninstalled pydot-3.0.4
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.11.0.86
#     Uninstalling opencv-contrib-python-4.11.0.86:
#       Successfully uninstalled opencv-contrib-python-4.11.0.86
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.3
#     Uninstalling typer-0.15.3:
#       Successfully uninstalled typer-0.15.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# pymc 5.22.0 requires rich>=13.7.1, but you have rich 13.0.1 which is incompatible.
# Successfully installed APScheduler-3.11.0 aiofiles-24.1.0 aiohttp-3.10.11 aiohttp-retry-2.8.3 aioice-0.10.1 aiortc-1.9.0 aiosqlite-0.21.0 anthropic-0.49.0 asyncua-1.1.6 av-12.3.0 backoff-2.2.1 boto3-1.35.60 botocore-1.35.99 coloredlogs-15.0.1 commonmark-0.9.1 dataclasses-json-0.6.7 dnspython-2.7.0 docker-7.1.0 fastapi-0.110.3 filelock-3.17.0 humanfriendly-10.0 ifaddr-0.2.0 inference-0.49.1 jmespath-1.0.1 marshmallow-3.26.1 mypy-extensions-1.1.0 onnxruntime-1.21.1 opencv-contrib-python-4.10.0.84 opencv-python-4.10.0.84 paho-mqtt-1.6.1 pandas-2.2.3 prometheus-fastapi-instrumentator-6.0.0 pybase64-1.0.2 pydantic-settings-2.7.1 pydot-2.0.0 pyee-13.0.0 pylibsrtp-0.12.0 pylogix-1.0.5 pymodbus-3.8.3 python-dotenv-1.0.1 redis-5.0.8 requests-file-2.1.0 rich-13.0.1 s3transfer-0.10.4 shapely-2.0.7 slack-sdk-3.33.5 starlette-0.37.2 structlog-24.4.0 tldextract-5.1.3 twilio-9.3.8 typer-0.12.5 typing-inspect-0.9.0 typing_extensions-4.12.2 wait-for2-0.3.2 zxing-cpp-2.2.0

# %%
import os, random, cv2
import supervision as sv
import IPython
import inference

model_id = project.id.split("/")[1] + "/" + dataset.version
model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))

# Location of test set images
test_set_loc = dataset.location + "/test/images/"
test_images = os.listdir(test_set_loc)

# Run inference on 4 random test images, or fewer if fewer images are available
for img_name in random.sample(test_images, min(4, len(test_images))):
    print("Running inference on " + img_name)

    # Load image
    image = cv2.imread(os.path.join(test_set_loc, img_name))

    # Perform inference
    results = model.infer(image, confidence=0.4, overlap=30)[0]
    detections = sv.Detections.from_inference(results)

    # Annotate boxes and labels
    box_annotator = sv.BoxAnnotator()
    label_annotator = sv.LabelAnnotator()
    annotated_image = box_annotator.annotate(scene=image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    # Display annotated image
    _, ret = cv2.imencode('.jpg', annotated_image)
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)
# Out:
# ModelDependencyMissing: Your `inference` configuration does not support Qwen2.5-VL model. Use pip install 'inference[transformers]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[sam]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[sam]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[clip]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support Gaze Detection model. Use pip install 'inference[gaze]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support GroundingDINO model. Use pip install 'inference[grounding-dino]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support YoloWorld model. Use pip install 'inference[yolo-world]' to install missing requirements.
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-15-348da3c98227> in <cell line: 0>()
#       5
#       6 model_id = project.id.split("/")[1] + "/" + dataset.version
# ----> 7 model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))
#       8
#       9 # Location of test set images
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret ROBOFLOW_API_KEY timed out. Secrets can only be fetched when running from the Colab UI.

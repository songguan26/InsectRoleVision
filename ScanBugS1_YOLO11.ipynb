# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu May  8 14:16:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             44W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 41.4/235.7 GB disk)

# %% [markdown]
# ## Inference with model pre-trained on COCO dataset

# %% [markdown]
# ### CLI
#
# **NOTE:** CLI requires no customization or Python code. You can simply run all tasks from the terminal with the yolo command.

# %%
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 328MB/s]
# Ultralytics 8.3.89 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 123MB/s]
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 60.7ms
# Speed: 6.8ms preprocess, 60.7ms inference, 429.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Result annotated image got saved in `{HOME}/runs/detect/predict/`. Let's display it.

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/predict/dog.jpeg', width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bbd66cb91f54> in <cell line: 0>()
#       1 from IPython.display import Image as IPyImage
#       2
# ----> 3 IPyImage(filename=f'{HOME}/runs/detect/predict/dog.jpeg', width=600)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/predict/dog.jpeg'

# %% [markdown]
# ### SDK
#
# **NOTE:** YOLO's Python interface allows for seamless integration into your Python projects, making it easy to load, run, and process the model's output.

# %%
from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11n.pt')
image = Image.open(requests.get('https://media.roboflow.com/notebooks/examples/dog.jpeg', stream=True).raw)
result = model.predict(image, conf=0.25)[0]
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 366MB/s]
# 0: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 72.2ms
# Speed: 8.1ms preprocess, 72.2ms inference, 359.1ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# **NOTE:** The obtained `result` object stores information about the location, classes, and confidence levels of the detected objects.

# %%
result.boxes.xyxy

# %%
result.boxes.conf

# %%
result.boxes.cls

# %% [markdown]
# **NOTE:** YOLO11 can be easily integrated with `supervision` using the familiar `from_ultralytics` connector.

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

annotated_image = image.copy()
annotated_image = box_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))

# %% [markdown]
# ## Fine-tune YOLO11 on custom dataset

# %% [markdown]
# **NOTE:** When training YOLOv11, make sure your data is located in `datasets`. If you'd like to change the default location of the data you want to use for fine-tuning, you can do so through Ultralytics' `settings.json`. In this tutorial, we will use one of the [datasets](https://universe.roboflow.com/liangdianzhong/-qvdww) available on [Roboflow Universe](https://universe.roboflow.com/). When downloading, make sure to select the `yolov11` export format.

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
from roboflow import Roboflow
rf = Roboflow(api_key="q5dx0cWktqaKU3A8SD6P")

workspace = rf.workspace("computervisionlab")
project = workspace.project("scanbugs1v2")
version = project.version(9)
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# Downloading Dataset Version Zip in ScanBugS1v2-9 to yolov11:: 100%|██████████| 399044/399044 [00:23<00:00, 17092.01it/s]
# Extracting Dataset Version Zip to ScanBugS1v2-9 in yolov11:: 100%|██████████| 6458/6458 [00:01<00:00, 4491.15it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=50 imgsz=3200 batch=2 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt'...
# 100% 18.4M/18.4M [00:00<00:00, 306MB/s]
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=2, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/datasets/ScanBugS1v2-9/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=3200, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 75.9MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 389MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1629.6±927.5 MB/s, size: 120.8 KB)
# train: Scanning /content/datasets/ScanBugS1v2-9/train/labels... 3038 images, 0 backgrounds, 0 corrupt: 100% 3038/3038 [00:02<00:00, 1125.03it/s]
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.063919a81f2ab4a3487a6c84201095cc.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.0979f4464381d797c344a033c8600751.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.604c909d745bd5057488f752ffb40739.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.a99bc62916196d372c7dcd7508953677.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.ad4a5cbfab0006a8ea759dad557aced2.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.ecc166d5fc0b9673d93046e10b157d27.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC10_DATE2_126_png_jpg.rf.f6b2d3a78f5f74c9d2e47c858288735a.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.26a9a492ed014855f9d5a5b0e7312a7b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.3a2600155216b08e7ca13f018ae46dfd.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.40b99ca840a062a2439369c9fb5057c5.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.4edc58e339f86cdf87e9e5a6e3c11066.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.ed26c1ac4b46b104a842029ebae7c25b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.f37044d9b66ce148b14050a99c3b9e1b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC5_DATE2_086_png_jpg.rf.fb7450ab4dac80900d3aee7a85c692dd.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.0d3e430d302c4b70ac0a40779adabbbb.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.1c5e35aa70b3e5520defd1ba27bb4595.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.2e6d807cf1fa73482a4f7c9bd1233139.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.400ed8017823207fe78dfe692bde5426.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.cfa430b21b248c189ed536a55f05e580.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.de37895e724635c9e289b584887c2a89.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/B_LOC6_DATE2_094_png_jpg.rf.fa6daa8cab512c4df3079da966402fef.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.218851c57280d96352692cf07afc9dd0.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.497008b2e4c3013b6dbd67adc1d42a1a.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.aac99092304ba136dff01bee59a24ad7.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.b6677099f79b86df8fc54837cee9265c.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.de294c2b2f96a711209e0de8ff592c7a.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.e4fc9b75892e652c1798e284c12f26ec.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE1_045_png_jpg.rf.e53d171b69d0c884dc663951636b6a0a.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC10_DATE2_124_png_jpg.rf.e33a1a41541a961de782fb7137508738.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.178c057e333259e0de8944370ee27b5f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.199b1a6fb1fbcd7cf2b8f88378ef7cb6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.6060bc7cb671bc5eb95efa992d582c20.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.73eed6148b459907cc7a696c528b078e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.aa7810f5a58f3d8dfc4bdacd3a07ba08.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.b852f5befaeff0fbbfd95e91e611bd4d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC2_DATE2_059_png_jpg.rf.be6a9be2bb62aa96b6ead26c5ca087bf.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.2874e24b8f82b7615f5f2652451d1b10.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.3715f4f0314f8cf365d54ed38debdba6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.4ae6253c5be407d9e6cbebc3116705f5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.a9eafd2b73978f07e4e838766557eeb7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.afcdbb0127f50f6d8955178b9f6d6a1f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.b943665d481d05f0685efe0957dd01dc.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC5_DATE1_005_png_jpg.rf.fe4e5bd7a22b6f64be333339a700e3f2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.16e8728c4d957bfb3de14fdcdd185f26.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.3cc712ffc399035ad1d94ac90cf54ec4.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.57fcd8ed64c22e11efdaf3defc39eca1.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.77736ef396b7811f7c4358c3dc63c16d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.c7d236deb16833af5cc68ac3d2a3c0fa.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.d71d8aa57ad564204f62e84fd898c3af.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC6_DATE2_092_png_jpg.rf.e91ade85a33bcfd2da02fbd1b16a1257.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.268aed50d7a5f20f94b4c3a8029d78ac.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.5f8f5e469022d4aa23c00303241e3cdd.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.60b581804165163bf0d971e5b9c480b0.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.66b6ea9f771826f82deba9abaeedadf6.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.73520be102311c2a1c2e2819604f374c.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.c300ca011a8bd9a9bfdc695dbfca0bab.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC7_DATE1_021_png_jpg.rf.edd303ac13576e3c04b5f8bad5a94f00.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.0d18a7cee3f333133f955e5ed5cc1efd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.203e1a5e1b7c2f116bac4c874d8a20ae.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.3571ab164465973fc6c6889a2b6c38d5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.43d977cdc11f864d33abf6a39dce3b67.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.50d78dd2ec57715b27fccc26355e9ee6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.7efb5f239997b0ecbe622a8390a739a2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/DB_LOC8_DATE1_029_png_jpg.rf.c49fd9bf40996595bebc3525bdc22215.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.1036f936df464fa42696691072d1b896.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.18bab1c3d6004794966cea6b25a6e283.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.58bd5cd89e5ff7623c8dd5428e2a4a65.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.9be2a2a8de2aecae24e373ac220cd49d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.a6e1aae47bcbd6c6391159a891f6c91e.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.d2ae2b8941142473176019aaa9f6d61c.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC10_DATE1_043_png_jpg.rf.d9ed6b7d5fd50148f94b8b490204f1d5.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.0b4f464abb779a605a93f73d7bdd05f3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.522db42e6d69138882fad4bbf71a75ce.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.5b32235c1cc1bac5fc02c1a7823d1f3c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.90fa27514a168589dd02748adfd6a2da.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.a7729ad0820c11b135d5a4ecd5c66ea0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.b543bb0a11b5670ec11e86cec5e585db.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC2_DATE1_003-copy_jpg.rf.e713a0a70c06143bee973ff08f7a896b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.0b2eff8d7ca6253bbdffdaadfb400dec.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.1ed06883780761a8310752233436fd0b.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.2e2d3f77bc0f464f125375c09882fbbc.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.4d70752cd3441b9a9796c408dadea07d.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.5ddc0a3960662b90885a729bbe32c507.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.87a2f14d1fee35953015c48b3e17ca25.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC3_DATE1_003_png_jpg.rf.c04fc35349f5eb22da27664fe97683e9.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.00c2c53772b6e8fc87c432735c2d9140.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.0bef70b1c3a2e5697919a1c33ca1151a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.15511b9f4e45512f6382bf157a2bea48.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.3099201c6fd204dc5178fb094fb2e2b1.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.51b11c8e74a373dd611b2d70c36a0fb1.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.53e64a798074ab0e7b99745b497dc762.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC5_DATE2_088_png_jpg.rf.c1b2e434b0e645351befc61b18f2cd52.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.1273d16b100546999a5cd8e20e6c3658.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.326e574bb12ae43081cae01b1fc75c81.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.3984ab625fb2df33874336b9c22bc8f2.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.5a46dad3fc29a26f0b3a205892ff34e3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.812a0d7ae9f9fdf0b83cc204e59aa17c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.8afe5b223fb968ae212a4b6471d5053f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE1_011_png_jpg.rf.f9625c7a8a19eb85b59e717e3458b946.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.028744df9fad3fda28293c11698c3743.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.0e8088f381dfb433068c5a7f4d607ae3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.3704395684958efcd0a1f7ed54c7bfaa.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.57f180dc6b639a6445961728db61496f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.6887bda57f4c66a1bc219f45b3b522f6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.c4c894b14bb650d0f5da97ce70e755a8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE2_096_png_jpg.rf.dc0f4391d909b6eb28e3e1161fea3694.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.20168a2986f874a1df9b3ebfe45b48d5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.42fa455b5842419d253f4750cb5a5bb3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.45b8abc87f2aa927526d5dbecd1eba53.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.52b0a2c1e43b272772584ca1de24f3ad.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.7896aa31202961a88ead5f97ca3efec8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.8b8611abd1b787165bbb1ca3111bef03.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.8c5e6c965330085397c08fa949c0039a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.94f51797c9f7fc05fe123870814fc23f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.a77edea283b1992ecca318e94fa8ddb3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.a8b5eb04e60d6c64f2b25c28e7e2c92a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.acd216075275dff2f9a0aaa7cd9ddf12.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.b6d84b93efb825c95ed60bd74c4d729e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.bbf7b2126a61fe241830d8da3537d3f5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE3025-copy_jpg.rf.ccd13a6db679e9237d0b7d4a7d0c2ec8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC6_DATE7_218_jpg.rf.417aca0c98d4d31fbbfccacc85993521.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.26700af636ff9ca948f00e5d16d24514.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.4a47711c9ef4fcd5ba3988028d26005f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.4f30fb4641847a563deabaa30f88d44b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.79dfcd2fefb98bb7c0bc168c32d3d5eb.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.962bd50912718bb4e03b87ee66c81092.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.e90701e6f06722e0a720cf5c83a42c53.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC7_DATE1_019_png_jpg.rf.ed0d99b62948f40451326660149c2079.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.33ba0d411e1303e2ca2f03a2b6a5cae8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.39285928fdc21b69fc88c82c9ddf5d28.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.3efcf0fa872eb9d8a392746c93c040ba.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.6b11a9b686c8ffd57ceef990550aac5a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.81f2d8eda6d073a32226badca433778e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.e2bdfc5660dbae0314bf6586bed14976.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVB_LOC9_DATE1_035_png_jpg.rf.ede7a7b67dc050f97ca7b4592bb74a84.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.0d3b8ae9f6547549406edfc220d7218c.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.3ce6c316edad869d164f23855e59f7d7.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.8d21f29803dbe8f3ca663c9bc806bffd.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.903bac31fffd2dead5a4b7b37c74c5cc.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.9fc26957f7756bbc85d183a856d33c31.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.bcf3e79e21ec007c676674cd2ab5913c.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE1_047_png_jpg.rf.dea9287b9456b4d08b13223ba63ae5a0.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.1df1061c5353c95c33676cfac3d237b8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.41394a49d554b907e2d76daeac5287d3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.69cfd3d1f41b2a0526a6d71787622bad.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.7ca3d4815554e7c451b6b91d530b5bec.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.83a5053cb3cada15f88450445ae28785.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.b6eddc509f3e97f84360e64d889cc24c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC10_DATE8_287_jpg.rf.e64cc2162b052dd160f18da1ec817240.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.0e7445d88fe40de0e42b0b730cae9f2b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.16643ba12dfdedb1cad035be31a5edf0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.3b4501d25bd2f6875678fbc13fe3c4d0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.558e79402f0f42b688e5c31ae5990933.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.6fa826d5f3a4c0fbf7bd3ac1012104d0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.8e82883cbe5adcd0904be1d9ea1ad508.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC3_DATE1_006_png_jpg.rf.eb0da8755184d0445c5d72a6d3a8bea7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.0653d4d7eb428a077953c299bc711c8e.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.37e43af581d48c99f2a8c5a4d2369ebf.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.651099baf27f0b10f2e471d9cb86dbe1.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.b9348d5500bba29e2b9d621a9090153d.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.c6a2e118d0b1f5a706077cf2bf7ad582.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.e94c7fe39b1614ccc4cb3c0700e07990.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC5_DATE1_006_png_jpg.rf.ed1e3fdaea2952b5731910bea695d7c0.jpg: 5 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.138161b331655fe672c11a88f32de047.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.51dfd6c9b18450f348b03ff86ad7d2cc.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.5e4669b018981243246990abe13fc976.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.99e9cf0ac1e26dba8ccaf86ba2f2b21c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.ab3bf5ab733635a6ec049f13cb7d5233.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.cd5311ed16cfab4db9d7b8239bc311f3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC7_DATE1_022_png_jpg.rf.f9e50f1c5e7eae73d7bc7189063e8f47.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC8_DATE2_107_png_jpg.rf.5075605f2e1c21b977fa772c2f95dc2b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC8_DATE2_107_png_jpg.rf.5a4d73068396b7118d8455f107fe49c7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVG_LOC8_DATE2_107_png_jpg.rf.b90f9db4544f3ed7e6109fa153e1e383.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.41782b29b0960341154a1c694ac18203.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.6d7b08087a50f0381d743779376d7a3e.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.87d8331423cfb297e3301bccb938e282.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.a1c2f3296087c05e975d481ea3318ada.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.a2d8cdc7c6faff2040b6520c5b01da25.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.b6b51468d20712c4210156ac3db6b526.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC1_DATE2_052_png_jpg.rf.ca3976a2f72c000a27d722b4af94b3e6.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.1399aeed3f5b046869473865fd29b17c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.704eafd8be0eb42040dab6ee3b7e41d0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.71d02175470f0b013db06c536d57aeec.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.73052e36b7aa87a8b851b9442541cf74.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.80087dd4fa89c4f7339a2044a312f89e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.9f05b4177eff52f147107cf8623392a4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC2_DATE1_001_png_jpg.rf.d9b4b04128e65c2200de76d8c0492f0e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.3efc36a3bbc1699ca33542466b5fe1d5.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.5f8d0e00f8c1d91f2c81bca35370f3c7.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.6127393aeb35278980382ef3d856460a.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.776cf65d1f43978273696c9017756960.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.a3d0ecb2de845434edfebc9a4306ebb2.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.a756075a8266090c8099a510f36c8ed1.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC3_DATE1_001_png_jpg.rf.d94d00bd8fc08251eb235e66b5833750.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.4e0bbb0c19d909beedee6600766b1f7f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.90e6e595819c4227bd7eccb5e69590f9.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.a699baea45db3863df80a35e820ff6c8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.c54d08ea1d8178daed1067597f940359.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.cd521959db60da254b7c1e709ba4c0d8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.dddec4f77d512345a20a085cb40e6ff4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC7_DATE1_017_png_jpg.rf.fa24e49fb2f5e95be957ea5c562acf60.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.2bd6676e8dc97736142101326e984929.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.4f10a843d2e65e0c9c76ed0ab85a3cd4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.5e20ecbdf8977df630c1d09e44cc7d77.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.6a1f94a2148edadf3f82ff0e7347223c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.6c05732fb52159f94581de263a406f5c.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.ccf9b24039a049f2bfbc3160c7f053db.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVO_LOC8_DATE1_025_png_jpg.rf.df9b61ee0a06ac7931a2448ac95e94fd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.29098dc7b8f21df470300964cdb9f645.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.36b0c8e332e600a1c48f4873113d908e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.80064650792a1897f2cc532cf1273063.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.919b710a17aaa83bf420d414a8be9ec3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.a3106be03016f4e32bdaea4a3069158f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.b6fdda115e5f64fe7956f4a63d37f929.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC10_DATE2_129_png_jpg.rf.f1c57fff370adf4433de01491a478425.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.30a83138fa750830a5c04f9b7bed205e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.55667c48cce2f14e68d1bddfca4b4284.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.57f14b62c346f99621b1cc30ccb6ccf3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.9764c769250de7bafff9c698975f8823.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.a2b9fbd2b9e71278151f08f5f1b696d8.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.bdeefc23738462ded327cb59de90c7d7.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC1_DATE2_056_png_jpg.rf.ef9373832c42961cf372903eb4a7b5c5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.198e3c246da6c79fa4317253a7f22e32.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.26615b8f4551a4bed334aebdc7f0f4c5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.4224a3e0f3b668d63bfd6edebbec2527.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.6724fff2df4d5dcc8867faf248e81a9b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.ce3078d92a30716e5a21d23498059d11.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.ee0d364d7de8a2a10261c750a409d355.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC2_DATE1_008_png_jpg.rf.f9a57f873ba44d870d4d2a03e93f8e30.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.08626d2321af5242f402892b2d213fc4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.23ed469210965e387bfd28cefc911427.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.4082ac6dc5d95032195b2982159396df.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.5ac32185fef27f480f2c55f0fceb341a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.b5df33d7e1105b4ddc119a8b928093d3.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.b6ce6ab8eb410a473e89b97aea4fd4d6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC3_DATE1_008_png_jpg.rf.fdb7b2af5d576a87287810cfa71dc98f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.04b5c9b62a040f6adb787ed17a26d450.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.083bd21e9aecf332471f81db311084da.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.41da1baad502306ff89677a5e7e67fe4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.4d25149c3006c3b87916ce7c0addbc82.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.e8fa62a8f3a8707b436083c36c454b5f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.f8bf4ba93ae0a50aa6f5ff938c0c42da.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC5_DATE2_089_png_jpg.rf.fc373de9f2170d1a88f936585f1981b5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.45838e1ec607bda7ad8fc4cdc85a20e1.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.a8a1dc6f2bf03a3470505a58f356aa91.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.c66ff8298a8512719632dc5535e2a61f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.da471c54403dd6d106069a13b97008fd.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.e68ca2fac0dd4d31d8ccfde59f1032b4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.f500074ce900816caad504f3fb886d4b.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC7_DATE2_105_png_jpg.rf.fe8fa391351c592bcc7c06054026b5c0.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.3fc8ac7c03b6798e06277ad1bf264329.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.45d72a00f13c9feb51c4dc523f3cd55a.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.4afa36eb490804a6cdf559a7e9d17fe5.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.6d06fe31c4718df6ed3ffe5697364b35.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.7697eebb9168b312c2c0015cab701dbf.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.ba773a874d1de9c2a2d8ee73d022b7e4.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC8_DATE1_032_png_jpg.rf.e3421a2dd582d0d8593c6d939ca9b776.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.7367727283356f2e706ec9f354f5f807.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.7493382e5e56bb9e9efa9e4d114c2698.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.7c16c5c350d5f6f58052388114535b17.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.882f17445c484a17ae16ae12a5d70d3e.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.c3deeeaeca855fe6f93f4fd10709cd67.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.f8cacfaac2e00eba1e151e6535559fac.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE1_040_png_jpg.rf.fe3d0b6df785b60adade1453cee1cc67.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.017fac976850e55379c48f4f46fafcdc.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.25299c27bd41f837d64fdbce2238eb38.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.2acc8658c911bac459615afb32fb3cd0.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.3fa1ada93f5635dfd5ba4df087a6d550.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.6dcc6a981fa6a2bc1d09b96e91c7bf86.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.8c957231e43bb8fbe5818453126a8701.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVR_LOC9_DATE2_121_png_jpg.rf.f8f6627ceeeb23c123ff96d41620b1b7.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.1f56b79099a0ea659dd58d61a9be0b46.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.6462d5665c3ae32dbff457c300e7e519.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.85c5346acd2c692534bda1f4c197cd5d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.8e177a0d2ea3810abb42fa4411b36eb6.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.a94c32e93f9f9391808a458ed372b860.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.bafc6b8f678285aedf02830c8e149e2f.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC10_DATE1_048_png_jpg.rf.d0bf25abc937e3db8d7c19c7483bad26.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.846edc77d8b6e47aa0a96611cca010ce.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.86a5ddb976173cfa5f8fa743def2da89.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.8ff67a8133adff0fdb3a6dfa9475eb10.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.a0e58528464e7abffc410665a13d0091.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.b9f545230dd05c02eb66e48fafa669be.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.e6c6551ee1a5d2d72d3219eb3ae22c63.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC2_DATE1_007_png_jpg.rf.f1a6108bb4f903e68a0fd8ed58f7c398.jpg: 3 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC3_DATE2_071_png_jpg.rf.995e038d7b3fae49dd13ef1ad717f05d.jpg: 1 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.0186433ab87366a6bdd195f716f30ca1.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.1e1c58587e5f508862da7ef4a731f10e.jpg: 2 duplicate labels removed
# train: /content/datasets/ScanBugS1v2-9/train/images/UVY_LOC5_DATE2_087_png_jpg.rf.2d77d6fdf6a501e3e37c85238fcec628.jpg: 2 duplicate labels removed
# ...
#                    all        124       9424      0.891      0.857       0.91      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      26.8G      2.066      1.837      1.406        112       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.00it/s]
#                    all        124       9424      0.893      0.859      0.914      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      26.5G      2.041      1.803      1.394        183       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.05it/s]
#                    all        124       9424      0.896      0.856      0.911      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      27.7G      2.048      1.813      1.405        415       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.03it/s]
#                    all        124       9424      0.885      0.853      0.904      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      31.3G      2.044      1.808      1.393        153       3200: 100% 1519/1519 [06:52<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.01it/s]
#                    all        124       9424      0.891       0.87      0.915      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      32.1G      2.044      1.802      1.396        164       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.97it/s]
#                    all        124       9424       0.89      0.865      0.911      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50        36G      2.028      1.747      1.381        517       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.08it/s]
#                    all        124       9424      0.893      0.863      0.916      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      27.3G      2.017      1.738       1.38         95       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.01it/s]
#                    all        124       9424      0.896      0.862      0.912      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      28.2G      2.012      1.711      1.374        243       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.06it/s]
#                    all        124       9424      0.887      0.865      0.915      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      32.6G      1.989      1.679      1.363         73       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.06it/s]
#                    all        124       9424      0.894      0.871      0.918      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      30.4G      1.983      1.661      1.359        279       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.04it/s]
#                    all        124       9424      0.899      0.865      0.918      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      35.1G      1.978      1.653      1.347        104       3200: 100% 1519/1519 [06:52<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.09it/s]
#                    all        124       9424       0.89      0.849      0.911      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      26.5G      1.963      1.629      1.343        183       3200: 100% 1519/1519 [06:52<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.03it/s]
#                    all        124       9424        0.9      0.859      0.912      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      27.5G      1.958      1.635      1.342        164       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.05it/s]
#                    all        124       9424      0.896      0.865      0.917      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      27.4G      1.953      1.609      1.335        198       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.02it/s]
#                    all        124       9424      0.897      0.867      0.919      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      36.9G      1.949      1.609      1.334        184       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.09it/s]
#                    all        124       9424      0.893      0.872      0.921       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      26.9G      1.933      1.588       1.33        147       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.10it/s]
#                    all        124       9424      0.904      0.869       0.92      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      37.9G       1.93      1.572      1.322        324       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.10it/s]
#                    all        124       9424      0.898      0.873       0.92      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50        32G      1.921      1.565      1.319        146       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.06it/s]
#                    all        124       9424      0.903      0.867       0.92      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50        38G      1.922      1.567      1.319        308       3200: 100% 1519/1519 [06:51<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.04it/s]
#                    all        124       9424      0.902      0.881      0.928      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      32.3G      1.906      1.536      1.312        258       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.07it/s]
#                    all        124       9424      0.896      0.869      0.922      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      34.5G      1.895      1.516      1.304        354       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.03it/s]
#                    all        124       9424      0.897      0.875      0.923      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      30.6G      1.907      1.548      1.314        131       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.09it/s]
#                    all        124       9424      0.906      0.876      0.927      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      35.5G      1.895      1.535      1.309        252       3200: 100% 1519/1519 [06:49<00:00,  3.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.11it/s]
#                    all        124       9424        0.9      0.871      0.925       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      31.8G       1.88      1.515        1.3        169       3200: 100% 1519/1519 [06:51<00:00,  3.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.08it/s]
#                    all        124       9424      0.904      0.872      0.925       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      35.3G      1.884      1.523      1.301        113       3200: 100% 1519/1519 [06:50<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.05it/s]
#                    all        124       9424      0.904      0.879       0.93      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      30.8G      1.868      1.502      1.294        157       3200: 100% 1519/1519 [06:51<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.06it/s]
#                    all        124       9424      0.913      0.873      0.931      0.564
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      26.7G      1.847      1.499      1.298        229       3200: 100% 1519/1519 [06:38<00:00,  3.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  6.98it/s]
#                    all        124       9424        0.9       0.88      0.929      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      26.8G      1.829      1.473      1.288        106       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.08it/s]
#                    all        124       9424      0.906      0.873      0.928      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50        27G      1.824       1.47      1.284        214       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.10it/s]
#                    all        124       9424       0.91      0.871      0.929      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      26.8G       1.82      1.458      1.276         75       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.03it/s]
#                    all        124       9424      0.912      0.874       0.93      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      27.2G      1.803      1.439      1.271         98       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.11it/s]
#                    all        124       9424       0.91      0.878      0.932      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      28.3G      1.801      1.435      1.273         95       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.09it/s]
#                    all        124       9424      0.904      0.878      0.929      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50        27G      1.796      1.424      1.266        234       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.08it/s]
#                    all        124       9424      0.906      0.881      0.931      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      26.3G      1.793      1.423      1.269        161       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.12it/s]
#                    all        124       9424      0.908      0.879      0.932      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      27.4G      1.785      1.405      1.264         89       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.12it/s]
#                    all        124       9424       0.91      0.876      0.931      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      26.9G      1.777      1.397      1.259        141       3200: 100% 1519/1519 [06:37<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:04<00:00,  7.11it/s]
#                    all        124       9424      0.909      0.878      0.931      0.569
#
# 50 epochs completed in 5.749 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 20.1MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 20.1MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:07<00:00,  4.15it/s]
#                    all        124       9424      0.906       0.88      0.931       0.57
# Speed: 2.1ms preprocess, 22.8ms inference, 0.1ms loss, 12.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `{HOME}/runs/detect/train/`. Let's examine them.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml			 R_curve.png	       train_batch60762.jpg
# confusion_matrix_normalized.png  results.csv	       val_batch0_labels.jpg
# confusion_matrix.png		 results.png	       val_batch0_pred.jpg
# F1_curve.png			 train_batch0.jpg      val_batch1_labels.jpg
# labels_correlogram.jpg		 train_batch1.jpg      val_batch1_pred.jpg
# labels.jpg			 train_batch2.jpg      val_batch2_labels.jpg
# P_curve.png			 train_batch60760.jpg  val_batch2_pred.jpg
# PR_curve.png			 train_batch60761.jpg  weights

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=1000)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=1000)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=1000)

# %% [markdown]
# ## Validate fine-tuned model

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2319.9±1377.3 MB/s, size: 136.3 KB)
# val: Scanning /content/datasets/ScanBugS1v2-9/valid/labels.cache... 124 images, 0 backgrounds, 0 corrupt: 100% 124/124 [00:00<?, ?it/s]
# val: /content/datasets/ScanBugS1v2-9/valid/images/B_LOC10_DATE1_044_png_jpg.rf.f180716f647fc8bc4eec4d3f46a6c4a1.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/B_LOC2_DATE2_068_png_jpg.rf.ff4e2abd621e0f5e5caaf56fd7cdedcb.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/DB_LOC1_DATE2_051_png_jpg.rf.9102999b960a198bdce3e45df86e92b4.jpg: 2 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/DB_LOC7_DATE2_100_png_jpg.rf.afe9f105481470018ae05c451c81f04f.jpg: 2 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVB_LOC4_DATE2_082_png_jpg.rf.9bf664e7f29de6da8740a9fcf309c877.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVG_LOC1_DATE2_050_png_jpg.rf.748391b5f73d1565e5b6977f28ad77b7.jpg: 2 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVG_LOC6_DATE2_091_png_jpg.rf.7ccc2c9031ffd9d879ac1ffe7c1f550e.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVG_LOC8_DATE1_030_png_jpg.rf.76baae7e5d2bf44810bcc71c758659ad.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVG_LOC9_DATE2_115_png_jpg.rf.71ec3a43ed562a2fe6ab100f673a6f4f.jpg: 2 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVO_LOC2_DATE2_060_png_jpg.rf.1c0006b6d145e87bad3c7d8a7eb0928d.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVO_LOC9_DATE2_117_png_jpg.rf.e81f25e0bd8b1e8c3146dee852d09cf6.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVR_LOC10_DATE1_049_png_jpg.rf.8f1bfa09bffd4f3e528f16a5537a1f75.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/UVR_LOC5_DATE1_008_png_jpg.rf.bfe419b1714874fac88d1021289d14b4.jpg: 4 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/W_LOC6_DATE1_010-copy_jpg.rf.70d5960706a1ca955e26d5287efd2106.jpg: 1 duplicate labels removed
# val: /content/datasets/ScanBugS1v2-9/valid/images/W_LOC8_DATE2_114_png_jpg.rf.b247cfb1c8c7bb18975d573a1a00f76d.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  12% 1/8 [00:05<00:37,  5.36s/it]
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 981, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 630, in val
#     validator(model=self.model)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/validator.py", line 214, in __call__
#     preds = model(batch["img"], augment=augment)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/autobackend.py", line 592, in forward
#     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 115, in forward
#     return self.predict(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 133, in predict
#     return self._predict_once(x, profile, visualize, embed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py", line 154, in _predict_once
#     x = m(x)  # run
#         ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py", line 1495, in forward
#     b = self.m(b)
#         ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py", line 250, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py", line 1378, in forward
#     x = x + self.attn(x) if self.add else self.attn(x)
#             ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py", line 1323, in forward
#     attn = (q.transpose(-2, -1) @ k) * self.scale
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 13.32 GiB. GPU 0 has a total capacity of 39.56 GiB of which 6.97 GiB is free. Process 1562934 has 32.57 GiB memory in use. Of the allocated memory 19.09 GiB is allocated by PyTorch, and 12.96 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ## Inference with custom model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv11 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv11 weights.

# %%
project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{HOME}/runs/detect/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/computervisionlab/scanbugs1v2/9
# Share your model with the world at: https://universe.roboflow.com/computervisionlab/scanbugs1v2/model/9

# %%
# !pip install inference

# %%
import os, random, cv2
import supervision as sv
import IPython
import inference

model_id = project.id.split("/")[1] + "/" + dataset.version
model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))

# Location of test set images
test_set_loc = dataset.location + "/test/images/"
test_images = os.listdir(test_set_loc)

# Run inference on 4 random test images, or fewer if fewer images are available
for img_name in random.sample(test_images, min(4, len(test_images))):
    print("Running inference on " + img_name)

    # Load image
    image = cv2.imread(os.path.join(test_set_loc, img_name))

    # Perform inference
    results = model.infer(image, confidence=0.4, overlap=30)[0]
    detections = sv.Detections.from_inference(results)

    # Annotate boxes and labels
    box_annotator = sv.BoxAnnotator()
    label_annotator = sv.LabelAnnotator()
    annotated_image = box_annotator.annotate(scene=image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    # Display annotated image
    _, ret = cv2.imencode('.jpg', annotated_image)
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)
# Out:
# ModelDependencyMissing: Your `inference` configuration does not support Qwen2.5-VL model. Use pip install 'inference[transformers]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[sam]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[sam]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support SAM model. Use pip install 'inference[clip]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support Gaze Detection model. Use pip install 'inference[gaze]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support GroundingDINO model. Use pip install 'inference[grounding-dino]' to install missing requirements.
# ModelDependencyMissing: Your `inference` configuration does not support YoloWorld model. Use pip install 'inference[yolo-world]' to install missing requirements.
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-18-348da3c98227> in <cell line: 0>()
#       5
#       6 model_id = project.id.split("/")[1] + "/" + dataset.version
# ----> 7 model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))
#       8
#       9 # Location of test set images
#
# /usr/local/lib/python3.11/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret ROBOFLOW_API_KEY timed out. Secrets can only be fetched when running from the Colab UI.

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

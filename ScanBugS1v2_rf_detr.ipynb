# %% [markdown]
# <a href="https://colab.research.google.com/github/songguan26/InsectRoleVision/blob/main/ScanBugS1v2_rf_detr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Open your [`HuggingFace Settings`](https://huggingface.co/settings) page. Click `Access Tokens` then `New Token` to generate new token.
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store HuggingFace Access Token under the name `HF_TOKEN`.
#     - Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu May 15 09:09:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             41W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -q rfdetr==1.1.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 99.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 116.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.1/361.1 kB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 49.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 135.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 842.5/842.5 kB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.9 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ## Download dataset from Roboflow Universe

# %%
from roboflow import download_dataset

dataset = download_dataset('https://universe.roboflow.com/computervisionlab/scanbugs1v2/dataset/11', "coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ScanBugS1v2-11 to coco:: 100%|██████████| 396772/396772 [00:04<00:00, 84591.05it/s]
# Extracting Dataset Version Zip to ScanBugS1v2-11 in coco:: 100%|██████████| 3230/3230 [00:01<00:00, 2798.63it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.
#
# ### Train with multiple GPUs
#
# You can fine-tune RF-DETR on multiple GPUs using PyTorch’s Distributed Data Parallel (DDP). Create a `main.py` script that initializes your model and calls `.train()` as usual than run it in terminal.
#
# ```bash
# python -m torch.distributed.launch \
#     --nproc_per_node=8 \
#     --use_env \
#     main.py
# ```
#
# Replace `8` in the `--nproc_per_node argument` with the number of GPUs you want to use. This approach creates one training process per GPU and splits the workload automatically. Note that your effective batch size is multiplied by the number of GPUs, so you may need to adjust your `batch_size` and `grad_accum_steps` to maintain the same overall batch size.

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()

model.train(dataset_dir=dataset.location, epochs=30, batch_size=1, lr=1e-3, resolution= 3192)
# Out:
# rf-detr-base.pth: 100%|██████████| 355M/355M [00:03<00:00, 108MiB/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 2 classes
# reinitializing your detection head with 2 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=2, grad_accum_steps=4, amp=True, lr=0.001, lr_encoder=0.00015, batch_size=1, weight_decay=0.0001, epochs=30, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/ScanBugS1v2-11', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=3192, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, tensorboard=True, wandb=False, project=None, run=None, class_names=['Arthropod'], distributed=False)
# number of params: 31854308
# [3024, 3080, 3136, 3192, 3248, 3304, 3360, 3416]
# loading annotations into memory...
# Done (t=1.00s)
# creating index...
# index created!
# [3024, 3080, 3136, 3192, 3248, 3304, 3360, 3416]
# loading annotations into memory...
# Done (t=0.57s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  4
# LENGTH OF DATA LOADER: 759
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
# Epoch: [0]  [  0/759]  eta: 1:53:00  lr: 0.001000  class_error: -0.00  loss: 23.3194 (23.3194)  loss_ce: 0.1960 (0.1960)  loss_bbox: 2.5705 (2.5705)  loss_giou: 2.8817 (2.8817)  loss_ce_0: 0.1980 (0.1980)  loss_bbox_0: 2.7012 (2.7012)  loss_giou_0: 2.9553 (2.9553)  loss_ce_1: 0.1922 (0.1922)  loss_bbox_1: 2.5760 (2.5760)  loss_giou_1: 2.9351 (2.9351)  loss_ce_enc: 0.1959 (0.1959)  loss_bbox_enc: 2.9083 (2.9083)  loss_giou_enc: 3.0091 (3.0091)  loss_ce_unscaled: 0.1960 (0.1960)  class_error_unscaled: -0.0000 (-0.0000)  loss_bbox_unscaled: 0.5141 (0.5141)  loss_giou_unscaled: 1.4409 (1.4409)  cardinality_error_unscaled: 15.0000 (15.0000)  loss_ce_0_unscaled: 0.1980 (0.1980)  loss_bbox_0_unscaled: 0.5402 (0.5402)  loss_giou_0_unscaled: 1.4776 (1.4776)  cardinality_error_0_unscaled: 45.0000 (45.0000)  loss_ce_1_unscaled: 0.1922 (0.1922)  loss_bbox_1_unscaled: 0.5152 (0.5152)  loss_giou_1_unscaled: 1.4676 (1.4676)  cardinality_error_1_unscaled: 90.0000 (90.0000)  loss_ce_enc_unscaled: 0.1959 (0.1959)  loss_bbox_enc_unscaled: 0.5817 (0.5817)  loss_giou_enc_unscaled: 1.5046 (1.5046)  cardinality_error_enc_unscaled: 1698.0000 (1698.0000)  time: 8.9334  data: 2.6007  max mem: 16258
# Epoch: [0]  [ 10/759]  eta: 0:48:49  lr: 0.001000  class_error: 0.00  loss: 11.1606 (13.3897)  loss_ce: 0.5375 (0.5162)  loss_bbox: 0.4217 (0.8045)  loss_giou: 1.9523 (2.0124)  loss_ce_0: 0.5409 (0.5125)  loss_bbox_0: 0.4070 (0.8140)  loss_giou_0: 1.9436 (2.0123)  loss_ce_1: 0.5319 (0.5119)  loss_bbox_1: 0.4230 (0.8076)  loss_giou_1: 1.9584 (2.0157)  loss_ce_enc: 0.4776 (0.4631)  loss_bbox_enc: 0.3972 (0.8326)  loss_giou_enc: 2.0379 (2.0870)  loss_ce_unscaled: 0.5375 (0.5162)  class_error_unscaled: 0.0000 (0.0104)  loss_bbox_unscaled: 0.0843 (0.1609)  loss_giou_unscaled: 0.9762 (1.0062)  cardinality_error_unscaled: 52.0000 (92.0909)  loss_ce_0_unscaled: 0.5409 (0.5125)  loss_bbox_0_unscaled: 0.0814 (0.1628)  loss_giou_0_unscaled: 0.9718 (1.0061)  cardinality_error_0_unscaled: 57.0000 (92.9091)  loss_ce_1_unscaled: 0.5319 (0.5119)  loss_bbox_1_unscaled: 0.0846 (0.1615)  loss_giou_1_unscaled: 0.9792 (1.0078)  cardinality_error_1_unscaled: 109.0000 (519.6364)  loss_ce_enc_unscaled: 0.4776 (0.4631)  loss_bbox_enc_unscaled: 0.0794 (0.1665)  loss_giou_enc_unscaled: 1.0190 (1.0435)  cardinality_error_enc_unscaled: 121.0000 (711.4545)  time: 3.9111  data: 0.2446  max mem: 19130
# Epoch: [0]  [ 20/759]  eta: 0:44:17  lr: 0.001000  class_error: 0.00  loss: 10.0405 (11.3464)  loss_ce: 0.6293 (0.6286)  loss_bbox: 0.2586 (0.5303)  loss_giou: 1.5554 (1.6614)  loss_ce_0: 0.6361 (0.6458)  loss_bbox_0: 0.2599 (0.5342)  loss_giou_0: 1.5588 (1.6505)  loss_ce_1: 0.6395 (0.6232)  loss_bbox_1: 0.2570 (0.5332)  loss_giou_1: 1.5494 (1.6631)  loss_ce_enc: 0.5744 (0.6061)  loss_bbox_enc: 0.2829 (0.5467)  loss_giou_enc: 1.7183 (1.7232)  loss_ce_unscaled: 0.6293 (0.6286)  class_error_unscaled: 0.0000 (0.0055)  loss_bbox_unscaled: 0.0517 (0.1061)  loss_giou_unscaled: 0.7777 (0.8307)  cardinality_error_unscaled: 52.0000 (100.5238)  loss_ce_0_unscaled: 0.6361 (0.6458)  loss_bbox_0_unscaled: 0.0520 (0.1068)  loss_giou_0_unscaled: 0.7794 (0.8253)  cardinality_error_0_unscaled: 57.0000 (100.9524)  loss_ce_1_unscaled: 0.6395 (0.6232)  loss_bbox_1_unscaled: 0.0514 (0.1066)  loss_giou_1_unscaled: 0.7747 (0.8316)  cardinality_error_1_unscaled: 100.0000 (324.4762)  loss_ce_enc_unscaled: 0.5744 (0.6061)  loss_bbox_enc_unscaled: 0.0566 (0.1093)  loss_giou_enc_unscaled: 0.8592 (0.8616)  cardinality_error_enc_unscaled: 100.0000 (424.9524)  time: 3.3293  data: 0.0093  max mem: 19298
# Epoch: [0]  [ 30/759]  eta: 0:42:05  lr: 0.001000  class_error: 0.00  loss: 7.1564 (9.9958)  loss_ce: 0.7846 (0.6834)  loss_bbox: 0.0897 (0.3860)  loss_giou: 0.8279 (1.4089)  loss_ce_0: 0.8414 (0.7091)  loss_bbox_0: 0.0874 (0.3878)  loss_giou_0: 0.7592 (1.3931)  loss_ce_1: 0.8150 (0.6848)  loss_bbox_1: 0.0913 (0.3883)  loss_giou_1: 0.8334 (1.4097)  loss_ce_enc: 0.8323 (0.6785)  loss_bbox_enc: 0.0860 (0.3979)  loss_giou_enc: 0.8759 (1.4683)  loss_ce_unscaled: 0.7846 (0.6834)  class_error_unscaled: 0.0000 (0.0037)  loss_bbox_unscaled: 0.0179 (0.0772)  loss_giou_unscaled: 0.4140 (0.7044)  cardinality_error_unscaled: 77.0000 (93.8387)  loss_ce_0_unscaled: 0.8414 (0.7091)  loss_bbox_0_unscaled: 0.0175 (0.0776)  loss_giou_0_unscaled: 0.3796 (0.6966)  cardinality_error_0_unscaled: 77.0000 (94.1290)  loss_ce_1_unscaled: 0.8150 (0.6848)  loss_bbox_1_unscaled: 0.0183 (0.0777)  loss_giou_1_unscaled: 0.4167 (0.7048)  cardinality_error_1_unscaled: 77.0000 (245.5484)  loss_ce_enc_unscaled: 0.8323 (0.6785)  loss_bbox_enc_unscaled: 0.0172 (0.0796)  loss_giou_enc_unscaled: 0.4380 (0.7341)  cardinality_error_enc_unscaled: 77.0000 (313.6129)  time: 3.2193  data: 0.0098  max mem: 19298
# Epoch: [0]  [ 40/759]  eta: 0:40:52  lr: 0.001000  class_error: 0.00  loss: 6.7284 (9.2154)  loss_ce: 0.7846 (0.7101)  loss_bbox: 0.0616 (0.3104)  loss_giou: 0.7827 (1.2619)  loss_ce_0: 0.8481 (0.7426)  loss_bbox_0: 0.0635 (0.3111)  loss_giou_0: 0.7406 (1.2445)  loss_ce_1: 0.7801 (0.7119)  loss_bbox_1: 0.0639 (0.3119)  loss_giou_1: 0.7547 (1.2618)  loss_ce_enc: 0.8489 (0.7191)  loss_bbox_enc: 0.0659 (0.3192)  loss_giou_enc: 0.8519 (1.3108)  loss_ce_unscaled: 0.7846 (0.7101)  class_error_unscaled: 0.0000 (0.0028)  loss_bbox_unscaled: 0.0123 (0.0621)  loss_giou_unscaled: 0.3914 (0.6309)  cardinality_error_unscaled: 62.0000 (86.7073)  loss_ce_0_unscaled: 0.8481 (0.7426)  loss_bbox_0_unscaled: 0.0127 (0.0622)  loss_giou_0_unscaled: 0.3703 (0.6222)  cardinality_error_0_unscaled: 62.0000 (86.9268)  loss_ce_1_unscaled: 0.7801 (0.7119)  loss_bbox_1_unscaled: 0.0128 (0.0624)  loss_giou_1_unscaled: 0.3774 (0.6309)  cardinality_error_1_unscaled: 62.0000 (201.4146)  loss_ce_enc_unscaled: 0.8489 (0.7191)  loss_bbox_enc_unscaled: 0.0132 (0.0638)  loss_giou_enc_unscaled: 0.4259 (0.6554)  cardinality_error_enc_unscaled: 62.0000 (252.8780)  time: 3.2179  data: 0.0098  max mem: 19298
# Epoch: [0]  [ 50/759]  eta: 0:39:56  lr: 0.001000  class_error: 0.00  loss: 6.7284 (8.7309)  loss_ce: 0.7641 (0.7180)  loss_bbox: 0.0622 (0.2661)  loss_giou: 0.7834 (1.1752)  loss_ce_0: 0.8393 (0.7555)  loss_bbox_0: 0.0587 (0.2663)  loss_giou_0: 0.7789 (1.1583)  loss_ce_1: 0.7655 (0.7206)  loss_bbox_1: 0.0615 (0.2671)  loss_giou_1: 0.7851 (1.1752)  loss_ce_enc: 0.8263 (0.7362)  loss_bbox_enc: 0.0642 (0.2729)  loss_giou_enc: 0.7919 (1.2195)  loss_ce_unscaled: 0.7641 (0.7180)  class_error_unscaled: 0.0000 (0.0023)  loss_bbox_unscaled: 0.0124 (0.0532)  loss_giou_unscaled: 0.3917 (0.5876)  cardinality_error_unscaled: 59.0000 (83.6275)  loss_ce_0_unscaled: 0.8393 (0.7555)  loss_bbox_0_unscaled: 0.0117 (0.0533)  loss_giou_0_unscaled: 0.3895 (0.5791)  cardinality_error_0_unscaled: 59.0000 (83.8039)  loss_ce_1_unscaled: 0.7655 (0.7206)  loss_bbox_1_unscaled: 0.0123 (0.0534)  loss_giou_1_unscaled: 0.3925 (0.5876)  cardinality_error_1_unscaled: 59.0000 (175.8431)  loss_ce_enc_unscaled: 0.8263 (0.7362)  loss_bbox_enc_unscaled: 0.0128 (0.0546)  loss_giou_enc_unscaled: 0.3960 (0.6098)  cardinality_error_enc_unscaled: 59.0000 (217.2157)  time: 3.2478  data: 0.0095  max mem: 19298
# Epoch: [0]  [ 60/759]  eta: 0:39:10  lr: 0.001000  class_error: 0.00  loss: 6.7778 (8.4285)  loss_ce: 0.7515 (0.7225)  loss_bbox: 0.0669 (0.2361)  loss_giou: 0.8188 (1.1200)  loss_ce_0: 0.7920 (0.7643)  loss_bbox_0: 0.0649 (0.2364)  loss_giou_0: 0.8263 (1.1062)  loss_ce_1: 0.7577 (0.7264)  loss_bbox_1: 0.0658 (0.2369)  loss_giou_1: 0.8226 (1.1192)  loss_ce_enc: 0.7539 (0.7375)  loss_bbox_enc: 0.0778 (0.2444)  loss_giou_enc: 0.9033 (1.1786)  loss_ce_unscaled: 0.7515 (0.7225)  class_error_unscaled: 0.0000 (0.0019)  loss_bbox_unscaled: 0.0134 (0.0472)  loss_giou_unscaled: 0.4094 (0.5600)  cardinality_error_unscaled: 78.0000 (81.4262)  loss_ce_0_unscaled: 0.7920 (0.7643)  loss_bbox_0_unscaled: 0.0130 (0.0473)  loss_giou_0_unscaled: 0.4131 (0.5531)  cardinality_error_0_unscaled: 78.0000 (81.5738)  loss_ce_1_unscaled: 0.7577 (0.7264)  loss_bbox_1_unscaled: 0.0132 (0.0474)  loss_giou_1_unscaled: 0.4113 (0.5596)  cardinality_error_1_unscaled: 78.0000 (158.5246)  loss_ce_enc_unscaled: 0.7539 (0.7375)  loss_bbox_enc_unscaled: 0.0156 (0.0489)  loss_giou_enc_unscaled: 0.4516 (0.5893)  cardinality_error_enc_unscaled: 78.0000 (193.1148)  time: 3.2614  data: 0.0096  max mem: 20087
# Epoch: [0]  [ 70/759]  eta: 0:38:25  lr: 0.001000  class_error: 0.00  loss: 6.7778 (8.1851)  loss_ce: 0.7477 (0.7335)  loss_bbox: 0.0570 (0.2122)  loss_giou: 0.8148 (1.0708)  loss_ce_0: 0.8042 (0.7782)  loss_bbox_0: 0.0609 (0.2124)  loss_giou_0: 0.8263 (1.0609)  loss_ce_1: 0.7560 (0.7343)  loss_bbox_1: 0.0576 (0.2130)  loss_giou_1: 0.8100 (1.0703)  loss_ce_enc: 0.7442 (0.7482)  loss_bbox_enc: 0.0638 (0.2202)  loss_giou_enc: 0.8775 (1.1311)  loss_ce_unscaled: 0.7477 (0.7335)  class_error_unscaled: 0.0000 (0.0016)  loss_bbox_unscaled: 0.0114 (0.0424)  loss_giou_unscaled: 0.4074 (0.5354)  cardinality_error_unscaled: 59.0000 (81.7746)  loss_ce_0_unscaled: 0.8042 (0.7782)  loss_bbox_0_unscaled: 0.0122 (0.0425)  loss_giou_0_unscaled: 0.4131 (0.5305)  cardinality_error_0_unscaled: 59.0000 (81.9014)  loss_ce_1_unscaled: 0.7560 (0.7343)  loss_bbox_1_unscaled: 0.0115 (0.0426)  loss_giou_1_unscaled: 0.4050 (0.5352)  cardinality_error_1_unscaled: 59.0000 (148.0141)  loss_ce_enc_unscaled: 0.7442 (0.7482)  loss_bbox_enc_unscaled: 0.0128 (0.0440)  loss_giou_enc_unscaled: 0.4387 (0.5655)  cardinality_error_enc_unscaled: 59.0000 (177.7324)  time: 3.2582  data: 0.0097  max mem: 20087
# Epoch: [0]  [ 80/759]  eta: 0:37:40  lr: 0.001000  class_error: 0.00  loss: 6.5981 (7.9827)  loss_ce: 0.7678 (0.7394)  loss_bbox: 0.0550 (0.1938)  loss_giou: 0.7767 (1.0329)  loss_ce_0: 0.8153 (0.7829)  loss_bbox_0: 0.0509 (0.1939)  loss_giou_0: 0.7610 (1.0232)  loss_ce_1: 0.7746 (0.7435)  loss_bbox_1: 0.0540 (0.1942)  loss_giou_1: 0.7888 (1.0315)  loss_ce_enc: 0.7382 (0.7500)  loss_bbox_enc: 0.0624 (0.2019)  loss_giou_enc: 0.8465 (1.0957)  loss_ce_unscaled: 0.7678 (0.7394)  class_error_unscaled: 0.0000 (0.0014)  loss_bbox_unscaled: 0.0110 (0.0388)  loss_giou_unscaled: 0.3883 (0.5164)  cardinality_error_unscaled: 47.0000 (78.2840)  loss_ce_0_unscaled: 0.8153 (0.7829)  loss_bbox_0_unscaled: 0.0102 (0.0388)  loss_giou_0_unscaled: 0.3805 (0.5116)  cardinality_error_0_unscaled: 47.0000 (78.3951)  loss_ce_1_unscaled: 0.7746 (0.7435)  loss_bbox_1_unscaled: 0.0108 (0.0388)  loss_giou_1_unscaled: 0.3944 (0.5157)  cardinality_error_1_unscaled: 47.0000 (136.3457)  loss_ce_enc_unscaled: 0.7382 (0.7500)  loss_bbox_enc_unscaled: 0.0125 (0.0404)  loss_giou_enc_unscaled: 0.4232 (0.5479)  cardinality_error_enc_unscaled: 47.0000 (162.3951)  time: 3.2290  data: 0.0097  max mem: 20087
# Epoch: [0]  [ 90/759]  eta: 0:36:55  lr: 0.001000  class_error: 0.00  loss: 6.4728 (7.8362)  loss_ce: 0.7678 (0.7441)  loss_bbox: 0.0574 (0.1794)  loss_giou: 0.7614 (1.0047)  loss_ce_0: 0.7975 (0.7875)  loss_bbox_0: 0.0549 (0.1796)  loss_giou_0: 0.7545 (0.9978)  loss_ce_1: 0.7877 (0.7491)  loss_bbox_1: 0.0544 (0.1797)  loss_giou_1: 0.7800 (1.0040)  loss_ce_enc: 0.7295 (0.7494)  loss_bbox_enc: 0.0648 (0.1874)  loss_giou_enc: 0.8583 (1.0734)  loss_ce_unscaled: 0.7678 (0.7441)  class_error_unscaled: 0.0000 (0.0013)  loss_bbox_unscaled: 0.0115 (0.0359)  loss_giou_unscaled: 0.3807 (0.5023)  cardinality_error_unscaled: 47.0000 (78.3187)  loss_ce_0_unscaled: 0.7975 (0.7875)  loss_bbox_0_unscaled: 0.0110 (0.0359)  loss_giou_0_unscaled: 0.3773 (0.4989)  cardinality_error_0_unscaled: 47.0000 (78.4176)  loss_ce_1_unscaled: 0.7877 (0.7491)  loss_bbox_1_unscaled: 0.0109 (0.0359)  loss_giou_1_unscaled: 0.3900 (0.5020)  cardinality_error_1_unscaled: 47.0000 (130.0000)  loss_ce_enc_unscaled: 0.7295 (0.7494)  loss_bbox_enc_unscaled: 0.0130 (0.0375)  loss_giou_enc_unscaled: 0.4291 (0.5367)  cardinality_error_enc_unscaled: 47.0000 (153.1868)  time: 3.1922  data: 0.0096  max mem: 20087
# Epoch: [0]  [100/759]  eta: 0:36:18  lr: 0.001000  class_error: 0.00  loss: 6.4728 (7.7421)  loss_ce: 0.7498 (0.7445)  loss_bbox: 0.0589 (0.1713)  loss_giou: 0.7666 (0.9874)  loss_ce_0: 0.7871 (0.7891)  loss_bbox_0: 0.0521 (0.1719)  loss_giou_0: 0.7545 (0.9798)  loss_ce_1: 0.7653 (0.7505)  loss_bbox_1: 0.0596 (0.1715)  loss_giou_1: 0.7905 (0.9867)  loss_ce_enc: 0.7269 (0.7487)  loss_bbox_enc: 0.0676 (0.1810)  loss_giou_enc: 0.8923 (1.0597)  loss_ce_unscaled: 0.7498 (0.7445)  class_error_unscaled: 0.0000 (0.0011)  loss_bbox_unscaled: 0.0118 (0.0343)  loss_giou_unscaled: 0.3833 (0.4937)  cardinality_error_unscaled: 41.0000 (76.3762)  loss_ce_0_unscaled: 0.7871 (0.7891)  loss_bbox_0_unscaled: 0.0104 (0.0344)  loss_giou_0_unscaled: 0.3773 (0.4899)  cardinality_error_0_unscaled: 41.0000 (76.4653)  loss_ce_1_unscaled: 0.7653 (0.7505)  loss_bbox_1_unscaled: 0.0119 (0.0343)  loss_giou_1_unscaled: 0.3952 (0.4933)  cardinality_error_1_unscaled: 41.0000 (122.9406)  loss_ce_enc_unscaled: 0.7269 (0.7487)  loss_bbox_enc_unscaled: 0.0135 (0.0362)  loss_giou_enc_unscaled: 0.4461 (0.5298)  cardinality_error_enc_unscaled: 50.0000 (145.2673)  time: 3.2091  data: 0.0096  max mem: 20087
# Epoch: [0]  [110/759]  eta: 0:35:38  lr: 0.001000  class_error: 0.00  loss: 6.4364 (7.6159)  loss_ce: 0.7316 (0.7428)  loss_bbox: 0.0611 (0.1618)  loss_giou: 0.8103 (0.9685)  loss_ce_0: 0.7621 (0.7856)  loss_bbox_0: 0.0584 (0.1624)  loss_giou_0: 0.7964 (0.9605)  loss_ce_1: 0.7284 (0.7478)  loss_bbox_1: 0.0647 (0.1622)  loss_giou_1: 0.7914 (0.9662)  loss_ce_enc: 0.7272 (0.7464)  loss_bbox_enc: 0.0676 (0.1718)  loss_giou_enc: 0.8668 (1.0399)  loss_ce_unscaled: 0.7316 (0.7428)  class_error_unscaled: 0.0000 (0.0010)  loss_bbox_unscaled: 0.0122 (0.0324)  loss_giou_unscaled: 0.4051 (0.4842)  cardinality_error_unscaled: 41.0000 (77.6396)  loss_ce_0_unscaled: 0.7621 (0.7856)  loss_bbox_0_unscaled: 0.0117 (0.0325)  loss_giou_0_unscaled: 0.3982 (0.4803)  cardinality_error_0_unscaled: 41.0000 (77.7207)  loss_ce_1_unscaled: 0.7284 (0.7478)  loss_bbox_1_unscaled: 0.0129 (0.0324)  loss_giou_1_unscaled: 0.3957 (0.4831)  cardinality_error_1_unscaled: 41.0000 (120.0090)  loss_ce_enc_unscaled: 0.7272 (0.7464)  loss_bbox_enc_unscaled: 0.0135 (0.0344)  loss_giou_enc_unscaled: 0.4334 (0.5199)  cardinality_error_enc_unscaled: 50.0000 (140.3243)  time: 3.2224  data: 0.0097  max mem: 20087
# Epoch: [0]  [120/759]  eta: 0:35:05  lr: 0.001000  class_error: 0.00  loss: 6.1183 (7.4851)  loss_ce: 0.7181 (0.7416)  loss_bbox: 0.0613 (0.1532)  loss_giou: 0.7423 (0.9488)  loss_ce_0: 0.7334 (0.7815)  loss_bbox_0: 0.0584 (0.1536)  loss_giou_0: 0.7142 (0.9384)  loss_ce_1: 0.7160 (0.7459)  loss_bbox_1: 0.0632 (0.1535)  loss_giou_1: 0.7531 (0.9452)  loss_ce_enc: 0.7155 (0.7428)  loss_bbox_enc: 0.0640 (0.1629)  loss_giou_enc: 0.7865 (1.0177)  loss_ce_unscaled: 0.7181 (0.7416)  class_error_unscaled: 0.0000 (0.0009)  loss_bbox_unscaled: 0.0123 (0.0306)  loss_giou_unscaled: 0.3711 (0.4744)  cardinality_error_unscaled: 67.0000 (77.8843)  loss_ce_0_unscaled: 0.7334 (0.7815)  loss_bbox_0_unscaled: 0.0117 (0.0307)  loss_giou_0_unscaled: 0.3571 (0.4692)  cardinality_error_0_unscaled: 67.0000 (77.9587)  loss_ce_1_unscaled: 0.7160 (0.7459)  loss_bbox_1_unscaled: 0.0126 (0.0307)  loss_giou_1_unscaled: 0.3765 (0.4726)  cardinality_error_1_unscaled: 67.0000 (116.7521)  loss_ce_enc_unscaled: 0.7155 (0.7428)  loss_bbox_enc_unscaled: 0.0128 (0.0326)  loss_giou_enc_unscaled: 0.3933 (0.5089)  cardinality_error_enc_unscaled: 67.0000 (135.3884)  time: 3.2420  data: 0.0095  max mem: 20087
# Epoch: [0]  [130/759]  eta: 0:34:23  lr: 0.001000  class_error: 0.00  loss: 6.1323 (7.4071)  loss_ce: 0.7236 (0.7455)  loss_bbox: 0.0522 (0.1456)  loss_giou: 0.7423 (0.9350)  loss_ce_0: 0.7360 (0.7850)  loss_bbox_0: 0.0526 (0.1459)  loss_giou_0: 0.7065 (0.9244)  loss_ce_1: 0.7193 (0.7478)  loss_bbox_1: 0.0516 (0.1458)  loss_giou_1: 0.7432 (0.9316)  loss_ce_enc: 0.7003 (0.7426)  loss_bbox_enc: 0.0577 (0.1549)  loss_giou_enc: 0.7795 (1.0029)  loss_ce_unscaled: 0.7236 (0.7455)  class_error_unscaled: 0.0000 (0.0009)  loss_bbox_unscaled: 0.0104 (0.0291)  loss_giou_unscaled: 0.3711 (0.4675)  cardinality_error_unscaled: 67.0000 (80.2748)  loss_ce_0_unscaled: 0.7360 (0.7850)  loss_bbox_0_unscaled: 0.0105 (0.0292)  loss_giou_0_unscaled: 0.3533 (0.4622)  cardinality_error_0_unscaled: 67.0000 (80.3435)  loss_ce_1_unscaled: 0.7193 (0.7478)  loss_bbox_1_unscaled: 0.0103 (0.0292)  loss_giou_1_unscaled: 0.3716 (0.4658)  cardinality_error_1_unscaled: 67.0000 (116.1756)  loss_ce_enc_unscaled: 0.7003 (0.7426)  loss_bbox_enc_unscaled: 0.0115 (0.0310)  loss_giou_enc_unscaled: 0.3898 (0.5014)  cardinality_error_enc_unscaled: 67.0000 (133.3893)  time: 3.1978  data: 0.0094  max mem: 20087
# Epoch: [0]  [140/759]  eta: 0:33:46  lr: 0.001000  class_error: 0.00  loss: 6.1323 (7.3121)  loss_ce: 0.7236 (0.7462)  loss_bbox: 0.0451 (0.1389)  loss_giou: 0.6987 (0.9163)  loss_ce_0: 0.7608 (0.7860)  loss_bbox_0: 0.0460 (0.1390)  loss_giou_0: 0.6679 (0.9060)  loss_ce_1: 0.7171 (0.7499)  loss_bbox_1: 0.0435 (0.1390)  loss_giou_1: 0.7189 (0.9128)  loss_ce_enc: 0.7305 (0.7446)  loss_bbox_enc: 0.0535 (0.1481)  loss_giou_enc: 0.7831 (0.9853)  loss_ce_unscaled: 0.7236 (0.7462)  class_error_unscaled: 0.0000 (0.0008)  loss_bbox_unscaled: 0.0090 (0.0278)  loss_giou_unscaled: 0.3493 (0.4581)  cardinality_error_unscaled: 32.0000 (77.5319)  loss_ce_0_unscaled: 0.7608 (0.7860)  loss_bbox_0_unscaled: 0.0092 (0.0278)  loss_giou_0_unscaled: 0.3339 (0.4530)  cardinality_error_0_unscaled: 32.0000 (77.5957)  loss_ce_1_unscaled: 0.7171 (0.7499)  loss_bbox_1_unscaled: 0.0087 (0.0278)  loss_giou_1_unscaled: 0.3594 (0.4564)  cardinality_error_1_unscaled: 32.0000 (110.8865)  loss_ce_enc_unscaled: 0.7305 (0.7446)  loss_bbox_enc_unscaled: 0.0107 (0.0296)  loss_giou_enc_unscaled: 0.3916 (0.4927)  cardinality_error_enc_unscaled: 32.0000 (126.8794)  time: 3.1431  data: 0.0095  max mem: 20087
# Epoch: [0]  [150/759]  eta: 0:33:10  lr: 0.001000  class_error: 0.00  loss: 6.0990 (7.2547)  loss_ce: 0.7086 (0.7441)  loss_bbox: 0.0537 (0.1346)  loss_giou: 0.7096 (0.9091)  loss_ce_0: 0.7282 (0.7817)  loss_bbox_0: 0.0478 (0.1347)  loss_giou_0: 0.7244 (0.8994)  loss_ce_1: 0.7086 (0.7474)  loss_bbox_1: 0.0520 (0.1347)  loss_giou_1: 0.7146 (0.9062)  loss_ce_enc: 0.7175 (0.7426)  loss_bbox_enc: 0.0613 (0.1436)  loss_giou_enc: 0.7831 (0.9767)  loss_ce_unscaled: 0.7086 (0.7441)  class_error_unscaled: 0.0000 (0.0008)  loss_bbox_unscaled: 0.0107 (0.0269)  loss_giou_unscaled: 0.3548 (0.4546)  cardinality_error_unscaled: 40.0000 (77.4172)  loss_ce_0_unscaled: 0.7282 (0.7817)  loss_bbox_0_unscaled: 0.0096 (0.0269)  loss_giou_0_unscaled: 0.3622 (0.4497)  cardinality_error_0_unscaled: 40.0000 (77.4768)  loss_ce_1_unscaled: 0.7086 (0.7474)  loss_bbox_1_unscaled: 0.0104 (0.0269)  loss_giou_1_unscaled: 0.3573 (0.4531)  cardinality_error_1_unscaled: 40.0000 (108.5629)  loss_ce_enc_unscaled: 0.7175 (0.7426)  loss_bbox_enc_unscaled: 0.0123 (0.0287)  loss_giou_enc_unscaled: 0.3916 (0.4883)  cardinality_error_enc_unscaled: 40.0000 (123.4967)  time: 3.1849  data: 0.0095  max mem: 20087
# Epoch: [0]  [160/759]  eta: 0:32:35  lr: 0.001000  class_error: 0.00  loss: 6.0860 (7.1613)  loss_ce: 0.7014 (0.7396)  loss_bbox: 0.0606 (0.1294)  loss_giou: 0.7096 (0.8954)  loss_ce_0: 0.7098 (0.7761)  loss_bbox_0: 0.0576 (0.1295)  loss_giou_0: 0.7205 (0.8867)  loss_ce_1: 0.6969 (0.7429)  loss_bbox_1: 0.0590 (0.1296)  loss_giou_1: 0.7145 (0.8927)  loss_ce_enc: 0.7046 (0.7393)  loss_bbox_enc: 0.0657 (0.1381)  loss_giou_enc: 0.7810 (0.9620)  loss_ce_unscaled: 0.7014 (0.7396)  class_error_unscaled: 0.0000 (0.0007)  loss_bbox_unscaled: 0.0121 (0.0259)  loss_giou_unscaled: 0.3548 (0.4477)  cardinality_error_unscaled: 71.0000 (78.8634)  loss_ce_0_unscaled: 0.7098 (0.7761)  loss_bbox_0_unscaled: 0.0115 (0.0259)  loss_giou_0_unscaled: 0.3603 (0.4434)  cardinality_error_0_unscaled: 71.0000 (78.9193)  loss_ce_1_unscaled: 0.6969 (0.7429)  loss_bbox_1_unscaled: 0.0118 (0.0259)  loss_giou_1_unscaled: 0.3572 (0.4463)  cardinality_error_1_unscaled: 71.0000 (108.0745)  loss_ce_enc_unscaled: 0.7046 (0.7393)  loss_bbox_enc_unscaled: 0.0131 (0.0276)  loss_giou_enc_unscaled: 0.3905 (0.4810)  cardinality_error_enc_unscaled: 71.0000 (122.0807)  time: 3.1980  data: 0.0095  max mem: 20087
# Epoch: [0]  [170/759]  eta: 0:32:03  lr: 0.001000  class_error: 0.00  loss: 5.7764 (7.0763)  loss_ce: 0.6920 (0.7368)  loss_bbox: 0.0454 (0.1244)  loss_giou: 0.6542 (0.8825)  loss_ce_0: 0.7114 (0.7726)  loss_bbox_0: 0.0433 (0.1245)  loss_giou_0: 0.6462 (0.8737)  loss_ce_1: 0.6923 (0.7402)  loss_bbox_1: 0.0449 (0.1246)  loss_giou_1: 0.6448 (0.8799)  loss_ce_enc: 0.6955 (0.7368)  loss_bbox_enc: 0.0496 (0.1330)  loss_giou_enc: 0.7039 (0.9472)  loss_ce_unscaled: 0.6920 (0.7368)  class_error_unscaled: 0.0000 (0.0007)  loss_bbox_unscaled: 0.0091 (0.0249)  loss_giou_unscaled: 0.3271 (0.4413)  cardinality_error_unscaled: 53.0000 (78.2105)  loss_ce_0_unscaled: 0.7114 (0.7726)  loss_bbox_0_unscaled: 0.0087 (0.0249)  loss_giou_0_unscaled: 0.3231 (0.4369)  cardinality_error_0_unscaled: 53.0000 (78.2632)  loss_ce_1_unscaled: 0.6923 (0.7402)  loss_bbox_1_unscaled: 0.0090 (0.0249)  loss_giou_1_unscaled: 0.3224 (0.4399)  cardinality_error_1_unscaled: 53.0000 (105.7135)  loss_ce_enc_unscaled: 0.6955 (0.7368)  loss_bbox_enc_unscaled: 0.0099 (0.0266)  loss_giou_enc_unscaled: 0.3519 (0.4736)  cardinality_error_enc_unscaled: 53.0000 (118.9006)  time: 3.2422  data: 0.0095  max mem: 20087
# Epoch: [0]  [180/759]  eta: 0:31:26  lr: 0.001000  class_error: -0.00  loss: 5.7764 (7.0176)  loss_ce: 0.7144 (0.7359)  loss_bbox: 0.0426 (0.1208)  loss_giou: 0.6542 (0.8727)  loss_ce_0: 0.7239 (0.7711)  loss_bbox_0: 0.0416 (0.1207)  loss_giou_0: 0.6685 (0.8640)  loss_ce_1: 0.7163 (0.7391)  loss_bbox_1: 0.0426 (0.1207)  loss_giou_1: 0.6602 (0.8696)  loss_ce_enc: 0.7193 (0.7362)  loss_bbox_enc: 0.0454 (0.1293)  loss_giou_enc: 0.7093 (0.9374)  loss_ce_unscaled: 0.7144 (0.7359)  class_error_unscaled: 0.0000 (0.0006)  loss_bbox_unscaled: 0.0085 (0.0242)  loss_giou_unscaled: 0.3271 (0.4364)  cardinality_error_unscaled: 33.0000 (75.4862)  loss_ce_0_unscaled: 0.7239 (0.7711)  loss_bbox_0_unscaled: 0.0083 (0.0241)  loss_giou_0_unscaled: 0.3342 (0.4320)  cardinality_error_0_unscaled: 33.0000 (75.5359)  loss_ce_1_unscaled: 0.7163 (0.7391)  loss_bbox_1_unscaled: 0.0085 (0.0241)  loss_giou_1_unscaled: 0.3301 (0.4348)  cardinality_error_1_unscaled: 33.0000 (101.4696)  loss_ce_enc_unscaled: 0.7193 (0.7362)  loss_bbox_enc_unscaled: 0.0091 (0.0259)  loss_giou_enc_unscaled: 0.3546 (0.4687)  cardinality_error_enc_unscaled: 34.0000 (114.0994)  time: 3.2165  data: 0.0095  max mem: 20087
# Epoch: [0]  [190/759]  eta: 0:30:53  lr: 0.001000  class_error: 0.00  loss: 5.9347 (6.9537)  loss_ce: 0.7103 (0.7331)  loss_bbox: 0.0426 (0.1173)  loss_giou: 0.6754 (0.8629)  loss_ce_0: 0.7254 (0.7672)  loss_bbox_0: 0.0439 (0.1172)  loss_giou_0: 0.6778 (0.8545)  loss_ce_1: 0.7115 (0.7358)  loss_bbox_1: 0.0433 (0.1172)  loss_giou_1: 0.6613 (0.8598)  loss_ce_enc: 0.7277 (0.7341)  loss_bbox_enc: 0.0527 (0.1257)  loss_giou_enc: 0.7371 (0.9289)  loss_ce_unscaled: 0.7103 (0.7331)  class_error_unscaled: 0.0000 (0.0006)  loss_bbox_unscaled: 0.0085 (0.0235)  loss_giou_unscaled: 0.3377 (0.4315)  cardinality_error_unscaled: 34.0000 (76.7435)  loss_ce_0_unscaled: 0.7254 (0.7672)  loss_bbox_0_unscaled: 0.0088 (0.0234)  loss_giou_0_unscaled: 0.3389 (0.4272)  cardinality_error_0_unscaled: 34.0000 (76.7906)  loss_ce_1_unscaled: 0.7115 (0.7358)  loss_bbox_1_unscaled: 0.0087 (0.0234)  loss_giou_1_unscaled: 0.3307 (0.4299)  cardinality_error_1_unscaled: 34.0000 (101.3665)  loss_ce_enc_unscaled: 0.7277 (0.7341)  loss_bbox_enc_unscaled: 0.0105 (0.0251)  loss_giou_enc_unscaled: 0.3686 (0.4644)  cardinality_error_enc_unscaled: 35.0000 (113.3351)  time: 3.1981  data: 0.0095  max mem: 20087
# Epoch: [0]  [200/759]  eta: 0:30:18  lr: 0.001000  class_error: 0.00  loss: 5.7888 (6.8983)  loss_ce: 0.6963 (0.7316)  loss_bbox: 0.0454 (0.1142)  loss_giou: 0.6525 (0.8534)  loss_ce_0: 0.7254 (0.7656)  loss_bbox_0: 0.0476 (0.1140)  loss_giou_0: 0.6529 (0.8450)  loss_ce_1: 0.7024 (0.7343)  loss_bbox_1: 0.0443 (0.1140)  loss_giou_1: 0.6494 (0.8504)  loss_ce_enc: 0.7256 (0.7334)  loss_bbox_enc: 0.0549 (0.1224)  loss_giou_enc: 0.7759 (0.9199)  loss_ce_unscaled: 0.6963 (0.7316)  class_error_unscaled: 0.0000 (0.0006)  loss_bbox_unscaled: 0.0091 (0.0228)  loss_giou_unscaled: 0.3263 (0.4267)  cardinality_error_unscaled: 58.0000 (75.9055)  loss_ce_0_unscaled: 0.7254 (0.7656)  loss_bbox_0_unscaled: 0.0095 (0.0228)  loss_giou_0_unscaled: 0.3264 (0.4225)  cardinality_error_0_unscaled: 58.0000 (75.9502)  loss_ce_1_unscaled: 0.7024 (0.7343)  loss_bbox_1_unscaled: 0.0089 (0.0228)  loss_giou_1_unscaled: 0.3247 (0.4252)  cardinality_error_1_unscaled: 58.0000 (99.3035)  loss_ce_enc_unscaled: 0.7256 (0.7334)  loss_bbox_enc_unscaled: 0.0110 (0.0245)  loss_giou_enc_unscaled: 0.3880 (0.4600)  cardinality_error_enc_unscaled: 58.0000 (110.6766)  time: 3.2009  data: 0.0096  max mem: 20087
# Epoch: [0]  [210/759]  eta: 0:29:43  lr: 0.001000  class_error: 0.00  loss: 5.7963 (6.8582)  loss_ce: 0.6963 (0.7316)  loss_bbox: 0.0445 (0.1116)  loss_giou: 0.6510 (0.8460)  loss_ce_0: 0.7255 (0.7650)  loss_bbox_0: 0.0448 (0.1113)  loss_giou_0: 0.6498 (0.8380)  loss_ce_1: 0.6977 (0.7344)  loss_bbox_1: 0.0444 (0.1115)  loss_giou_1: 0.6440 (0.8432)  loss_ce_enc: 0.7256 (0.7343)  loss_bbox_enc: 0.0546 (0.1196)  loss_giou_enc: 0.7319 (0.9119)  loss_ce_unscaled: 0.6963 (0.7316)  class_error_unscaled: 0.0000 (0.0005)  loss_bbox_unscaled: 0.0089 (0.0223)  loss_giou_unscaled: 0.3255 (0.4230)  cardinality_error_unscaled: 46.0000 (75.0284)  loss_ce_0_unscaled: 0.7255 (0.7650)  loss_bbox_0_unscaled: 0.0090 (0.0223)  loss_giou_0_unscaled: 0.3249 (0.4190)  cardinality_error_0_unscaled: 46.0000 (75.0711)  loss_ce_1_unscaled: 0.6977 (0.7344)  loss_bbox_1_unscaled: 0.0089 (0.0223)  loss_giou_1_unscaled: 0.3220 (0.4216)  cardinality_error_1_unscaled: 46.0000 (97.3175)  loss_ce_enc_unscaled: 0.7256 (0.7343)  loss_bbox_enc_unscaled: 0.0109 (0.0239)  loss_giou_enc_unscaled: 0.3659 (0.4559)  cardinality_error_enc_unscaled: 46.0000 (108.1517)  time: 3.1632  data: 0.0097  max mem: 20087
# Epoch: [0]  [220/759]  eta: 0:29:10  lr: 0.001000  class_error: 0.00  loss: 5.8069 (6.8162)  loss_ce: 0.6960 (0.7301)  loss_bbox: 0.0474 (0.1090)  loss_giou: 0.6918 (0.8403)  loss_ce_0: 0.7175 (0.7629)  loss_bbox_0: 0.0469 (0.1087)  loss_giou_0: 0.6844 (0.8320)  loss_ce_1: 0.6903 (0.7328)  loss_bbox_1: 0.0472 (0.1089)  loss_giou_1: 0.6872 (0.8376)  loss_ce_enc: 0.7104 (0.7335)  loss_bbox_enc: 0.0517 (0.1168)  loss_giou_enc: 0.7292 (0.9035)  loss_ce_unscaled: 0.6960 (0.7301)  class_error_unscaled: 0.0000 (0.0005)  loss_bbox_unscaled: 0.0095 (0.0218)  loss_giou_unscaled: 0.3459 (0.4202)  cardinality_error_unscaled: 39.0000 (75.2489)  loss_ce_0_unscaled: 0.7175 (0.7629)  loss_bbox_0_unscaled: 0.0094 (0.0217)  loss_giou_0_unscaled: 0.3422 (0.4160)  cardinality_error_0_unscaled: 39.0000 (75.2896)  loss_ce_1_unscaled: 0.6903 (0.7328)  loss_bbox_1_unscaled: 0.0094 (0.0218)  loss_giou_1_unscaled: 0.3436 (0.4188)  cardinality_error_1_unscaled: 39.0000 (96.5294)  loss_ce_enc_unscaled: 0.7104 (0.7335)  loss_bbox_enc_unscaled: 0.0103 (0.0234)  loss_giou_enc_unscaled: 0.3646 (0.4517)  cardinality_error_enc_unscaled: 39.0000 (106.8733)  time: 3.1862  data: 0.0097  max mem: 20087
# Epoch: [0]  [230/759]  eta: 0:28:36  lr: 0.001000  class_error: 0.00  loss: 5.9453 (6.7747)  loss_ce: 0.6947 (0.7281)  loss_bbox: 0.0478 (0.1067)  loss_giou: 0.7036 (0.8345)  loss_ce_0: 0.6974 (0.7602)  loss_bbox_0: 0.0471 (0.1065)  loss_giou_0: 0.6965 (0.8265)  loss_ce_1: 0.6868 (0.7305)  loss_bbox_1: 0.0488 (0.1067)  loss_giou_1: 0.7045 (0.8317)  loss_ce_enc: 0.7007 (0.7320)  loss_bbox_enc: 0.0577 (0.1145)  loss_giou_enc: 0.7297 (0.8969)  loss_ce_unscaled: 0.6947 (0.7281)  class_error_unscaled: 0.0000 (0.0005)  loss_bbox_unscaled: 0.0096 (0.0213)  loss_giou_unscaled: 0.3518 (0.4172)  cardinality_error_unscaled: 39.0000 (74.5108)  loss_ce_0_unscaled: 0.6974 (0.7602)  loss_bbox_0_unscaled: 0.0094 (0.0213)  loss_giou_0_unscaled: 0.3482 (0.4132)  cardinality_error_0_unscaled: 39.0000 (74.5498)  loss_ce_1_unscaled: 0.6868 (0.7305)  loss_bbox_1_unscaled: 0.0098 (0.0213)  loss_giou_1_unscaled: 0.3523 (0.4159)  cardinality_error_1_unscaled: 39.0000 (94.8701)  loss_ce_enc_unscaled: 0.7007 (0.7320)  loss_bbox_enc_unscaled: 0.0115 (0.0229)  loss_giou_enc_unscaled: 0.3648 (0.4485)  cardinality_error_enc_unscaled: 39.0000 (104.7662)  time: 3.2108  data: 0.0096  max mem: 20087
# Epoch: [0]  [240/759]  eta: 0:28:03  lr: 0.001000  class_error: -0.00  loss: 6.0095 (6.7517)  loss_ce: 0.6805 (0.7276)  loss_bbox: 0.0528 (0.1047)  loss_giou: 0.7211 (0.8310)  loss_ce_0: 0.7032 (0.7591)  loss_bbox_0: 0.0505 (0.1043)  loss_giou_0: 0.7110 (0.8223)  loss_ce_1: 0.6806 (0.7299)  loss_bbox_1: 0.0517 (0.1045)  loss_giou_1: 0.7193 (0.8276)  loss_ce_enc: 0.7007 (0.7320)  loss_bbox_enc: 0.0593 (0.1125)  loss_giou_enc: 0.7457 (0.8961)  loss_ce_unscaled: 0.6805 (0.7276)  class_error_unscaled: 0.0000 (0.0005)  loss_bbox_unscaled: 0.0106 (0.0209)  loss_giou_unscaled: 0.3605 (0.4155)  cardinality_error_unscaled: 52.0000 (73.9834)  loss_ce_0_unscaled: 0.7032 (0.7591)  loss_bbox_0_unscaled: 0.0101 (0.0209)  loss_giou_0_unscaled: 0.3555 (0.4111)  cardinality_error_0_unscaled: 52.0000 (74.0207)  loss_ce_1_unscaled: 0.6806 (0.7299)  loss_bbox_1_unscaled: 0.0103 (0.0209)  loss_giou_1_unscaled: 0.3596 (0.4138)  cardinality_error_1_unscaled: 52.0000 (93.4979)  loss_ce_enc_unscaled: 0.7007 (0.7320)  loss_bbox_enc_unscaled: 0.0119 (0.0225)  loss_giou_enc_unscaled: 0.3728 (0.4480)  cardinality_error_enc_unscaled: 52.0000 (102.9834)  time: 3.2012  data: 0.0096  max mem: 20087
# Epoch: [0]  [250/759]  eta: 0:27:27  lr: 0.001000  class_error: 0.00  loss: 6.0471 (6.7205)  loss_ce: 0.6825 (0.7270)  loss_bbox: 0.0490 (0.1028)  loss_giou: 0.7308 (0.8256)  loss_ce_0: 0.7152 (0.7583)  loss_bbox_0: 0.0509 (0.1025)  loss_giou_0: 0.6988 (0.8174)  loss_ce_1: 0.6865 (0.7298)  loss_bbox_1: 0.0527 (0.1027)  loss_giou_1: 0.7096 (0.8225)  loss_ce_enc: 0.7102 (0.7321)  loss_bbox_enc: 0.0541 (0.1104)  loss_giou_enc: 0.7805 (0.8896)  loss_ce_unscaled: 0.6825 (0.7270)  class_error_unscaled: 0.0000 (0.0005)  loss_bbox_unscaled: 0.0098 (0.0206)  loss_giou_unscaled: 0.3654 (0.4128)  cardinality_error_unscaled: 55.0000 (74.1952)  loss_ce_0_unscaled: 0.7152 (0.7583)  loss_bbox_0_unscaled: 0.0102 (0.0205)  loss_giou_0_unscaled: 0.3494 (0.4087)  cardinality_error_0_unscaled: 55.0000 (74.2311)  loss_ce_1_unscaled: 0.6865 (0.7298)  loss_bbox_1_unscaled: 0.0105 (0.0205)  loss_giou_1_unscaled: 0.3548 (0.4112)  cardinality_error_1_unscaled: 55.0000 (92.9323)  loss_ce_enc_unscaled: 0.7102 (0.7321)  loss_bbox_enc_unscaled: 0.0108 (0.0221)  loss_giou_enc_unscaled: 0.3902 (0.4448)  cardinality_error_enc_unscaled: 55.0000 (102.0398)  time: 3.1394  data: 0.0096  max mem: 20087
# Epoch: [0]  [260/759]  eta: 0:26:51  lr: 0.001000  class_error: 0.00  loss: 5.9104 (6.6897)  loss_ce: 0.7125 (0.7273)  loss_bbox: 0.0464 (0.1005)  loss_giou: 0.6848 (0.8201)  loss_ce_0: 0.7331 (0.7588)  loss_bbox_0: 0.0435 (0.1001)  loss_giou_0: 0.6894 (0.8120)  loss_ce_1: 0.7320 (0.7300)  loss_bbox_1: 0.0439 (0.1004)  loss_giou_1: 0.7006 (0.8171)  loss_ce_enc: 0.7094 (0.7313)  loss_bbox_enc: 0.0520 (0.1080)  loss_giou_enc: 0.7166 (0.8843)  loss_ce_unscaled: 0.7125 (0.7273)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0093 (0.0201)  loss_giou_unscaled: 0.3424 (0.4100)  cardinality_error_unscaled: 25.0000 (73.0690)  loss_ce_0_unscaled: 0.7331 (0.7588)  loss_bbox_0_unscaled: 0.0087 (0.0200)  loss_giou_0_unscaled: 0.3447 (0.4060)  cardinality_error_0_unscaled: 25.0000 (73.1034)  loss_ce_1_unscaled: 0.7320 (0.7300)  loss_bbox_1_unscaled: 0.0088 (0.0201)  loss_giou_1_unscaled: 0.3503 (0.4086)  cardinality_error_1_unscaled: 25.0000 (91.0881)  loss_ce_enc_unscaled: 0.7094 (0.7313)  loss_bbox_enc_unscaled: 0.0104 (0.0216)  loss_giou_enc_unscaled: 0.3583 (0.4421)  cardinality_error_enc_unscaled: 25.0000 (99.8467)  time: 3.0695  data: 0.0095  max mem: 20087
# Epoch: [0]  [270/759]  eta: 0:26:19  lr: 0.001000  class_error: 0.00  loss: 5.9104 (6.6678)  loss_ce: 0.7184 (0.7269)  loss_bbox: 0.0464 (0.0989)  loss_giou: 0.6848 (0.8171)  loss_ce_0: 0.7350 (0.7581)  loss_bbox_0: 0.0435 (0.0987)  loss_giou_0: 0.6882 (0.8088)  loss_ce_1: 0.7205 (0.7293)  loss_bbox_1: 0.0450 (0.0988)  loss_giou_1: 0.6996 (0.8139)  loss_ce_enc: 0.7033 (0.7302)  loss_bbox_enc: 0.0510 (0.1063)  loss_giou_enc: 0.7360 (0.8807)  loss_ce_unscaled: 0.7184 (0.7269)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0093 (0.0198)  loss_giou_unscaled: 0.3424 (0.4086)  cardinality_error_unscaled: 25.0000 (72.2546)  loss_ce_0_unscaled: 0.7350 (0.7581)  loss_bbox_0_unscaled: 0.0087 (0.0197)  loss_giou_0_unscaled: 0.3441 (0.4044)  cardinality_error_0_unscaled: 25.0000 (72.2878)  loss_ce_1_unscaled: 0.7205 (0.7293)  loss_bbox_1_unscaled: 0.0090 (0.0198)  loss_giou_1_unscaled: 0.3498 (0.4069)  cardinality_error_1_unscaled: 25.0000 (89.6089)  loss_ce_enc_unscaled: 0.7033 (0.7302)  loss_bbox_enc_unscaled: 0.0102 (0.0213)  loss_giou_enc_unscaled: 0.3680 (0.4403)  cardinality_error_enc_unscaled: 25.0000 (98.0443)  time: 3.1297  data: 0.0094  max mem: 20087
# Epoch: [0]  [280/759]  eta: 0:25:47  lr: 0.001000  class_error: 0.00  loss: 5.8049 (6.6329)  loss_ce: 0.7139 (0.7259)  loss_bbox: 0.0515 (0.0971)  loss_giou: 0.6723 (0.8116)  loss_ce_0: 0.7345 (0.7574)  loss_bbox_0: 0.0470 (0.0969)  loss_giou_0: 0.6524 (0.8027)  loss_ce_1: 0.7100 (0.7283)  loss_bbox_1: 0.0473 (0.0970)  loss_giou_1: 0.6736 (0.8081)  loss_ce_enc: 0.7085 (0.7292)  loss_bbox_enc: 0.0502 (0.1043)  loss_giou_enc: 0.7360 (0.8743)  loss_ce_unscaled: 0.7139 (0.7259)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0103 (0.0194)  loss_giou_unscaled: 0.3362 (0.4058)  cardinality_error_unscaled: 51.0000 (72.1708)  loss_ce_0_unscaled: 0.7345 (0.7574)  loss_bbox_0_unscaled: 0.0094 (0.0194)  loss_giou_0_unscaled: 0.3262 (0.4014)  cardinality_error_0_unscaled: 51.0000 (72.2028)  loss_ce_1_unscaled: 0.7100 (0.7283)  loss_bbox_1_unscaled: 0.0095 (0.0194)  loss_giou_1_unscaled: 0.3368 (0.4040)  cardinality_error_1_unscaled: 51.0000 (88.9075)  loss_ce_enc_unscaled: 0.7085 (0.7292)  loss_bbox_enc_unscaled: 0.0100 (0.0209)  loss_giou_enc_unscaled: 0.3680 (0.4372)  cardinality_error_enc_unscaled: 51.0000 (97.0427)  time: 3.2276  data: 0.0100  max mem: 20087
# Epoch: [0]  [290/759]  eta: 0:25:15  lr: 0.001000  class_error: 0.00  loss: 5.7270 (6.6082)  loss_ce: 0.7046 (0.7248)  loss_bbox: 0.0471 (0.0957)  loss_giou: 0.6600 (0.8078)  loss_ce_0: 0.7428 (0.7572)  loss_bbox_0: 0.0442 (0.0954)  loss_giou_0: 0.6554 (0.7993)  loss_ce_1: 0.6914 (0.7273)  loss_bbox_1: 0.0469 (0.0955)  loss_giou_1: 0.6472 (0.8044)  loss_ce_enc: 0.7044 (0.7280)  loss_bbox_enc: 0.0481 (0.1028)  loss_giou_enc: 0.7181 (0.8700)  loss_ce_unscaled: 0.7046 (0.7248)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0094 (0.0191)  loss_giou_unscaled: 0.3300 (0.4039)  cardinality_error_unscaled: 52.0000 (71.4880)  loss_ce_0_unscaled: 0.7428 (0.7572)  loss_bbox_0_unscaled: 0.0088 (0.0191)  loss_giou_0_unscaled: 0.3277 (0.3996)  cardinality_error_0_unscaled: 52.0000 (71.5189)  loss_ce_1_unscaled: 0.6914 (0.7273)  loss_bbox_1_unscaled: 0.0094 (0.0191)  loss_giou_1_unscaled: 0.3236 (0.4022)  cardinality_error_1_unscaled: 52.0000 (87.6495)  loss_ce_enc_unscaled: 0.7044 (0.7280)  loss_bbox_enc_unscaled: 0.0096 (0.0206)  loss_giou_enc_unscaled: 0.3591 (0.4350)  cardinality_error_enc_unscaled: 52.0000 (95.5052)  time: 3.2480  data: 0.0099  max mem: 20087
# Epoch: [0]  [300/759]  eta: 0:24:41  lr: 0.001000  class_error: -0.00  loss: 5.8560 (6.5895)  loss_ce: 0.7132 (0.7251)  loss_bbox: 0.0445 (0.0941)  loss_giou: 0.7246 (0.8046)  loss_ce_0: 0.7343 (0.7561)  loss_bbox_0: 0.0442 (0.0939)  loss_giou_0: 0.6980 (0.7964)  loss_ce_1: 0.7175 (0.7273)  loss_bbox_1: 0.0456 (0.0941)  loss_giou_1: 0.7260 (0.8012)  loss_ce_enc: 0.6945 (0.7276)  loss_bbox_enc: 0.0481 (0.1014)  loss_giou_enc: 0.7760 (0.8676)  loss_ce_unscaled: 0.7132 (0.7251)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0089 (0.0188)  loss_giou_unscaled: 0.3623 (0.4023)  cardinality_error_unscaled: 52.0000 (71.4718)  loss_ce_0_unscaled: 0.7343 (0.7561)  loss_bbox_0_unscaled: 0.0088 (0.0188)  loss_giou_0_unscaled: 0.3490 (0.3982)  cardinality_error_0_unscaled: 52.0000 (71.5017)  loss_ce_1_unscaled: 0.7175 (0.7273)  loss_bbox_1_unscaled: 0.0091 (0.0188)  loss_giou_1_unscaled: 0.3630 (0.4006)  cardinality_error_1_unscaled: 52.0000 (87.0963)  loss_ce_enc_unscaled: 0.6945 (0.7276)  loss_bbox_enc_unscaled: 0.0096 (0.0203)  loss_giou_enc_unscaled: 0.3880 (0.4338)  cardinality_error_enc_unscaled: 52.0000 (94.6910)  time: 3.2000  data: 0.0096  max mem: 20087
# Epoch: [0]  [310/759]  eta: 0:24:10  lr: 0.001000  class_error: -0.00  loss: 5.9858 (6.5691)  loss_ce: 0.7161 (0.7250)  loss_bbox: 0.0433 (0.0928)  loss_giou: 0.6859 (0.8007)  loss_ce_0: 0.7213 (0.7562)  loss_bbox_0: 0.0412 (0.0925)  loss_giou_0: 0.6934 (0.7934)  loss_ce_1: 0.7224 (0.7274)  loss_bbox_1: 0.0415 (0.0927)  loss_giou_1: 0.6805 (0.7975)  loss_ce_enc: 0.7058 (0.7277)  loss_bbox_enc: 0.0478 (0.0999)  loss_giou_enc: 0.7573 (0.8632)  loss_ce_unscaled: 0.7161 (0.7250)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0087 (0.0186)  loss_giou_unscaled: 0.3430 (0.4004)  cardinality_error_unscaled: 68.0000 (71.6399)  loss_ce_0_unscaled: 0.7213 (0.7562)  loss_bbox_0_unscaled: 0.0082 (0.0185)  loss_giou_0_unscaled: 0.3467 (0.3967)  cardinality_error_0_unscaled: 68.0000 (71.6688)  loss_ce_1_unscaled: 0.7224 (0.7274)  loss_bbox_1_unscaled: 0.0083 (0.0185)  loss_giou_1_unscaled: 0.3402 (0.3988)  cardinality_error_1_unscaled: 68.0000 (86.7621)  loss_ce_enc_unscaled: 0.7058 (0.7277)  loss_bbox_enc_unscaled: 0.0096 (0.0200)  loss_giou_enc_unscaled: 0.3786 (0.4316)  cardinality_error_enc_unscaled: 68.0000 (94.1125)  time: 3.2247  data: 0.0096  max mem: 20087
# Epoch: [0]  [320/759]  eta: 0:23:37  lr: 0.001000  class_error: 0.00  loss: 6.0263 (6.5531)  loss_ce: 0.7105 (0.7250)  loss_bbox: 0.0541 (0.0917)  loss_giou: 0.6942 (0.7976)  loss_ce_0: 0.7348 (0.7562)  loss_bbox_0: 0.0517 (0.0914)  loss_giou_0: 0.6812 (0.7902)  loss_ce_1: 0.7220 (0.7278)  loss_bbox_1: 0.0534 (0.0916)  loss_giou_1: 0.6965 (0.7948)  loss_ce_enc: 0.7103 (0.7274)  loss_bbox_enc: 0.0555 (0.0988)  loss_giou_enc: 0.7573 (0.8605)  loss_ce_unscaled: 0.7105 (0.7250)  class_error_unscaled: 0.0000 (0.0004)  loss_bbox_unscaled: 0.0108 (0.0183)  loss_giou_unscaled: 0.3471 (0.3988)  cardinality_error_unscaled: 49.0000 (71.0592)  loss_ce_0_unscaled: 0.7348 (0.7562)  loss_bbox_0_unscaled: 0.0103 (0.0183)  loss_giou_0_unscaled: 0.3406 (0.3951)  cardinality_error_0_unscaled: 49.0000 (71.0872)  loss_ce_1_unscaled: 0.7220 (0.7278)  loss_bbox_1_unscaled: 0.0107 (0.0183)  loss_giou_1_unscaled: 0.3483 (0.3974)  cardinality_error_1_unscaled: 49.0000 (85.7103)  loss_ce_enc_unscaled: 0.7103 (0.7274)  loss_bbox_enc_unscaled: 0.0111 (0.0198)  loss_giou_enc_unscaled: 0.3786 (0.4303)  cardinality_error_enc_unscaled: 49.0000 (92.8318)  time: 3.2470  data: 0.0094  max mem: 20087
# Epoch: [0]  [330/759]  eta: 0:23:05  lr: 0.001000  class_error: 0.00  loss: 6.0263 (6.5298)  loss_ce: 0.7105 (0.7248)  loss_bbox: 0.0441 (0.0904)  loss_giou: 0.6825 (0.7933)  loss_ce_0: 0.7505 (0.7569)  loss_bbox_0: 0.0507 (0.0902)  loss_giou_0: 0.6882 (0.7859)  loss_ce_1: 0.7218 (0.7279)  loss_bbox_1: 0.0467 (0.0904)  loss_giou_1: 0.6965 (0.7906)  loss_ce_enc: 0.7044 (0.7264)  loss_bbox_enc: 0.0470 (0.0975)  loss_giou_enc: 0.7447 (0.8555)  loss_ce_unscaled: 0.7105 (0.7248)  class_error_unscaled: 0.0000 (0.0003)  loss_bbox_unscaled: 0.0088 (0.0181)  loss_giou_unscaled: 0.3412 (0.3966)  cardinality_error_unscaled: 41.0000 (70.2870)  loss_ce_0_unscaled: 0.7505 (0.7569)  loss_bbox_0_unscaled: 0.0101 (0.0180)  loss_giou_0_unscaled: 0.3441 (0.3930)  cardinality_error_0_unscaled: 41.0000 (70.3142)  loss_ce_1_unscaled: 0.7218 (0.7279)  loss_bbox_1_unscaled: 0.0093 (0.0181)  loss_giou_1_unscaled: 0.3483 (0.3953)  cardinality_error_1_unscaled: 41.0000 (84.4955)  loss_ce_enc_unscaled: 0.7044 (0.7264)  loss_bbox_enc_unscaled: 0.0094 (0.0195)  loss_giou_enc_unscaled: 0.3724 (0.4277)  cardinality_error_enc_unscaled: 41.0000 (91.4018)  time: 3.2267  data: 0.0094  max mem: 20087
# Epoch: [0]  [340/759]  eta: 0:22:33  lr: 0.001000  class_error: 0.00  loss: 5.8803 (6.5144)  loss_ce: 0.7002 (0.7244)  loss_bbox: 0.0466 (0.0898)  loss_giou: 0.6712 (0.7908)  loss_ce_0: 0.7252 (0.7556)  loss_bbox_0: 0.0507 (0.0896)  loss_giou_0: 0.6580 (0.7835)  loss_ce_1: 0.6948 (0.7273)  loss_bbox_1: 0.0497 (0.0898)  loss_giou_1: 0.6813 (0.7881)  loss_ce_enc: 0.6916 (0.7257)  loss_bbox_enc: 0.0543 (0.0970)  loss_giou_enc: 0.7307 (0.8528)  loss_ce_unscaled: 0.7002 (0.7244)  class_error_unscaled: 0.0000 (0.0003)  loss_bbox_unscaled: 0.0093 (0.0180)  loss_giou_unscaled: 0.3356 (0.3954)  cardinality_error_unscaled: 39.0000 (70.7390)  loss_ce_0_unscaled: 0.7252 (0.7556)  loss_bbox_0_unscaled: 0.0101 (0.0179)  loss_giou_0_unscaled: 0.3290 (0.3917)  cardinality_error_0_unscaled: 39.0000 (70.7654)  loss_ce_1_unscaled: 0.6948 (0.7273)  loss_bbox_1_unscaled: 0.0099 (0.0180)  loss_giou_1_unscaled: 0.3406 (0.3941)  cardinality_error_1_unscaled: 39.0000 (84.5308)  loss_ce_enc_unscaled: 0.6916 (0.7257)  loss_bbox_enc_unscaled: 0.0109 (0.0194)  loss_giou_enc_unscaled: 0.3653 (0.4264)  cardinality_error_enc_unscaled: 39.0000 (91.2346)  time: 3.2376  data: 0.0099  max mem: 20087
# Epoch: [0]  [350/759]  eta: 0:22:00  lr: 0.001000  class_error: 0.00  loss: 6.0984 (6.5040)  loss_ce: 0.7126 (0.7243)  loss_bbox: 0.0523 (0.0889)  loss_giou: 0.7173 (0.7896)  loss_ce_0: 0.7081 (0.7545)  loss_bbox_0: 0.0515 (0.0886)  loss_giou_0: 0.6971 (0.7821)  loss_ce_1: 0.7030 (0.7265)  loss_bbox_1: 0.0530 (0.0888)  loss_giou_1: 0.7080 (0.7869)  loss_ce_enc: 0.6910 (0.7250)  loss_bbox_enc: 0.0626 (0.0961)  loss_giou_enc: 0.8093 (0.8528)  loss_ce_unscaled: 0.7126 (0.7243)  class_error_unscaled: 0.0000 (0.0003)  loss_bbox_unscaled: 0.0105 (0.0178)  loss_giou_unscaled: 0.3587 (0.3948)  cardinality_error_unscaled: 58.0000 (70.6638)  loss_ce_0_unscaled: 0.7081 (0.7545)  loss_bbox_0_unscaled: 0.0103 (0.0177)  loss_giou_0_unscaled: 0.3485 (0.3910)  cardinality_error_0_unscaled: 58.0000 (70.6895)  loss_ce_1_unscaled: 0.7030 (0.7265)  loss_bbox_1_unscaled: 0.0106 (0.0178)  loss_giou_1_unscaled: 0.3540 (0.3934)  cardinality_error_1_unscaled: 58.0000 (84.0627)  loss_ce_enc_unscaled: 0.6910 (0.7250)  loss_bbox_enc_unscaled: 0.0125 (0.0192)  loss_giou_enc_unscaled: 0.4047 (0.4264)  cardinality_error_enc_unscaled: 58.0000 (90.5755)  time: 3.2263  data: 0.0099  max mem: 20087
# Epoch: [0]  [360/759]  eta: 0:21:29  lr: 0.001000  class_error: 0.00  loss: 6.0984 (6.4921)  loss_ce: 0.7017 (0.7236)  loss_bbox: 0.0554 (0.0884)  loss_giou: 0.6983 (0.7875)  loss_ce_0: 0.7184 (0.7543)  loss_bbox_0: 0.0520 (0.0883)  loss_giou_0: 0.6693 (0.7802)  loss_ce_1: 0.6996 (0.7257)  loss_bbox_1: 0.0570 (0.0885)  loss_giou_1: 0.7029 (0.7850)  loss_ce_enc: 0.6908 (0.7244)  loss_bbox_enc: 0.0688 (0.0956)  loss_giou_enc: 0.8388 (0.8507)  loss_ce_unscaled: 0.7017 (0.7236)  class_error_unscaled: 0.0000 (0.0003)  loss_bbox_unscaled: 0.0111 (0.0177)  loss_giou_unscaled: 0.3492 (0.3938)  cardinality_error_unscaled: 53.0000 (69.9557)  loss_ce_0_unscaled: 0.7184 (0.7543)  loss_bbox_0_unscaled: 0.0104 (0.0177)  loss_giou_0_unscaled: 0.3346 (0.3901)  cardinality_error_0_unscaled: 53.0000 (69.9806)  loss_ce_1_unscaled: 0.6996 (0.7257)  loss_bbox_1_unscaled: 0.0114 (0.0177)  loss_giou_1_unscaled: 0.3515 (0.3925)  cardinality_error_1_unscaled: 53.0000 (82.9834)  loss_ce_enc_unscaled: 0.6908 (0.7244)  loss_bbox_enc_unscaled: 0.0138 (0.0191)  loss_giou_enc_unscaled: 0.4194 (0.4253)  cardinality_error_enc_unscaled: 53.0000 (89.3158)  time: 3.2552  data: 0.0098  max mem: 20087
# ...
# Test:  [ 30/124]  eta: 0:00:36  class_error: 0.00  loss: 4.1906 (4.3385)  loss_ce: 0.5664 (0.5737)  loss_bbox: 0.0182 (0.0225)  loss_giou: 0.4565 (0.4725)  loss_ce_0: 0.5742 (0.5857)  loss_bbox_0: 0.0185 (0.0226)  loss_giou_0: 0.4531 (0.4726)  loss_ce_1: 0.5664 (0.5767)  loss_bbox_1: 0.0181 (0.0218)  loss_giou_1: 0.4582 (0.4729)  loss_ce_enc: 0.5781 (0.5921)  loss_bbox_enc: 0.0207 (0.0243)  loss_giou_enc: 0.4798 (0.5012)  loss_ce_unscaled: 0.5664 (0.5737)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0036 (0.0045)  loss_giou_unscaled: 0.2282 (0.2362)  cardinality_error_unscaled: 46.0000 (63.0645)  loss_ce_0_unscaled: 0.5742 (0.5857)  loss_bbox_0_unscaled: 0.0037 (0.0045)  loss_giou_0_unscaled: 0.2265 (0.2363)  cardinality_error_0_unscaled: 46.0000 (63.0645)  loss_ce_1_unscaled: 0.5664 (0.5767)  loss_bbox_1_unscaled: 0.0036 (0.0044)  loss_giou_1_unscaled: 0.2291 (0.2365)  cardinality_error_1_unscaled: 46.0000 (63.0645)  loss_ce_enc_unscaled: 0.5781 (0.5921)  loss_bbox_enc_unscaled: 0.0041 (0.0049)  loss_giou_enc_unscaled: 0.2399 (0.2506)  cardinality_error_enc_unscaled: 31.0000 (53.5484)  time: 0.3444  data: 0.0250  max mem: 23419
# Test:  [ 40/124]  eta: 0:00:31  class_error: 0.00  loss: 4.1751 (4.3428)  loss_ce: 0.5664 (0.5734)  loss_bbox: 0.0177 (0.0225)  loss_giou: 0.4389 (0.4730)  loss_ce_0: 0.5664 (0.5860)  loss_bbox_0: 0.0178 (0.0226)  loss_giou_0: 0.4359 (0.4735)  loss_ce_1: 0.5664 (0.5756)  loss_bbox_1: 0.0180 (0.0220)  loss_giou_1: 0.4381 (0.4730)  loss_ce_enc: 0.5781 (0.5927)  loss_bbox_enc: 0.0213 (0.0246)  loss_giou_enc: 0.4605 (0.5039)  loss_ce_unscaled: 0.5664 (0.5734)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0035 (0.0045)  loss_giou_unscaled: 0.2195 (0.2365)  cardinality_error_unscaled: 31.0000 (65.0000)  loss_ce_0_unscaled: 0.5664 (0.5860)  loss_bbox_0_unscaled: 0.0036 (0.0045)  loss_giou_0_unscaled: 0.2180 (0.2367)  cardinality_error_0_unscaled: 31.0000 (65.0000)  loss_ce_1_unscaled: 0.5664 (0.5756)  loss_bbox_1_unscaled: 0.0036 (0.0044)  loss_giou_1_unscaled: 0.2191 (0.2365)  cardinality_error_1_unscaled: 31.0000 (65.0000)  loss_ce_enc_unscaled: 0.5781 (0.5927)  loss_bbox_enc_unscaled: 0.0043 (0.0049)  loss_giou_enc_unscaled: 0.2303 (0.2520)  cardinality_error_enc_unscaled: 12.0000 (56.1463)  time: 0.3415  data: 0.0249  max mem: 23419
# Test:  [ 50/124]  eta: 0:00:28  class_error: 0.00  loss: 4.3288 (4.3638)  loss_ce: 0.5625 (0.5735)  loss_bbox: 0.0200 (0.0235)  loss_giou: 0.4389 (0.4771)  loss_ce_0: 0.5781 (0.5863)  loss_bbox_0: 0.0230 (0.0242)  loss_giou_0: 0.4404 (0.4788)  loss_ce_1: 0.5664 (0.5743)  loss_bbox_1: 0.0200 (0.0231)  loss_giou_1: 0.4381 (0.4774)  loss_ce_enc: 0.5703 (0.5921)  loss_bbox_enc: 0.0231 (0.0260)  loss_giou_enc: 0.4864 (0.5076)  loss_ce_unscaled: 0.5625 (0.5735)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0040 (0.0047)  loss_giou_unscaled: 0.2195 (0.2386)  cardinality_error_unscaled: 37.0000 (69.2745)  loss_ce_0_unscaled: 0.5781 (0.5863)  loss_bbox_0_unscaled: 0.0046 (0.0048)  loss_giou_0_unscaled: 0.2202 (0.2394)  cardinality_error_0_unscaled: 37.0000 (69.2745)  loss_ce_1_unscaled: 0.5664 (0.5743)  loss_bbox_1_unscaled: 0.0040 (0.0046)  loss_giou_1_unscaled: 0.2191 (0.2387)  cardinality_error_1_unscaled: 37.0000 (69.2745)  loss_ce_enc_unscaled: 0.5703 (0.5921)  loss_bbox_enc_unscaled: 0.0046 (0.0052)  loss_giou_enc_unscaled: 0.2432 (0.2538)  cardinality_error_enc_unscaled: 34.0000 (61.3137)  time: 0.3649  data: 0.0250  max mem: 23419
# Test:  [ 60/124]  eta: 0:00:24  class_error: 0.00  loss: 4.3041 (4.3552)  loss_ce: 0.5625 (0.5749)  loss_bbox: 0.0201 (0.0231)  loss_giou: 0.4592 (0.4732)  loss_ce_0: 0.5781 (0.5885)  loss_bbox_0: 0.0206 (0.0237)  loss_giou_0: 0.4668 (0.4750)  loss_ce_1: 0.5664 (0.5753)  loss_bbox_1: 0.0206 (0.0229)  loss_giou_1: 0.4620 (0.4739)  loss_ce_enc: 0.5781 (0.5940)  loss_bbox_enc: 0.0243 (0.0258)  loss_giou_enc: 0.4907 (0.5050)  loss_ce_unscaled: 0.5625 (0.5749)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0040 (0.0046)  loss_giou_unscaled: 0.2296 (0.2366)  cardinality_error_unscaled: 68.0000 (71.9836)  loss_ce_0_unscaled: 0.5781 (0.5885)  loss_bbox_0_unscaled: 0.0041 (0.0047)  loss_giou_0_unscaled: 0.2334 (0.2375)  cardinality_error_0_unscaled: 68.0000 (71.9836)  loss_ce_1_unscaled: 0.5664 (0.5753)  loss_bbox_1_unscaled: 0.0041 (0.0046)  loss_giou_1_unscaled: 0.2310 (0.2369)  cardinality_error_1_unscaled: 68.0000 (71.9836)  loss_ce_enc_unscaled: 0.5781 (0.5940)  loss_bbox_enc_unscaled: 0.0049 (0.0052)  loss_giou_enc_unscaled: 0.2453 (0.2525)  cardinality_error_enc_unscaled: 68.0000 (64.9180)  time: 0.3723  data: 0.0250  max mem: 23419
# Test:  [ 70/124]  eta: 0:00:20  class_error: 0.00  loss: 4.2035 (4.3209)  loss_ce: 0.5547 (0.5717)  loss_bbox: 0.0205 (0.0227)  loss_giou: 0.4592 (0.4682)  loss_ce_0: 0.5664 (0.5845)  loss_bbox_0: 0.0206 (0.0233)  loss_giou_0: 0.4668 (0.4709)  loss_ce_1: 0.5547 (0.5722)  loss_bbox_1: 0.0208 (0.0225)  loss_giou_1: 0.4620 (0.4689)  loss_ce_enc: 0.5781 (0.5912)  loss_bbox_enc: 0.0236 (0.0254)  loss_giou_enc: 0.4907 (0.4995)  loss_ce_unscaled: 0.5547 (0.5717)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0041 (0.0045)  loss_giou_unscaled: 0.2296 (0.2341)  cardinality_error_unscaled: 68.0000 (74.2958)  loss_ce_0_unscaled: 0.5664 (0.5845)  loss_bbox_0_unscaled: 0.0041 (0.0047)  loss_giou_0_unscaled: 0.2334 (0.2354)  cardinality_error_0_unscaled: 68.0000 (74.2958)  loss_ce_1_unscaled: 0.5547 (0.5722)  loss_bbox_1_unscaled: 0.0042 (0.0045)  loss_giou_1_unscaled: 0.2310 (0.2344)  cardinality_error_1_unscaled: 68.0000 (74.2958)  loss_ce_enc_unscaled: 0.5781 (0.5912)  loss_bbox_enc_unscaled: 0.0047 (0.0051)  loss_giou_enc_unscaled: 0.2454 (0.2498)  cardinality_error_enc_unscaled: 68.0000 (67.2676)  time: 0.3785  data: 0.0254  max mem: 23419
# Test:  [ 80/124]  eta: 0:00:16  class_error: 0.00  loss: 4.0327 (4.2810)  loss_ce: 0.5352 (0.5676)  loss_bbox: 0.0178 (0.0219)  loss_giou: 0.4383 (0.4626)  loss_ce_0: 0.5547 (0.5813)  loss_bbox_0: 0.0181 (0.0226)  loss_giou_0: 0.4441 (0.4654)  loss_ce_1: 0.5391 (0.5682)  loss_bbox_1: 0.0178 (0.0218)  loss_giou_1: 0.4396 (0.4633)  loss_ce_enc: 0.5508 (0.5876)  loss_bbox_enc: 0.0189 (0.0248)  loss_giou_enc: 0.4655 (0.4940)  loss_ce_unscaled: 0.5352 (0.5676)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0036 (0.0044)  loss_giou_unscaled: 0.2192 (0.2313)  cardinality_error_unscaled: 48.0000 (73.0494)  loss_ce_0_unscaled: 0.5547 (0.5813)  loss_bbox_0_unscaled: 0.0036 (0.0045)  loss_giou_0_unscaled: 0.2220 (0.2327)  cardinality_error_0_unscaled: 48.0000 (73.0494)  loss_ce_1_unscaled: 0.5391 (0.5682)  loss_bbox_1_unscaled: 0.0036 (0.0044)  loss_giou_1_unscaled: 0.2198 (0.2317)  cardinality_error_1_unscaled: 48.0000 (73.0494)  loss_ce_enc_unscaled: 0.5508 (0.5876)  loss_bbox_enc_unscaled: 0.0038 (0.0050)  loss_giou_enc_unscaled: 0.2327 (0.2470)  cardinality_error_enc_unscaled: 39.0000 (65.9383)  time: 0.3622  data: 0.0254  max mem: 23419
# Test:  [ 90/124]  eta: 0:00:12  class_error: 0.00  loss: 4.0327 (4.2658)  loss_ce: 0.5352 (0.5663)  loss_bbox: 0.0176 (0.0217)  loss_giou: 0.4383 (0.4605)  loss_ce_0: 0.5547 (0.5802)  loss_bbox_0: 0.0181 (0.0223)  loss_giou_0: 0.4441 (0.4631)  loss_ce_1: 0.5391 (0.5669)  loss_bbox_1: 0.0176 (0.0216)  loss_giou_1: 0.4396 (0.4612)  loss_ce_enc: 0.5508 (0.5861)  loss_bbox_enc: 0.0189 (0.0245)  loss_giou_enc: 0.4665 (0.4915)  loss_ce_unscaled: 0.5352 (0.5663)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0035 (0.0043)  loss_giou_unscaled: 0.2192 (0.2302)  cardinality_error_unscaled: 48.0000 (73.2418)  loss_ce_0_unscaled: 0.5547 (0.5802)  loss_bbox_0_unscaled: 0.0036 (0.0045)  loss_giou_0_unscaled: 0.2220 (0.2315)  cardinality_error_0_unscaled: 48.0000 (73.2418)  loss_ce_1_unscaled: 0.5391 (0.5669)  loss_bbox_1_unscaled: 0.0035 (0.0043)  loss_giou_1_unscaled: 0.2198 (0.2306)  cardinality_error_1_unscaled: 48.0000 (73.2418)  loss_ce_enc_unscaled: 0.5508 (0.5861)  loss_bbox_enc_unscaled: 0.0038 (0.0049)  loss_giou_enc_unscaled: 0.2332 (0.2457)  cardinality_error_enc_unscaled: 39.0000 (65.9560)  time: 0.3466  data: 0.0252  max mem: 23419
# Test:  [100/124]  eta: 0:00:08  class_error: 0.00  loss: 4.2002 (4.2867)  loss_ce: 0.5547 (0.5663)  loss_bbox: 0.0204 (0.0226)  loss_giou: 0.4666 (0.4646)  loss_ce_0: 0.5703 (0.5803)  loss_bbox_0: 0.0209 (0.0232)  loss_giou_0: 0.4667 (0.4671)  loss_ce_1: 0.5547 (0.5670)  loss_bbox_1: 0.0213 (0.0226)  loss_giou_1: 0.4637 (0.4656)  loss_ce_enc: 0.5742 (0.5865)  loss_bbox_enc: 0.0223 (0.0253)  loss_giou_enc: 0.4859 (0.4956)  loss_ce_unscaled: 0.5547 (0.5663)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0041 (0.0045)  loss_giou_unscaled: 0.2333 (0.2323)  cardinality_error_unscaled: 61.0000 (75.8020)  loss_ce_0_unscaled: 0.5703 (0.5803)  loss_bbox_0_unscaled: 0.0042 (0.0046)  loss_giou_0_unscaled: 0.2334 (0.2336)  cardinality_error_0_unscaled: 61.0000 (75.8020)  loss_ce_1_unscaled: 0.5547 (0.5670)  loss_bbox_1_unscaled: 0.0043 (0.0045)  loss_giou_1_unscaled: 0.2318 (0.2328)  cardinality_error_1_unscaled: 61.0000 (75.8020)  loss_ce_enc_unscaled: 0.5742 (0.5865)  loss_bbox_enc_unscaled: 0.0045 (0.0051)  loss_giou_enc_unscaled: 0.2430 (0.2478)  cardinality_error_enc_unscaled: 61.0000 (68.2871)  time: 0.3746  data: 0.0254  max mem: 23419
# Test:  [110/124]  eta: 0:00:05  class_error: 0.00  loss: 4.2452 (4.2732)  loss_ce: 0.5508 (0.5645)  loss_bbox: 0.0222 (0.0226)  loss_giou: 0.4466 (0.4633)  loss_ce_0: 0.5703 (0.5785)  loss_bbox_0: 0.0219 (0.0231)  loss_giou_0: 0.4458 (0.4658)  loss_ce_1: 0.5469 (0.5653)  loss_bbox_1: 0.0229 (0.0225)  loss_giou_1: 0.4497 (0.4642)  loss_ce_enc: 0.5742 (0.5847)  loss_bbox_enc: 0.0242 (0.0251)  loss_giou_enc: 0.4802 (0.4936)  loss_ce_unscaled: 0.5508 (0.5645)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0044 (0.0045)  loss_giou_unscaled: 0.2233 (0.2317)  cardinality_error_unscaled: 65.0000 (77.7117)  loss_ce_0_unscaled: 0.5703 (0.5785)  loss_bbox_0_unscaled: 0.0044 (0.0046)  loss_giou_0_unscaled: 0.2229 (0.2329)  cardinality_error_0_unscaled: 65.0000 (77.7117)  loss_ce_1_unscaled: 0.5469 (0.5653)  loss_bbox_1_unscaled: 0.0046 (0.0045)  loss_giou_1_unscaled: 0.2249 (0.2321)  cardinality_error_1_unscaled: 65.0000 (77.7117)  loss_ce_enc_unscaled: 0.5742 (0.5847)  loss_bbox_enc_unscaled: 0.0048 (0.0050)  loss_giou_enc_unscaled: 0.2401 (0.2468)  cardinality_error_enc_unscaled: 62.0000 (70.2973)  time: 0.3912  data: 0.0252  max mem: 23419
# Test:  [120/124]  eta: 0:00:01  class_error: 0.00  loss: 4.1464 (4.2659)  loss_ce: 0.5391 (0.5635)  loss_bbox: 0.0196 (0.0224)  loss_giou: 0.4360 (0.4628)  loss_ce_0: 0.5547 (0.5775)  loss_bbox_0: 0.0207 (0.0230)  loss_giou_0: 0.4441 (0.4654)  loss_ce_1: 0.5430 (0.5642)  loss_bbox_1: 0.0200 (0.0223)  loss_giou_1: 0.4366 (0.4636)  loss_ce_enc: 0.5625 (0.5838)  loss_bbox_enc: 0.0223 (0.0250)  loss_giou_enc: 0.4668 (0.4925)  loss_ce_unscaled: 0.5391 (0.5635)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0039 (0.0045)  loss_giou_unscaled: 0.2180 (0.2314)  cardinality_error_unscaled: 54.0000 (76.2397)  loss_ce_0_unscaled: 0.5547 (0.5775)  loss_bbox_0_unscaled: 0.0041 (0.0046)  loss_giou_0_unscaled: 0.2220 (0.2327)  cardinality_error_0_unscaled: 54.0000 (76.2479)  loss_ce_1_unscaled: 0.5430 (0.5642)  loss_bbox_1_unscaled: 0.0040 (0.0045)  loss_giou_1_unscaled: 0.2183 (0.2318)  cardinality_error_1_unscaled: 54.0000 (76.2479)  loss_ce_enc_unscaled: 0.5625 (0.5838)  loss_bbox_enc_unscaled: 0.0045 (0.0050)  loss_giou_enc_unscaled: 0.2334 (0.2462)  cardinality_error_enc_unscaled: 54.0000 (68.6612)  time: 0.3605  data: 0.0252  max mem: 23419
# Test:  [123/124]  eta: 0:00:00  class_error: 0.00  loss: 4.2080 (4.2709)  loss_ce: 0.5547 (0.5644)  loss_bbox: 0.0204 (0.0224)  loss_giou: 0.4466 (0.4633)  loss_ce_0: 0.5586 (0.5782)  loss_bbox_0: 0.0212 (0.0230)  loss_giou_0: 0.4458 (0.4659)  loss_ce_1: 0.5547 (0.5651)  loss_bbox_1: 0.0208 (0.0224)  loss_giou_1: 0.4497 (0.4642)  loss_ce_enc: 0.5625 (0.5842)  loss_bbox_enc: 0.0227 (0.0250)  loss_giou_enc: 0.4711 (0.4929)  loss_ce_unscaled: 0.5547 (0.5644)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0041 (0.0045)  loss_giou_unscaled: 0.2233 (0.2316)  cardinality_error_unscaled: 64.0000 (76.1694)  loss_ce_0_unscaled: 0.5586 (0.5782)  loss_bbox_0_unscaled: 0.0042 (0.0046)  loss_giou_0_unscaled: 0.2229 (0.2329)  cardinality_error_0_unscaled: 64.0000 (76.1774)  loss_ce_1_unscaled: 0.5547 (0.5651)  loss_bbox_1_unscaled: 0.0042 (0.0045)  loss_giou_1_unscaled: 0.2249 (0.2321)  cardinality_error_1_unscaled: 64.0000 (76.1774)  loss_ce_enc_unscaled: 0.5625 (0.5842)  loss_bbox_enc_unscaled: 0.0045 (0.0050)  loss_giou_enc_unscaled: 0.2355 (0.2465)  cardinality_error_enc_unscaled: 54.0000 (68.6210)  time: 0.3636  data: 0.0250  max mem: 23419
# Test: Total time: 0:00:46 (0.3723 s / it)
# Averaged stats: class_error: 0.00  loss: 4.2080 (4.2709)  loss_ce: 0.5547 (0.5644)  loss_bbox: 0.0204 (0.0224)  loss_giou: 0.4466 (0.4633)  loss_ce_0: 0.5586 (0.5782)  loss_bbox_0: 0.0212 (0.0230)  loss_giou_0: 0.4458 (0.4659)  loss_ce_1: 0.5547 (0.5651)  loss_bbox_1: 0.0208 (0.0224)  loss_giou_1: 0.4497 (0.4642)  loss_ce_enc: 0.5625 (0.5842)  loss_bbox_enc: 0.0227 (0.0250)  loss_giou_enc: 0.4711 (0.4929)  loss_ce_unscaled: 0.5547 (0.5644)  class_error_unscaled: 0.0000 (-0.0000)  loss_bbox_unscaled: 0.0041 (0.0045)  loss_giou_unscaled: 0.2233 (0.2316)  cardinality_error_unscaled: 64.0000 (76.1694)  loss_ce_0_unscaled: 0.5586 (0.5782)  loss_bbox_0_unscaled: 0.0042 (0.0046)  loss_giou_0_unscaled: 0.2229 (0.2329)  cardinality_error_0_unscaled: 64.0000 (76.1774)  loss_ce_1_unscaled: 0.5547 (0.5651)  loss_bbox_1_unscaled: 0.0042 (0.0045)  loss_giou_1_unscaled: 0.2249 (0.2321)  cardinality_error_1_unscaled: 64.0000 (76.1774)  loss_ce_enc_unscaled: 0.5625 (0.5842)  loss_bbox_enc_unscaled: 0.0045 (0.0050)  loss_giou_enc_unscaled: 0.2355 (0.2465)  cardinality_error_enc_unscaled: 54.0000 (68.6210)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.619
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.666
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.101
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.721
# Training time 21:05:42
# Results saved to output/results.json
# Results saved to output/metrics_plot.png

# %%
from PIL import Image

Image.open("/content/output/metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %% [markdown]
# ## Run inference with fine-tuned model

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(thickness=thickness)
label_annotator = sv.LabelAnnotator(
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    text_thickness=thickness,
    smart_position=True)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
import supervision as sv
from rfdetr import RFDETRBase
from PIL import Image

detections_images = []

for i in range(9):
    path, image, annotations = ds[i]
    image = Image.open(path)

    detections = model.predict(image, threshold=0.5)

    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
    thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

    bbox_annotator = sv.BoxAnnotator(thickness=thickness)
    label_annotator = sv.LabelAnnotator(
        text_color=sv.Color.BLACK,
        text_scale=text_scale,
        text_thickness=thickness,
        smart_position=True)

    detections_labels = [
        f"{ds.classes[class_id]} {confidence:.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    detections_image = image.copy()
    detections_image = bbox_annotator.annotate(detections_image, detections)
    detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

    detections_images.append(detections_image)

sv.plot_images_grid(images=detections_images, grid_size=(3, 3), size=(12, 12))

# %% [markdown]
# ## Evaluate fine-tuned model

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0.5)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 60/60 [00:04<00:00, 13.38it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()

map_result.plot()

# %%
confusion_matrix = sv.ConfusionMatrix.from_detections(
    predictions=predictions,
    targets=targets,
    classes=ds.classes
)

confusion_matrix.plot()

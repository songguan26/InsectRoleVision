# %% [markdown]
# <a href="https://colab.research.google.com/github/songguan26/InsectRoleVision/blob/main/ScanBugM1v2_rf_detr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Open your [`HuggingFace Settings`](https://huggingface.co/settings) page. Click `Access Tokens` then `New Token` to generate new token.
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store HuggingFace Access Token under the name `HF_TOKEN`.
#     - Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu May 15 09:16:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0             57W /  400W |   40439MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -q rfdetr==1.1.0

# %% [markdown]
# ## Download dataset from Roboflow Universe

# %%
from roboflow import download_dataset

dataset = download_dataset('https://universe.roboflow.com/computervisionlab/scanbugm1/dataset/3', "coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.
#
# ### Train with multiple GPUs
#
# You can fine-tune RF-DETR on multiple GPUs using PyTorch’s Distributed Data Parallel (DDP). Create a `main.py` script that initializes your model and calls `.train()` as usual than run it in terminal.
#
# ```bash
# python -m torch.distributed.launch \
#     --nproc_per_node=8 \
#     --use_env \
#     main.py
# ```
#
# Replace `8` in the `--nproc_per_node argument` with the number of GPUs you want to use. This approach creates one training process per GPU and splits the workload automatically. Note that your effective batch size is multiplied by the number of GPUs, so you may need to adjust your `batch_size` and `grad_accum_steps` to maintain the same overall batch size.

# %%
from rfdetr import RFDETRBase

model = RFDETRBase()

model.train(dataset_dir=dataset.location, epochs=30, batch_size=1, lr=1e-3, resolution= 3192)
# Out:
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 13 classes
# reinitializing your detection head with 13 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=13, grad_accum_steps=4, amp=True, lr=0.001, lr_encoder=0.00015, batch_size=1, weight_decay=0.0001, epochs=30, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/ScanBugM1-3', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=3192, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, tensorboard=True, wandb=False, project=None, run=None, class_names=['Arachnida', 'Coleoptera', 'Diptera_Brachycera', 'Diptera_Nematocera', 'Diptera_Syrphidae', 'Hemiptera_Aphidomorpha', 'Hemiptera_Heteroptera', 'Hemiptera_Membracoidea', 'Hymenoptera_Apocrita', 'Hymenoptera_Formicidae', 'Lepidotpera', 'Psocodea'], distributed=False)
# number of params: 31893886
# [3024, 3080, 3136, 3192, 3248, 3304, 3360, 3416]
# loading annotations into memory...
# Done (t=1.32s)
# creating index...
# index created!
# [3024, 3080, 3136, 3192, 3248, 3304, 3360, 3416]
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  4
# Total batch size:  4
# LENGTH OF DATA LOADER: 759
# Epoch: [0]  [  0/759]  eta: 1:16:17  lr: 0.001000  class_error: 71.24  loss: 23.7516 (23.7516)  loss_ce: 0.1113 (0.1113)  loss_bbox: 2.4184 (2.4184)  loss_giou: 2.8964 (2.8964)  loss_ce_0: 0.1033 (0.1033)  loss_bbox_0: 2.9000 (2.9000)  loss_giou_0: 3.0751 (3.0751)  loss_ce_1: 0.1088 (0.1088)  loss_bbox_1: 2.5123 (2.5123)  loss_giou_1: 2.9858 (2.9858)  loss_ce_enc: 0.1008 (0.1008)  loss_bbox_enc: 3.6608 (3.6608)  loss_giou_enc: 2.8787 (2.8787)  loss_ce_unscaled: 0.1113 (0.1113)  class_error_unscaled: 71.2375 (71.2375)  loss_bbox_unscaled: 0.4837 (0.4837)  loss_giou_unscaled: 1.4482 (1.4482)  cardinality_error_unscaled: 3298.0000 (3298.0000)  loss_ce_0_unscaled: 0.1033 (0.1033)  loss_bbox_0_unscaled: 0.5800 (0.5800)  loss_giou_0_unscaled: 1.5376 (1.5376)  cardinality_error_0_unscaled: 3757.0000 (3757.0000)  loss_ce_1_unscaled: 0.1088 (0.1088)  loss_bbox_1_unscaled: 0.5025 (0.5025)  loss_giou_1_unscaled: 1.4929 (1.4929)  cardinality_error_1_unscaled: 3466.0000 (3466.0000)  loss_ce_enc_unscaled: 0.1008 (0.1008)  loss_bbox_enc_unscaled: 0.7322 (0.7322)  loss_giou_enc_unscaled: 1.4393 (1.4393)  cardinality_error_enc_unscaled: 3577.0000 (3577.0000)  time: 6.0305  data: 2.6746  max mem: 38593
# Epoch: [0]  [ 10/759]  eta: 0:44:41  lr: 0.001000  class_error: 44.62  loss: 11.8099 (12.3489)  loss_ce: 0.5651 (0.5492)  loss_bbox: 0.4608 (0.5887)  loss_giou: 1.8351 (1.9040)  loss_ce_0: 0.5791 (0.5524)  loss_bbox_0: 0.4506 (0.6265)  loss_giou_0: 1.8625 (1.9129)  loss_ce_1: 0.5847 (0.5557)  loss_bbox_1: 0.4699 (0.5964)  loss_giou_1: 1.8366 (1.9019)  loss_ce_enc: 0.5327 (0.5297)  loss_bbox_enc: 0.4491 (0.6977)  loss_giou_enc: 1.9124 (1.9337)  loss_ce_unscaled: 0.5651 (0.5492)  class_error_unscaled: 81.9048 (73.8058)  loss_bbox_unscaled: 0.0922 (0.1177)  loss_giou_unscaled: 0.9176 (0.9520)  cardinality_error_unscaled: 3863.0000 (3803.7273)  loss_ce_0_unscaled: 0.5791 (0.5524)  loss_bbox_0_unscaled: 0.0901 (0.1253)  loss_giou_0_unscaled: 0.9312 (0.9565)  cardinality_error_0_unscaled: 3863.0000 (3837.1818)  loss_ce_1_unscaled: 0.5847 (0.5557)  loss_bbox_1_unscaled: 0.0940 (0.1193)  loss_giou_1_unscaled: 0.9183 (0.9509)  cardinality_error_1_unscaled: 3870.0000 (3824.1818)  loss_ce_enc_unscaled: 0.5327 (0.5297)  loss_bbox_enc_unscaled: 0.0898 (0.1395)  loss_giou_enc_unscaled: 0.9562 (0.9669)  cardinality_error_enc_unscaled: 3790.0000 (3730.0000)  time: 3.5807  data: 0.2512  max mem: 38593
# Epoch: [0]  [ 20/759]  eta: 0:42:33  lr: 0.001000  class_error: 48.98  loss: 9.4829 (10.9136)  loss_ce: 0.7288 (0.6691)  loss_bbox: 0.2287 (0.4243)  loss_giou: 1.3941 (1.6018)  loss_ce_0: 0.7436 (0.6721)  loss_bbox_0: 0.2317 (0.4444)  loss_giou_0: 1.3815 (1.6088)  loss_ce_1: 0.7333 (0.6696)  loss_bbox_1: 0.2301 (0.4283)  loss_giou_1: 1.4084 (1.6087)  loss_ce_enc: 0.7142 (0.6462)  loss_bbox_enc: 0.2361 (0.4833)  loss_giou_enc: 1.4348 (1.6571)  loss_ce_unscaled: 0.7288 (0.6691)  class_error_unscaled: 64.2483 (61.0840)  loss_bbox_unscaled: 0.0457 (0.0849)  loss_giou_unscaled: 0.6971 (0.8009)  cardinality_error_unscaled: 3833.0000 (3797.9524)  loss_ce_0_unscaled: 0.7436 (0.6721)  loss_bbox_0_unscaled: 0.0463 (0.0889)  loss_giou_0_unscaled: 0.6907 (0.8044)  cardinality_error_0_unscaled: 3828.0000 (3815.0952)  loss_ce_1_unscaled: 0.7333 (0.6696)  loss_bbox_1_unscaled: 0.0460 (0.0857)  loss_giou_1_unscaled: 0.7042 (0.8044)  cardinality_error_1_unscaled: 3849.0000 (3808.6190)  loss_ce_enc_unscaled: 0.7142 (0.6462)  loss_bbox_enc_unscaled: 0.0472 (0.0967)  loss_giou_enc_unscaled: 0.7174 (0.8285)  cardinality_error_enc_unscaled: 3812.0000 (3759.3333)  time: 3.3268  data: 0.0094  max mem: 38593
# Epoch: [0]  [ 30/759]  eta: 0:40:48  lr: 0.001000  class_error: 62.30  loss: 8.1166 (10.0437)  loss_ce: 0.8538 (0.7308)  loss_bbox: 0.1348 (0.3309)  loss_giou: 1.0349 (1.4241)  loss_ce_0: 0.8708 (0.7333)  loss_bbox_0: 0.1310 (0.3432)  loss_giou_0: 1.0183 (1.4266)  loss_ce_1: 0.8514 (0.7286)  loss_bbox_1: 0.1358 (0.3334)  loss_giou_1: 1.0492 (1.4289)  loss_ce_enc: 0.8296 (0.7062)  loss_bbox_enc: 0.1413 (0.3718)  loss_giou_enc: 1.1144 (1.4858)  loss_ce_unscaled: 0.8538 (0.7308)  class_error_unscaled: 62.2960 (62.5579)  loss_bbox_unscaled: 0.0270 (0.0662)  loss_giou_unscaled: 0.5175 (0.7120)  cardinality_error_unscaled: 3811.0000 (3802.4516)  loss_ce_0_unscaled: 0.8708 (0.7333)  loss_bbox_0_unscaled: 0.0262 (0.0686)  loss_giou_0_unscaled: 0.5092 (0.7133)  cardinality_error_0_unscaled: 3811.0000 (3814.0645)  loss_ce_1_unscaled: 0.8514 (0.7286)  loss_bbox_1_unscaled: 0.0272 (0.0667)  loss_giou_1_unscaled: 0.5246 (0.7144)  cardinality_error_1_unscaled: 3811.0000 (3809.6129)  loss_ce_enc_unscaled: 0.8296 (0.7062)  loss_bbox_enc_unscaled: 0.0283 (0.0744)  loss_giou_enc_unscaled: 0.5572 (0.7429)  cardinality_error_enc_unscaled: 3811.0000 (3776.0323)  time: 3.2363  data: 0.0098  max mem: 38593
# Epoch: [0]  [ 40/759]  eta: 0:40:16  lr: 0.001000  class_error: 71.49  loss: 7.9464 (9.4716)  loss_ce: 0.9322 (0.8065)  loss_bbox: 0.0982 (0.2717)  loss_giou: 0.9022 (1.2691)  loss_ce_0: 0.9307 (0.8162)  loss_bbox_0: 0.0966 (0.2807)  loss_giou_0: 0.8916 (1.2604)  loss_ce_1: 0.9143 (0.8048)  loss_bbox_1: 0.0979 (0.2742)  loss_giou_1: 0.9084 (1.2745)  loss_ce_enc: 0.9028 (0.7861)  loss_bbox_enc: 0.1041 (0.3042)  loss_giou_enc: 0.9298 (1.3230)  loss_ce_unscaled: 0.9322 (0.8065)  class_error_unscaled: 65.7544 (61.9128)  loss_bbox_unscaled: 0.0196 (0.0543)  loss_giou_unscaled: 0.4511 (0.6346)  cardinality_error_unscaled: 3855.0000 (3817.6585)  loss_ce_0_unscaled: 0.9307 (0.8162)  loss_bbox_0_unscaled: 0.0193 (0.0561)  loss_giou_0_unscaled: 0.4458 (0.6302)  cardinality_error_0_unscaled: 3855.0000 (3826.5854)  loss_ce_1_unscaled: 0.9143 (0.8048)  loss_bbox_1_unscaled: 0.0196 (0.0548)  loss_giou_1_unscaled: 0.4542 (0.6372)  cardinality_error_1_unscaled: 3849.0000 (3822.3171)  loss_ce_enc_unscaled: 0.9028 (0.7861)  loss_bbox_enc_unscaled: 0.0208 (0.0608)  loss_giou_enc_unscaled: 0.4649 (0.6615)  cardinality_error_enc_unscaled: 3855.0000 (3797.4634)  time: 3.2605  data: 0.0098  max mem: 38593
# Epoch: [0]  [ 50/759]  eta: 0:39:40  lr: 0.001000  class_error: 61.94  loss: 7.6639 (9.0957)  loss_ce: 0.9702 (0.8307)  loss_bbox: 0.0830 (0.2369)  loss_giou: 0.7945 (1.1869)  loss_ce_0: 1.0229 (0.8450)  loss_bbox_0: 0.0770 (0.2437)  loss_giou_0: 0.7574 (1.1754)  loss_ce_1: 0.9678 (0.8290)  loss_bbox_1: 0.0870 (0.2392)  loss_giou_1: 0.8019 (1.1927)  loss_ce_enc: 1.0000 (0.8203)  loss_bbox_enc: 0.0815 (0.2633)  loss_giou_enc: 0.8236 (1.2326)  loss_ce_unscaled: 0.9702 (0.8307)  class_error_unscaled: 61.1722 (60.2286)  loss_bbox_unscaled: 0.0166 (0.0474)  loss_giou_unscaled: 0.3973 (0.5934)  cardinality_error_unscaled: 3863.0000 (3823.0588)  loss_ce_0_unscaled: 1.0229 (0.8450)  loss_bbox_0_unscaled: 0.0154 (0.0487)  loss_giou_0_unscaled: 0.3787 (0.5877)  cardinality_error_0_unscaled: 3863.0000 (3830.2941)  loss_ce_1_unscaled: 0.9678 (0.8290)  loss_bbox_1_unscaled: 0.0174 (0.0478)  loss_giou_1_unscaled: 0.4010 (0.5964)  cardinality_error_1_unscaled: 3859.0000 (3826.7647)  loss_ce_enc_unscaled: 1.0000 (0.8203)  loss_bbox_enc_unscaled: 0.0163 (0.0527)  loss_giou_enc_unscaled: 0.4118 (0.6163)  cardinality_error_enc_unscaled: 3858.0000 (3805.0392)  time: 3.3570  data: 0.0100  max mem: 38593
# Epoch: [0]  [ 60/759]  eta: 0:38:54  lr: 0.001000  class_error: 10.90  loss: 7.1482 (8.7531)  loss_ce: 0.9383 (0.8557)  loss_bbox: 0.0617 (0.2069)  loss_giou: 0.7239 (1.1051)  loss_ce_0: 1.0025 (0.8756)  loss_bbox_0: 0.0588 (0.2120)  loss_giou_0: 0.7241 (1.0918)  loss_ce_1: 0.9466 (0.8547)  loss_bbox_1: 0.0602 (0.2089)  loss_giou_1: 0.7226 (1.1092)  loss_ce_enc: 0.9824 (0.8520)  loss_bbox_enc: 0.0606 (0.2293)  loss_giou_enc: 0.7349 (1.1519)  loss_ce_unscaled: 0.9383 (0.8557)  class_error_unscaled: 54.2582 (58.4455)  loss_bbox_unscaled: 0.0123 (0.0414)  loss_giou_unscaled: 0.3619 (0.5525)  cardinality_error_unscaled: 3852.0000 (3828.4754)  loss_ce_0_unscaled: 1.0025 (0.8756)  loss_bbox_0_unscaled: 0.0118 (0.0424)  loss_giou_0_unscaled: 0.3620 (0.5459)  cardinality_error_0_unscaled: 3852.0000 (3834.6066)  loss_ce_1_unscaled: 0.9466 (0.8547)  loss_bbox_1_unscaled: 0.0120 (0.0418)  loss_giou_1_unscaled: 0.3613 (0.5546)  cardinality_error_1_unscaled: 3852.0000 (3831.5902)  loss_ce_enc_unscaled: 0.9824 (0.8520)  loss_bbox_enc_unscaled: 0.0121 (0.0459)  loss_giou_enc_unscaled: 0.3675 (0.5760)  cardinality_error_enc_unscaled: 3850.0000 (3812.8525)  time: 3.2994  data: 0.0099  max mem: 38593
# Epoch: [0]  [ 70/759]  eta: 0:38:15  lr: 0.001000  class_error: 41.83  loss: 6.9115 (8.5340)  loss_ce: 0.9578 (0.8685)  loss_bbox: 0.0440 (0.1866)  loss_giou: 0.6669 (1.0590)  loss_ce_0: 1.0158 (0.8935)  loss_bbox_0: 0.0422 (0.1905)  loss_giou_0: 0.6306 (1.0419)  loss_ce_1: 0.9516 (0.8677)  loss_bbox_1: 0.0450 (0.1883)  loss_giou_1: 0.6584 (1.0619)  loss_ce_enc: 1.0103 (0.8699)  loss_bbox_enc: 0.0445 (0.2057)  loss_giou_enc: 0.7052 (1.1007)  loss_ce_unscaled: 0.9578 (0.8685)  class_error_unscaled: 45.9276 (57.0895)  loss_bbox_unscaled: 0.0088 (0.0373)  loss_giou_unscaled: 0.3334 (0.5295)  cardinality_error_unscaled: 3866.0000 (3832.3380)  loss_ce_0_unscaled: 1.0158 (0.8935)  loss_bbox_0_unscaled: 0.0084 (0.0381)  loss_giou_0_unscaled: 0.3153 (0.5209)  cardinality_error_0_unscaled: 3866.0000 (3837.6056)  loss_ce_1_unscaled: 0.9516 (0.8677)  loss_bbox_1_unscaled: 0.0090 (0.0377)  loss_giou_1_unscaled: 0.3292 (0.5309)  cardinality_error_1_unscaled: 3866.0000 (3835.0141)  loss_ce_enc_unscaled: 1.0103 (0.8699)  loss_bbox_enc_unscaled: 0.0089 (0.0411)  loss_giou_enc_unscaled: 0.3526 (0.5504)  cardinality_error_enc_unscaled: 3865.0000 (3818.7183)  time: 3.2644  data: 0.0102  max mem: 38593
# Epoch: [0]  [ 80/759]  eta: 0:37:33  lr: 0.001000  class_error: 5.36  loss: 6.9441 (8.3737)  loss_ce: 0.9486 (0.8728)  loss_bbox: 0.0572 (0.1732)  loss_giou: 0.6850 (1.0278)  loss_ce_0: 0.9969 (0.8994)  loss_bbox_0: 0.0594 (0.1763)  loss_giou_0: 0.6498 (1.0102)  loss_ce_1: 0.9428 (0.8720)  loss_bbox_1: 0.0583 (0.1747)  loss_giou_1: 0.6809 (1.0302)  loss_ce_enc: 0.9836 (0.8782)  loss_bbox_enc: 0.0588 (0.1903)  loss_giou_enc: 0.7420 (1.0687)  loss_ce_unscaled: 0.9486 (0.8728)  class_error_unscaled: 41.5027 (54.8114)  loss_bbox_unscaled: 0.0114 (0.0346)  loss_giou_unscaled: 0.3425 (0.5139)  cardinality_error_unscaled: 3856.0000 (3829.0000)  loss_ce_0_unscaled: 0.9969 (0.8994)  loss_bbox_0_unscaled: 0.0119 (0.0353)  loss_giou_0_unscaled: 0.3249 (0.5051)  cardinality_error_0_unscaled: 3857.0000 (3833.7531)  loss_ce_1_unscaled: 0.9428 (0.8720)  loss_bbox_1_unscaled: 0.0117 (0.0349)  loss_giou_1_unscaled: 0.3405 (0.5151)  cardinality_error_1_unscaled: 3856.0000 (3831.3580)  loss_ce_enc_unscaled: 0.9836 (0.8782)  loss_bbox_enc_unscaled: 0.0118 (0.0381)  loss_giou_enc_unscaled: 0.3710 (0.5343)  cardinality_error_enc_unscaled: 3856.0000 (3816.9012)  time: 3.2516  data: 0.0102  max mem: 38593
# Epoch: [0]  [ 90/759]  eta: 0:36:49  lr: 0.001000  class_error: 55.56  loss: 7.0709 (8.2775)  loss_ce: 0.9082 (0.8729)  loss_bbox: 0.0661 (0.1647)  loss_giou: 0.7837 (1.0117)  loss_ce_0: 0.9547 (0.9007)  loss_bbox_0: 0.0658 (0.1673)  loss_giou_0: 0.7296 (0.9948)  loss_ce_1: 0.9094 (0.8730)  loss_bbox_1: 0.0645 (0.1659)  loss_giou_1: 0.7727 (1.0132)  loss_ce_enc: 0.9513 (0.8820)  loss_bbox_enc: 0.0657 (0.1800)  loss_giou_enc: 0.7694 (1.0512)  loss_ce_unscaled: 0.9082 (0.8729)  class_error_unscaled: 46.1538 (54.3745)  loss_bbox_unscaled: 0.0132 (0.0329)  loss_giou_unscaled: 0.3919 (0.5059)  cardinality_error_unscaled: 3852.0000 (3825.4835)  loss_ce_0_unscaled: 0.9547 (0.9007)  loss_bbox_0_unscaled: 0.0132 (0.0335)  loss_giou_0_unscaled: 0.3648 (0.4974)  cardinality_error_0_unscaled: 3852.0000 (3829.7143)  loss_ce_1_unscaled: 0.9094 (0.8730)  loss_bbox_1_unscaled: 0.0129 (0.0332)  loss_giou_1_unscaled: 0.3864 (0.5066)  cardinality_error_1_unscaled: 3852.0000 (3827.5824)  loss_ce_enc_unscaled: 0.9513 (0.8820)  loss_bbox_enc_unscaled: 0.0131 (0.0360)  loss_giou_enc_unscaled: 0.3847 (0.5256)  cardinality_error_enc_unscaled: 3851.0000 (3814.6264)  time: 3.1973  data: 0.0098  max mem: 38593
# Epoch: [0]  [100/759]  eta: 0:36:14  lr: 0.001000  class_error: 47.55  loss: 7.2593 (8.2092)  loss_ce: 0.8566 (0.8709)  loss_bbox: 0.0843 (0.1605)  loss_giou: 0.8552 (1.0009)  loss_ce_0: 0.9163 (0.9025)  loss_bbox_0: 0.0777 (0.1621)  loss_giou_0: 0.8341 (0.9831)  loss_ce_1: 0.8704 (0.8718)  loss_bbox_1: 0.0830 (0.1615)  loss_giou_1: 0.8567 (1.0019)  loss_ce_enc: 0.9232 (0.8844)  loss_bbox_enc: 0.0836 (0.1739)  loss_giou_enc: 0.9067 (1.0358)  loss_ce_unscaled: 0.8566 (0.8709)  class_error_unscaled: 48.2517 (53.2179)  loss_bbox_unscaled: 0.0169 (0.0321)  loss_giou_unscaled: 0.4276 (0.5004)  cardinality_error_unscaled: 3818.0000 (3823.2673)  loss_ce_0_unscaled: 0.9163 (0.9025)  loss_bbox_0_unscaled: 0.0155 (0.0324)  loss_giou_0_unscaled: 0.4171 (0.4915)  cardinality_error_0_unscaled: 3818.0000 (3827.0792)  loss_ce_1_unscaled: 0.8704 (0.8718)  loss_bbox_1_unscaled: 0.0166 (0.0323)  loss_giou_1_unscaled: 0.4284 (0.5009)  cardinality_error_1_unscaled: 3818.0000 (3825.1485)  loss_ce_enc_unscaled: 0.9232 (0.8844)  loss_bbox_enc_unscaled: 0.0167 (0.0348)  loss_giou_enc_unscaled: 0.4534 (0.5179)  cardinality_error_enc_unscaled: 3818.0000 (3813.4851)  time: 3.2244  data: 0.0098  max mem: 38593
# Epoch: [0]  [110/759]  eta: 0:35:37  lr: 0.001000  class_error: 67.66  loss: 7.4162 (8.1318)  loss_ce: 0.8830 (0.8755)  loss_bbox: 0.1095 (0.1550)  loss_giou: 0.8359 (0.9822)  loss_ce_0: 0.9745 (0.9085)  loss_bbox_0: 0.1065 (0.1561)  loss_giou_0: 0.7971 (0.9644)  loss_ce_1: 0.9006 (0.8767)  loss_bbox_1: 0.1110 (0.1557)  loss_giou_1: 0.8536 (0.9828)  loss_ce_enc: 0.9573 (0.8929)  loss_bbox_enc: 0.1080 (0.1672)  loss_giou_enc: 0.8073 (1.0148)  loss_ce_unscaled: 0.8830 (0.8755)  class_error_unscaled: 46.1538 (53.3261)  loss_bbox_unscaled: 0.0219 (0.0310)  loss_giou_unscaled: 0.4180 (0.4911)  cardinality_error_unscaled: 3826.0000 (3822.9369)  loss_ce_0_unscaled: 0.9745 (0.9085)  loss_bbox_0_unscaled: 0.0213 (0.0312)  loss_giou_0_unscaled: 0.3985 (0.4822)  cardinality_error_0_unscaled: 3826.0000 (3826.4775)  loss_ce_1_unscaled: 0.9006 (0.8767)  loss_bbox_1_unscaled: 0.0222 (0.0311)  loss_giou_1_unscaled: 0.4268 (0.4914)  cardinality_error_1_unscaled: 3826.0000 (3824.3063)  loss_ce_enc_unscaled: 0.9573 (0.8929)  loss_bbox_enc_unscaled: 0.0216 (0.0334)  loss_giou_enc_unscaled: 0.4037 (0.5074)  cardinality_error_enc_unscaled: 3826.0000 (3813.6667)  time: 3.2514  data: 0.0101  max mem: 38593
# Epoch: [0]  [120/759]  eta: 0:35:05  lr: 0.001000  class_error: 27.97  loss: 6.9829 (8.0682)  loss_ce: 0.9205 (0.8738)  loss_bbox: 0.0660 (0.1506)  loss_giou: 0.7977 (0.9725)  loss_ce_0: 0.9795 (0.9064)  loss_bbox_0: 0.0685 (0.1514)  loss_giou_0: 0.7774 (0.9560)  loss_ce_1: 0.9339 (0.8749)  loss_bbox_1: 0.0680 (0.1513)  loss_giou_1: 0.8012 (0.9724)  loss_ce_enc: 0.9803 (0.8913)  loss_bbox_enc: 0.0764 (0.1620)  loss_giou_enc: 0.7999 (1.0056)  loss_ce_unscaled: 0.9205 (0.8738)  class_error_unscaled: 46.3267 (52.3773)  loss_bbox_unscaled: 0.0132 (0.0301)  loss_giou_unscaled: 0.3988 (0.4863)  cardinality_error_unscaled: 3846.0000 (3817.8926)  loss_ce_0_unscaled: 0.9795 (0.9064)  loss_bbox_0_unscaled: 0.0137 (0.0303)  loss_giou_0_unscaled: 0.3887 (0.4780)  cardinality_error_0_unscaled: 3848.0000 (3821.1405)  loss_ce_1_unscaled: 0.9339 (0.8749)  loss_bbox_1_unscaled: 0.0136 (0.0303)  loss_giou_1_unscaled: 0.4006 (0.4862)  cardinality_error_1_unscaled: 3832.0000 (3819.1488)  loss_ce_enc_unscaled: 0.9803 (0.8913)  loss_bbox_enc_unscaled: 0.0153 (0.0324)  loss_giou_enc_unscaled: 0.3999 (0.5028)  cardinality_error_enc_unscaled: 3843.0000 (3809.3636)  time: 3.2745  data: 0.0100  max mem: 38593
# Epoch: [0]  [130/759]  eta: 0:34:24  lr: 0.001000  class_error: 31.89  loss: 7.1528 (7.9863)  loss_ce: 0.9028 (0.8767)  loss_bbox: 0.0660 (0.1448)  loss_giou: 0.7605 (0.9544)  loss_ce_0: 0.9415 (0.9113)  loss_bbox_0: 0.0683 (0.1457)  loss_giou_0: 0.7656 (0.9369)  loss_ce_1: 0.9065 (0.8790)  loss_bbox_1: 0.0679 (0.1455)  loss_giou_1: 0.7618 (0.9536)  loss_ce_enc: 0.9318 (0.8958)  loss_bbox_enc: 0.0661 (0.1554)  loss_giou_enc: 0.7999 (0.9870)  loss_ce_unscaled: 0.9028 (0.8767)  class_error_unscaled: 42.1911 (51.7957)  loss_bbox_unscaled: 0.0132 (0.0290)  loss_giou_unscaled: 0.3803 (0.4772)  cardinality_error_unscaled: 3830.0000 (3819.7481)  loss_ce_0_unscaled: 0.9415 (0.9113)  loss_bbox_0_unscaled: 0.0137 (0.0291)  loss_giou_0_unscaled: 0.3828 (0.4685)  cardinality_error_0_unscaled: 3830.0000 (3822.7557)  loss_ce_1_unscaled: 0.9065 (0.8790)  loss_bbox_1_unscaled: 0.0136 (0.0291)  loss_giou_1_unscaled: 0.3809 (0.4768)  cardinality_error_1_unscaled: 3811.0000 (3820.1908)  loss_ce_enc_unscaled: 0.9318 (0.8958)  loss_bbox_enc_unscaled: 0.0132 (0.0311)  loss_giou_enc_unscaled: 0.3999 (0.4935)  cardinality_error_enc_unscaled: 3830.0000 (3811.6412)  time: 3.2216  data: 0.0098  max mem: 38593
# Epoch: [0]  [140/759]  eta: 0:33:48  lr: 0.001000  class_error: 55.13  loss: 7.1528 (7.9387)  loss_ce: 0.9213 (0.8811)  loss_bbox: 0.0666 (0.1415)  loss_giou: 0.7068 (0.9417)  loss_ce_0: 1.0035 (0.9166)  loss_bbox_0: 0.0568 (0.1418)  loss_giou_0: 0.6481 (0.9233)  loss_ce_1: 0.9283 (0.8840)  loss_bbox_1: 0.0664 (0.1421)  loss_giou_1: 0.7002 (0.9409)  loss_ce_enc: 0.9610 (0.9008)  loss_bbox_enc: 0.0661 (0.1512)  loss_giou_enc: 0.7029 (0.9736)  loss_ce_unscaled: 0.9213 (0.8811)  class_error_unscaled: 45.8462 (51.5784)  loss_bbox_unscaled: 0.0133 (0.0283)  loss_giou_unscaled: 0.3534 (0.4708)  cardinality_error_unscaled: 3856.0000 (3819.8156)  loss_ce_0_unscaled: 1.0035 (0.9166)  loss_bbox_0_unscaled: 0.0114 (0.0284)  loss_giou_0_unscaled: 0.3241 (0.4616)  cardinality_error_0_unscaled: 3857.0000 (3822.6879)  loss_ce_1_unscaled: 0.9283 (0.8840)  loss_bbox_1_unscaled: 0.0133 (0.0284)  loss_giou_1_unscaled: 0.3501 (0.4704)  cardinality_error_1_unscaled: 3837.0000 (3820.0567)  loss_ce_enc_unscaled: 0.9610 (0.9008)  loss_bbox_enc_unscaled: 0.0132 (0.0302)  loss_giou_enc_unscaled: 0.3515 (0.4868)  cardinality_error_enc_unscaled: 3851.0000 (3811.9787)  time: 3.1693  data: 0.0097  max mem: 38593
# Epoch: [0]  [150/759]  eta: 0:33:13  lr: 0.001000  class_error: 45.64  loss: 7.0575 (7.8924)  loss_ce: 0.9239 (0.8847)  loss_bbox: 0.0666 (0.1367)  loss_giou: 0.7068 (0.9315)  loss_ce_0: 0.9888 (0.9192)  loss_bbox_0: 0.0566 (0.1368)  loss_giou_0: 0.6710 (0.9127)  loss_ce_1: 0.9291 (0.8874)  loss_bbox_1: 0.0664 (0.1372)  loss_giou_1: 0.7002 (0.9301)  loss_ce_enc: 0.9549 (0.9044)  loss_bbox_enc: 0.0685 (0.1460)  loss_giou_enc: 0.7628 (0.9657)  loss_ce_unscaled: 0.9239 (0.8847)  class_error_unscaled: 51.4255 (51.6700)  loss_bbox_unscaled: 0.0133 (0.0273)  loss_giou_unscaled: 0.3534 (0.4658)  cardinality_error_unscaled: 3848.0000 (3820.3510)  loss_ce_0_unscaled: 0.9888 (0.9192)  loss_bbox_0_unscaled: 0.0113 (0.0274)  loss_giou_0_unscaled: 0.3355 (0.4564)  cardinality_error_0_unscaled: 3848.0000 (3822.7947)  loss_ce_1_unscaled: 0.9291 (0.8874)  loss_bbox_1_unscaled: 0.0133 (0.0274)  loss_giou_1_unscaled: 0.3501 (0.4650)  cardinality_error_1_unscaled: 3837.0000 (3820.5033)  loss_ce_enc_unscaled: 0.9549 (0.9044)  loss_bbox_enc_unscaled: 0.0137 (0.0292)  loss_giou_enc_unscaled: 0.3814 (0.4828)  cardinality_error_enc_unscaled: 3842.0000 (3812.8742)  time: 3.2183  data: 0.0098  max mem: 38593
# Epoch: [0]  [160/759]  eta: 0:32:37  lr: 0.001000  class_error: 59.37  loss: 6.9003 (7.8204)  loss_ce: 0.9080 (0.8884)  loss_bbox: 0.0485 (0.1314)  loss_giou: 0.7061 (0.9144)  loss_ce_0: 0.9670 (0.9257)  loss_bbox_0: 0.0445 (0.1314)  loss_giou_0: 0.6875 (0.8959)  loss_ce_1: 0.9152 (0.8910)  loss_bbox_1: 0.0473 (0.1318)  loss_giou_1: 0.6960 (0.9132)  loss_ce_enc: 0.9319 (0.9095)  loss_bbox_enc: 0.0438 (0.1402)  loss_giou_enc: 0.7400 (0.9475)  loss_ce_unscaled: 0.9080 (0.8884)  class_error_unscaled: 46.0317 (51.0648)  loss_bbox_unscaled: 0.0097 (0.0263)  loss_giou_unscaled: 0.3530 (0.4572)  cardinality_error_unscaled: 3853.0000 (3823.0373)  loss_ce_0_unscaled: 0.9670 (0.9257)  loss_bbox_0_unscaled: 0.0089 (0.0263)  loss_giou_0_unscaled: 0.3437 (0.4479)  cardinality_error_0_unscaled: 3837.0000 (3820.0435)  loss_ce_1_unscaled: 0.9152 (0.8910)  loss_bbox_1_unscaled: 0.0095 (0.0264)  loss_giou_1_unscaled: 0.3480 (0.4566)  cardinality_error_1_unscaled: 3834.0000 (3820.9565)  loss_ce_enc_unscaled: 0.9319 (0.9095)  loss_bbox_enc_unscaled: 0.0088 (0.0280)  loss_giou_enc_unscaled: 0.3700 (0.4738)  cardinality_error_enc_unscaled: 3822.0000 (3812.3665)  time: 3.1999  data: 0.0101  max mem: 38593
# Epoch: [0]  [170/759]  eta: 0:32:05  lr: 0.001000  class_error: 24.77  loss: 6.7571 (7.7689)  loss_ce: 0.9121 (0.8906)  loss_bbox: 0.0496 (0.1275)  loss_giou: 0.6887 (0.9025)  loss_ce_0: 1.0014 (0.9305)  loss_bbox_0: 0.0429 (0.1273)  loss_giou_0: 0.6757 (0.8833)  loss_ce_1: 0.9151 (0.8939)  loss_bbox_1: 0.0456 (0.1279)  loss_giou_1: 0.6808 (0.9014)  loss_ce_enc: 0.9659 (0.9135)  loss_bbox_enc: 0.0429 (0.1358)  loss_giou_enc: 0.7036 (0.9348)  loss_ce_unscaled: 0.9121 (0.8906)  class_error_unscaled: 45.2991 (51.2764)  loss_bbox_unscaled: 0.0099 (0.0255)  loss_giou_unscaled: 0.3444 (0.4512)  cardinality_error_unscaled: 3863.0000 (3824.3509)  loss_ce_0_unscaled: 1.0014 (0.9305)  loss_bbox_0_unscaled: 0.0086 (0.0255)  loss_giou_0_unscaled: 0.3378 (0.4416)  cardinality_error_0_unscaled: 3850.0000 (3821.5263)  loss_ce_1_unscaled: 0.9151 (0.8939)  loss_bbox_1_unscaled: 0.0091 (0.0256)  loss_giou_1_unscaled: 0.3404 (0.4507)  cardinality_error_1_unscaled: 3851.0000 (3822.3918)  loss_ce_enc_unscaled: 0.9659 (0.9135)  loss_bbox_enc_unscaled: 0.0086 (0.0272)  loss_giou_enc_unscaled: 0.3518 (0.4674)  cardinality_error_enc_unscaled: 3822.0000 (3813.9649)  time: 3.2348  data: 0.0100  max mem: 38593
# Epoch: [0]  [180/759]  eta: 0:31:29  lr: 0.001000  class_error: 50.00  loss: 6.8539 (7.7215)  loss_ce: 0.9278 (0.8938)  loss_bbox: 0.0560 (0.1241)  loss_giou: 0.6829 (0.8909)  loss_ce_0: 0.9850 (0.9345)  loss_bbox_0: 0.0518 (0.1237)  loss_giou_0: 0.6757 (0.8713)  loss_ce_1: 0.9310 (0.8976)  loss_bbox_1: 0.0546 (0.1244)  loss_giou_1: 0.6797 (0.8889)  loss_ce_enc: 0.9659 (0.9165)  loss_bbox_enc: 0.0525 (0.1320)  loss_giou_enc: 0.7163 (0.9239)  loss_ce_unscaled: 0.9278 (0.8938)  class_error_unscaled: 52.4038 (51.1344)  loss_bbox_unscaled: 0.0112 (0.0248)  loss_giou_unscaled: 0.3414 (0.4455)  cardinality_error_unscaled: 3850.0000 (3825.4641)  loss_ce_0_unscaled: 0.9850 (0.9345)  loss_bbox_0_unscaled: 0.0104 (0.0247)  loss_giou_0_unscaled: 0.3378 (0.4356)  cardinality_error_0_unscaled: 3850.0000 (3822.7956)  loss_ce_1_unscaled: 0.9310 (0.8976)  loss_bbox_1_unscaled: 0.0109 (0.0249)  loss_giou_1_unscaled: 0.3399 (0.4444)  cardinality_error_1_unscaled: 3850.0000 (3823.6133)  loss_ce_enc_unscaled: 0.9659 (0.9165)  loss_bbox_enc_unscaled: 0.0105 (0.0264)  loss_giou_enc_unscaled: 0.3581 (0.4620)  cardinality_error_enc_unscaled: 3847.0000 (3815.5304)  time: 3.2335  data: 0.0098  max mem: 38593
# Epoch: [0]  [190/759]  eta: 0:30:56  lr: 0.001000  class_error: 57.03  loss: 6.8148 (7.6720)  loss_ce: 0.9373 (0.8952)  loss_bbox: 0.0437 (0.1198)  loss_giou: 0.6714 (0.8810)  loss_ce_0: 0.9687 (0.9357)  loss_bbox_0: 0.0420 (0.1194)  loss_giou_0: 0.6819 (0.8612)  loss_ce_1: 0.9466 (0.8991)  loss_bbox_1: 0.0458 (0.1202)  loss_giou_1: 0.6656 (0.8792)  loss_ce_enc: 0.9516 (0.9180)  loss_bbox_enc: 0.0502 (0.1276)  loss_giou_enc: 0.7369 (0.9156)  loss_ce_unscaled: 0.9373 (0.8952)  class_error_unscaled: 48.3258 (50.8097)  loss_bbox_unscaled: 0.0087 (0.0240)  loss_giou_unscaled: 0.3357 (0.4405)  cardinality_error_unscaled: 3839.0000 (3825.8168)  loss_ce_0_unscaled: 0.9687 (0.9357)  loss_bbox_0_unscaled: 0.0084 (0.0239)  loss_giou_0_unscaled: 0.3409 (0.4306)  cardinality_error_0_unscaled: 3839.0000 (3823.2880)  loss_ce_1_unscaled: 0.9466 (0.8991)  loss_bbox_1_unscaled: 0.0092 (0.0240)  loss_giou_1_unscaled: 0.3328 (0.4396)  cardinality_error_1_unscaled: 3839.0000 (3824.0524)  loss_ce_enc_unscaled: 0.9516 (0.9180)  loss_bbox_enc_unscaled: 0.0100 (0.0255)  loss_giou_enc_unscaled: 0.3684 (0.4578)  cardinality_error_enc_unscaled: 3839.0000 (3816.2670)  time: 3.2154  data: 0.0099  max mem: 38593
# Epoch: [0]  [200/759]  eta: 0:30:21  lr: 0.001000  class_error: 9.06  loss: 6.7777 (7.6283)  loss_ce: 0.8900 (0.8951)  loss_bbox: 0.0451 (0.1177)  loss_giou: 0.7231 (0.8722)  loss_ce_0: 0.9392 (0.9362)  loss_bbox_0: 0.0426 (0.1169)  loss_giou_0: 0.7020 (0.8525)  loss_ce_1: 0.9001 (0.8993)  loss_bbox_1: 0.0463 (0.1180)  loss_giou_1: 0.7123 (0.8705)  loss_ce_enc: 0.9252 (0.9183)  loss_bbox_enc: 0.0502 (0.1250)  loss_giou_enc: 0.7587 (0.9067)  loss_ce_unscaled: 0.8900 (0.8951)  class_error_unscaled: 44.7115 (50.3045)  loss_bbox_unscaled: 0.0090 (0.0235)  loss_giou_unscaled: 0.3615 (0.4361)  cardinality_error_unscaled: 3834.0000 (3825.8756)  loss_ce_0_unscaled: 0.9392 (0.9362)  loss_bbox_0_unscaled: 0.0085 (0.0234)  loss_giou_0_unscaled: 0.3510 (0.4262)  cardinality_error_0_unscaled: 3833.0000 (3823.1493)  loss_ce_1_unscaled: 0.9001 (0.8993)  loss_bbox_1_unscaled: 0.0093 (0.0236)  loss_giou_1_unscaled: 0.3561 (0.4353)  cardinality_error_1_unscaled: 3834.0000 (3824.1194)  loss_ce_enc_unscaled: 0.9252 (0.9183)  loss_bbox_enc_unscaled: 0.0100 (0.0250)  loss_giou_enc_unscaled: 0.3793 (0.4534)  cardinality_error_enc_unscaled: 3830.0000 (3816.6567)  time: 3.2113  data: 0.0099  max mem: 38593
# Epoch: [0]  [210/759]  eta: 0:29:47  lr: 0.001000  class_error: 70.96  loss: 6.8402 (7.5896)  loss_ce: 0.8776 (0.8956)  loss_bbox: 0.0578 (0.1149)  loss_giou: 0.7094 (0.8649)  loss_ce_0: 0.9392 (0.9380)  loss_bbox_0: 0.0520 (0.1140)  loss_giou_0: 0.6970 (0.8445)  loss_ce_1: 0.9001 (0.9002)  loss_bbox_1: 0.0564 (0.1152)  loss_giou_1: 0.6850 (0.8627)  loss_ce_enc: 0.9122 (0.9194)  loss_bbox_enc: 0.0517 (0.1218)  loss_giou_enc: 0.7051 (0.8983)  loss_ce_unscaled: 0.8776 (0.8956)  class_error_unscaled: 42.0000 (50.0800)  loss_bbox_unscaled: 0.0116 (0.0230)  loss_giou_unscaled: 0.3547 (0.4324)  cardinality_error_unscaled: 3855.0000 (3827.1280)  loss_ce_0_unscaled: 0.9392 (0.9380)  loss_bbox_0_unscaled: 0.0104 (0.0228)  loss_giou_0_unscaled: 0.3485 (0.4223)  cardinality_error_0_unscaled: 3850.0000 (3824.5213)  loss_ce_1_unscaled: 0.9001 (0.9002)  loss_bbox_1_unscaled: 0.0113 (0.0230)  loss_giou_1_unscaled: 0.3425 (0.4314)  cardinality_error_1_unscaled: 3855.0000 (3825.4265)  loss_ce_enc_unscaled: 0.9122 (0.9194)  loss_bbox_enc_unscaled: 0.0103 (0.0244)  loss_giou_enc_unscaled: 0.3526 (0.4491)  cardinality_error_enc_unscaled: 3855.0000 (3818.2701)  time: 3.1834  data: 0.0100  max mem: 38593
# Epoch: [0]  [220/759]  eta: 0:29:14  lr: 0.001000  class_error: 42.88  loss: 6.8402 (7.5785)  loss_ce: 0.8776 (0.8936)  loss_bbox: 0.0536 (0.1153)  loss_giou: 0.7227 (0.8637)  loss_ce_0: 0.9244 (0.9356)  loss_bbox_0: 0.0542 (0.1142)  loss_giou_0: 0.6970 (0.8438)  loss_ce_1: 0.8733 (0.8980)  loss_bbox_1: 0.0553 (0.1155)  loss_giou_1: 0.7140 (0.8619)  loss_ce_enc: 0.8899 (0.9167)  loss_bbox_enc: 0.0557 (0.1219)  loss_giou_enc: 0.7312 (0.8982)  loss_ce_unscaled: 0.8776 (0.8936)  class_error_unscaled: 42.0000 (49.6133)  loss_bbox_unscaled: 0.0107 (0.0231)  loss_giou_unscaled: 0.3614 (0.4319)  cardinality_error_unscaled: 3855.0000 (3826.2172)  loss_ce_0_unscaled: 0.9244 (0.9356)  loss_bbox_0_unscaled: 0.0108 (0.0228)  loss_giou_0_unscaled: 0.3485 (0.4219)  cardinality_error_0_unscaled: 3855.0000 (3823.7240)  loss_ce_1_unscaled: 0.8733 (0.8980)  loss_bbox_1_unscaled: 0.0111 (0.0231)  loss_giou_1_unscaled: 0.3570 (0.4310)  cardinality_error_1_unscaled: 3855.0000 (3824.5339)  loss_ce_enc_unscaled: 0.8899 (0.9167)  loss_bbox_enc_unscaled: 0.0111 (0.0244)  loss_giou_enc_unscaled: 0.3656 (0.4491)  cardinality_error_enc_unscaled: 3855.0000 (3817.8100)  time: 3.2205  data: 0.0100  max mem: 38593
# Epoch: [0]  [230/759]  eta: 0:28:41  lr: 0.001000  class_error: 41.98  loss: 6.7238 (7.5384)  loss_ce: 0.8708 (0.8928)  loss_bbox: 0.0543 (0.1128)  loss_giou: 0.7227 (0.8563)  loss_ce_0: 0.9244 (0.9351)  loss_bbox_0: 0.0549 (0.1116)  loss_giou_0: 0.7177 (0.8369)  loss_ce_1: 0.8814 (0.8975)  loss_bbox_1: 0.0547 (0.1128)  loss_giou_1: 0.7140 (0.8543)  loss_ce_enc: 0.8899 (0.9155)  loss_bbox_enc: 0.0565 (0.1193)  loss_giou_enc: 0.7531 (0.8934)  loss_ce_unscaled: 0.8708 (0.8928)  class_error_unscaled: 42.0118 (49.2902)  loss_bbox_unscaled: 0.0109 (0.0226)  loss_giou_unscaled: 0.3614 (0.4282)  cardinality_error_unscaled: 3855.0000 (3825.3766)  loss_ce_0_unscaled: 0.9244 (0.9351)  loss_bbox_0_unscaled: 0.0110 (0.0223)  loss_giou_0_unscaled: 0.3589 (0.4184)  cardinality_error_0_unscaled: 3855.0000 (3822.9870)  loss_ce_1_unscaled: 0.8814 (0.8975)  loss_bbox_1_unscaled: 0.0109 (0.0226)  loss_giou_1_unscaled: 0.3570 (0.4272)  cardinality_error_1_unscaled: 3850.0000 (3823.7662)  loss_ce_enc_unscaled: 0.8899 (0.9155)  loss_bbox_enc_unscaled: 0.0113 (0.0239)  loss_giou_enc_unscaled: 0.3766 (0.4467)  cardinality_error_enc_unscaled: 3855.0000 (3817.3333)  time: 3.2466  data: 0.0097  max mem: 38593
# Epoch: [0]  [240/759]  eta: 0:28:08  lr: 0.001000  class_error: 49.82  loss: 6.7267 (7.5058)  loss_ce: 0.8835 (0.8931)  loss_bbox: 0.0543 (0.1104)  loss_giou: 0.7168 (0.8498)  loss_ce_0: 0.9444 (0.9361)  loss_bbox_0: 0.0542 (0.1091)  loss_giou_0: 0.7013 (0.8305)  loss_ce_1: 0.8992 (0.8976)  loss_bbox_1: 0.0543 (0.1104)  loss_giou_1: 0.7079 (0.8478)  loss_ce_enc: 0.9121 (0.9152)  loss_bbox_enc: 0.0569 (0.1169)  loss_giou_enc: 0.7407 (0.8889)  loss_ce_unscaled: 0.8835 (0.8931)  class_error_unscaled: 42.0118 (49.0007)  loss_bbox_unscaled: 0.0109 (0.0221)  loss_giou_unscaled: 0.3584 (0.4249)  cardinality_error_unscaled: 3865.0000 (3826.5519)  loss_ce_0_unscaled: 0.9444 (0.9361)  loss_bbox_0_unscaled: 0.0108 (0.0218)  loss_giou_0_unscaled: 0.3506 (0.4153)  cardinality_error_0_unscaled: 3864.0000 (3824.2573)  loss_ce_1_unscaled: 0.8992 (0.8976)  loss_bbox_1_unscaled: 0.0109 (0.0221)  loss_giou_1_unscaled: 0.3540 (0.4239)  cardinality_error_1_unscaled: 3865.0000 (3825.0083)  loss_ce_enc_unscaled: 0.9121 (0.9152)  loss_bbox_enc_unscaled: 0.0114 (0.0234)  loss_giou_enc_unscaled: 0.3704 (0.4444)  cardinality_error_enc_unscaled: 3862.0000 (3818.6722)  time: 3.2203  data: 0.0097  max mem: 38593
# Epoch: [0]  [250/759]  eta: 0:27:33  lr: 0.001000  class_error: 77.97  loss: 6.7371 (7.4753)  loss_ce: 0.8988 (0.8932)  loss_bbox: 0.0563 (0.1083)  loss_giou: 0.7188 (0.8441)  loss_ce_0: 0.9453 (0.9361)  loss_bbox_0: 0.0529 (0.1070)  loss_giou_0: 0.6842 (0.8250)  loss_ce_1: 0.8971 (0.8977)  loss_bbox_1: 0.0553 (0.1083)  loss_giou_1: 0.7090 (0.8423)  loss_ce_enc: 0.9121 (0.9150)  loss_bbox_enc: 0.0569 (0.1147)  loss_giou_enc: 0.7407 (0.8834)  loss_ce_unscaled: 0.8988 (0.8932)  class_error_unscaled: 41.0989 (48.9240)  loss_bbox_unscaled: 0.0113 (0.0217)  loss_giou_unscaled: 0.3594 (0.4220)  cardinality_error_unscaled: 3844.0000 (3826.2908)  loss_ce_0_unscaled: 0.9453 (0.9361)  loss_bbox_0_unscaled: 0.0106 (0.0214)  loss_giou_0_unscaled: 0.3421 (0.4125)  cardinality_error_0_unscaled: 3842.0000 (3824.0558)  loss_ce_1_unscaled: 0.8971 (0.8977)  loss_bbox_1_unscaled: 0.0111 (0.0217)  loss_giou_1_unscaled: 0.3545 (0.4212)  cardinality_error_1_unscaled: 3837.0000 (3824.7490)  loss_ce_enc_unscaled: 0.9121 (0.9150)  loss_bbox_enc_unscaled: 0.0114 (0.0229)  loss_giou_enc_unscaled: 0.3704 (0.4417)  cardinality_error_enc_unscaled: 3835.0000 (3818.6414)  time: 3.1675  data: 0.0097  max mem: 38593
# Epoch: [0]  [260/759]  eta: 0:26:58  lr: 0.001000  class_error: 31.15  loss: 6.6874 (7.4443)  loss_ce: 0.9074 (0.8944)  loss_bbox: 0.0500 (0.1061)  loss_giou: 0.6712 (0.8370)  loss_ce_0: 0.9533 (0.9374)  loss_bbox_0: 0.0494 (0.1049)  loss_giou_0: 0.6709 (0.8181)  loss_ce_1: 0.9177 (0.8991)  loss_bbox_1: 0.0518 (0.1062)  loss_giou_1: 0.6906 (0.8354)  loss_ce_enc: 0.9253 (0.9156)  loss_bbox_enc: 0.0540 (0.1124)  loss_giou_enc: 0.7407 (0.8777)  loss_ce_unscaled: 0.9074 (0.8944)  class_error_unscaled: 52.2706 (49.0383)  loss_bbox_unscaled: 0.0100 (0.0212)  loss_giou_unscaled: 0.3356 (0.4185)  cardinality_error_unscaled: 3843.0000 (3827.2759)  loss_ce_0_unscaled: 0.9533 (0.9374)  loss_bbox_0_unscaled: 0.0099 (0.0210)  loss_giou_0_unscaled: 0.3355 (0.4090)  cardinality_error_0_unscaled: 3842.0000 (3825.1226)  loss_ce_1_unscaled: 0.9177 (0.8991)  loss_bbox_1_unscaled: 0.0104 (0.0212)  loss_giou_1_unscaled: 0.3453 (0.4177)  cardinality_error_1_unscaled: 3837.0000 (3825.7893)  loss_ce_enc_unscaled: 0.9253 (0.9156)  loss_bbox_enc_unscaled: 0.0108 (0.0225)  loss_giou_enc_unscaled: 0.3704 (0.4389)  cardinality_error_enc_unscaled: 3832.0000 (3819.9195)  time: 3.1309  data: 0.0097  max mem: 38593
# Epoch: [0]  [270/759]  eta: 0:26:25  lr: 0.001000  class_error: 56.09  loss: 6.6421 (7.4226)  loss_ce: 0.9135 (0.8952)  loss_bbox: 0.0459 (0.1044)  loss_giou: 0.6537 (0.8329)  loss_ce_0: 0.9678 (0.9385)  loss_bbox_0: 0.0449 (0.1031)  loss_giou_0: 0.6346 (0.8139)  loss_ce_1: 0.9192 (0.8998)  loss_bbox_1: 0.0474 (0.1045)  loss_giou_1: 0.6505 (0.8313)  loss_ce_enc: 0.9301 (0.9157)  loss_bbox_enc: 0.0529 (0.1106)  loss_giou_enc: 0.7578 (0.8728)  loss_ce_unscaled: 0.9135 (0.8952)  class_error_unscaled: 46.4103 (48.9216)  loss_bbox_unscaled: 0.0092 (0.0209)  loss_giou_unscaled: 0.3269 (0.4164)  cardinality_error_unscaled: 3853.0000 (3827.6273)  loss_ce_0_unscaled: 0.9678 (0.9385)  loss_bbox_0_unscaled: 0.0090 (0.0206)  loss_giou_0_unscaled: 0.3173 (0.4070)  cardinality_error_0_unscaled: 3853.0000 (3825.5535)  loss_ce_1_unscaled: 0.9192 (0.8998)  loss_bbox_1_unscaled: 0.0095 (0.0209)  loss_giou_1_unscaled: 0.3253 (0.4156)  cardinality_error_1_unscaled: 3853.0000 (3826.1956)  loss_ce_enc_unscaled: 0.9301 (0.9157)  loss_bbox_enc_unscaled: 0.0106 (0.0221)  loss_giou_enc_unscaled: 0.3789 (0.4364)  cardinality_error_enc_unscaled: 3853.0000 (3820.5424)  time: 3.1690  data: 0.0096  max mem: 38593
# Epoch: [0]  [280/759]  eta: 0:25:53  lr: 0.001000  class_error: 55.38  loss: 6.4834 (7.3889)  loss_ce: 0.9309 (0.8964)  loss_bbox: 0.0437 (0.1022)  loss_giou: 0.6374 (0.8257)  loss_ce_0: 0.9848 (0.9400)  loss_bbox_0: 0.0423 (0.1009)  loss_giou_0: 0.6090 (0.8069)  loss_ce_1: 0.9165 (0.9006)  loss_bbox_1: 0.0426 (0.1023)  loss_giou_1: 0.6351 (0.8246)  loss_ce_enc: 0.9301 (0.9164)  loss_bbox_enc: 0.0423 (0.1082)  loss_giou_enc: 0.6254 (0.8646)  loss_ce_unscaled: 0.9309 (0.8964)  class_error_unscaled: 45.1719 (48.9914)  loss_bbox_unscaled: 0.0087 (0.0204)  loss_giou_unscaled: 0.3187 (0.4129)  cardinality_error_unscaled: 3853.0000 (3827.6762)  loss_ce_0_unscaled: 0.9848 (0.9400)  loss_bbox_0_unscaled: 0.0085 (0.0202)  loss_giou_0_unscaled: 0.3045 (0.4035)  cardinality_error_0_unscaled: 3853.0000 (3825.6762)  loss_ce_1_unscaled: 0.9165 (0.9006)  loss_bbox_1_unscaled: 0.0085 (0.0205)  loss_giou_1_unscaled: 0.3175 (0.4123)  cardinality_error_1_unscaled: 3853.0000 (3826.2954)  loss_ce_enc_unscaled: 0.9301 (0.9164)  loss_bbox_enc_unscaled: 0.0085 (0.0216)  loss_giou_enc_unscaled: 0.3127 (0.4323)  cardinality_error_enc_unscaled: 3853.0000 (3820.8292)  time: 3.2369  data: 0.0097  max mem: 38593
# Epoch: [0]  [290/759]  eta: 0:25:20  lr: 0.001000  class_error: 75.21  loss: 6.5521 (7.3773)  loss_ce: 0.8834 (0.8960)  loss_bbox: 0.0418 (0.1014)  loss_giou: 0.6907 (0.8243)  loss_ce_0: 0.9424 (0.9392)  loss_bbox_0: 0.0447 (0.1001)  loss_giou_0: 0.6802 (0.8057)  loss_ce_1: 0.8947 (0.9002)  loss_bbox_1: 0.0426 (0.1015)  loss_giou_1: 0.6878 (0.8231)  loss_ce_enc: 0.9063 (0.9150)  loss_bbox_enc: 0.0513 (0.1072)  loss_giou_enc: 0.7033 (0.8635)  loss_ce_unscaled: 0.8834 (0.8960)  class_error_unscaled: 48.8294 (49.0470)  loss_bbox_unscaled: 0.0084 (0.0203)  loss_giou_unscaled: 0.3454 (0.4121)  cardinality_error_unscaled: 3860.0000 (3827.3540)  loss_ce_0_unscaled: 0.9424 (0.9392)  loss_bbox_0_unscaled: 0.0089 (0.0200)  loss_giou_0_unscaled: 0.3401 (0.4028)  cardinality_error_0_unscaled: 3853.0000 (3825.2990)  loss_ce_1_unscaled: 0.8947 (0.9002)  loss_bbox_1_unscaled: 0.0085 (0.0203)  loss_giou_1_unscaled: 0.3439 (0.4116)  cardinality_error_1_unscaled: 3855.0000 (3825.9588)  loss_ce_enc_unscaled: 0.9063 (0.9150)  loss_bbox_enc_unscaled: 0.0103 (0.0214)  loss_giou_enc_unscaled: 0.3516 (0.4317)  cardinality_error_enc_unscaled: 3855.0000 (3820.6048)  time: 3.2447  data: 0.0099  max mem: 38593
# Epoch: [0]  [300/759]  eta: 0:24:46  lr: 0.001000  class_error: 42.95  loss: 6.5521 (7.3493)  loss_ce: 0.9174 (0.8969)  loss_bbox: 0.0467 (0.0995)  loss_giou: 0.6907 (0.8182)  loss_ce_0: 0.9513 (0.9399)  loss_bbox_0: 0.0449 (0.0983)  loss_giou_0: 0.6802 (0.7999)  loss_ce_1: 0.9092 (0.9009)  loss_bbox_1: 0.0464 (0.0996)  loss_giou_1: 0.6878 (0.8173)  loss_ce_enc: 0.9063 (0.9152)  loss_bbox_enc: 0.0488 (0.1053)  loss_giou_enc: 0.7294 (0.8583)  loss_ce_unscaled: 0.9174 (0.8969)  class_error_unscaled: 50.1425 (49.1097)  loss_bbox_unscaled: 0.0093 (0.0199)  loss_giou_unscaled: 0.3454 (0.4091)  cardinality_error_unscaled: 3860.0000 (3827.4850)  loss_ce_0_unscaled: 0.9513 (0.9399)  loss_bbox_0_unscaled: 0.0090 (0.0197)  loss_giou_0_unscaled: 0.3401 (0.4000)  cardinality_error_0_unscaled: 3853.0000 (3825.3920)  loss_ce_1_unscaled: 0.9092 (0.9009)  loss_bbox_1_unscaled: 0.0093 (0.0199)  loss_giou_1_unscaled: 0.3439 (0.4087)  cardinality_error_1_unscaled: 3860.0000 (3826.1993)  loss_ce_enc_unscaled: 0.9063 (0.9152)  loss_bbox_enc_unscaled: 0.0098 (0.0211)  loss_giou_enc_unscaled: 0.3647 (0.4292)  cardinality_error_enc_unscaled: 3853.0000 (3820.8306)  time: 3.1761  data: 0.0098  max mem: 38593
# Epoch: [0]  [310/759]  eta: 0:24:14  lr: 0.001000  class_error: 28.94  loss: 6.4598 (7.3194)  loss_ce: 0.9178 (0.8974)  loss_bbox: 0.0430 (0.0979)  loss_giou: 0.6070 (0.8120)  loss_ce_0: 0.9665 (0.9403)  loss_bbox_0: 0.0421 (0.0966)  loss_giou_0: 0.6028 (0.7939)  loss_ce_1: 0.9171 (0.9015)  loss_bbox_1: 0.0433 (0.0980)  loss_giou_1: 0.5986 (0.8109)  loss_ce_enc: 0.9225 (0.9154)  loss_bbox_enc: 0.0460 (0.1036)  loss_giou_enc: 0.6564 (0.8518)  loss_ce_unscaled: 0.9178 (0.8974)  class_error_unscaled: 42.9487 (48.7753)  loss_bbox_unscaled: 0.0086 (0.0196)  loss_giou_unscaled: 0.3035 (0.4060)  cardinality_error_unscaled: 3861.0000 (3827.5434)  loss_ce_0_unscaled: 0.9665 (0.9403)  loss_bbox_0_unscaled: 0.0084 (0.0193)  loss_giou_0_unscaled: 0.3014 (0.3969)  cardinality_error_0_unscaled: 3853.0000 (3825.4244)  loss_ce_1_unscaled: 0.9171 (0.9015)  loss_bbox_1_unscaled: 0.0087 (0.0196)  loss_giou_1_unscaled: 0.2993 (0.4055)  cardinality_error_1_unscaled: 3863.0000 (3826.2990)  loss_ce_enc_unscaled: 0.9225 (0.9154)  loss_bbox_enc_unscaled: 0.0092 (0.0207)  loss_giou_enc_unscaled: 0.3282 (0.4259)  cardinality_error_enc_unscaled: 3853.0000 (3821.0643)  time: 3.2032  data: 0.0098  max mem: 38593
# Epoch: [0]  [320/759]  eta: 0:23:42  lr: 0.001000  class_error: 48.89  loss: 6.5146 (7.2962)  loss_ce: 0.8995 (0.8969)  loss_bbox: 0.0475 (0.0965)  loss_giou: 0.6448 (0.8083)  loss_ce_0: 0.9345 (0.9404)  loss_bbox_0: 0.0477 (0.0952)  loss_giou_0: 0.6090 (0.7898)  loss_ce_1: 0.9016 (0.9010)  loss_bbox_1: 0.0473 (0.0965)  loss_giou_1: 0.6366 (0.8070)  loss_ce_enc: 0.9035 (0.9143)  loss_bbox_enc: 0.0529 (0.1021)  loss_giou_enc: 0.6800 (0.8481)  loss_ce_unscaled: 0.8995 (0.8969)  class_error_unscaled: 41.3187 (48.5366)  loss_bbox_unscaled: 0.0095 (0.0193)  loss_giou_unscaled: 0.3224 (0.4042)  cardinality_error_unscaled: 3855.0000 (3827.6231)  loss_ce_0_unscaled: 0.9345 (0.9404)  loss_bbox_0_unscaled: 0.0095 (0.0190)  loss_giou_0_unscaled: 0.3045 (0.3949)  cardinality_error_0_unscaled: 3849.0000 (3825.5701)  loss_ce_1_unscaled: 0.9016 (0.9010)  loss_bbox_1_unscaled: 0.0095 (0.0193)  loss_giou_1_unscaled: 0.3183 (0.4035)  cardinality_error_1_unscaled: 3855.0000 (3826.4174)  loss_ce_enc_unscaled: 0.9035 (0.9143)  loss_bbox_enc_unscaled: 0.0106 (0.0204)  loss_giou_enc_unscaled: 0.3400 (0.4240)  cardinality_error_enc_unscaled: 3853.0000 (3821.3458)  time: 3.2589  data: 0.0098  max mem: 38593
# Epoch: [0]  [330/759]  eta: 0:23:10  lr: 0.001000  class_error: 26.67  loss: 6.5564 (7.2745)  loss_ce: 0.8802 (0.8959)  loss_bbox: 0.0502 (0.0954)  loss_giou: 0.6461 (0.8049)  loss_ce_0: 0.9168 (0.9392)  loss_bbox_0: 0.0481 (0.0941)  loss_giou_0: 0.6593 (0.7870)  loss_ce_1: 0.8824 (0.8999)  loss_bbox_1: 0.0509 (0.0955)  loss_giou_1: 0.6552 (0.8038)  loss_ce_enc: 0.8693 (0.9128)  loss_bbox_enc: 0.0553 (0.1011)  loss_giou_enc: 0.6955 (0.8449)  loss_ce_unscaled: 0.8802 (0.8959)  class_error_unscaled: 40.2930 (48.1817)  loss_bbox_unscaled: 0.0100 (0.0191)  loss_giou_unscaled: 0.3231 (0.4024)  cardinality_error_unscaled: 3844.0000 (3827.5317)  loss_ce_0_unscaled: 0.9168 (0.9392)  loss_bbox_0_unscaled: 0.0096 (0.0188)  loss_giou_0_unscaled: 0.3296 (0.3935)  cardinality_error_0_unscaled: 3844.0000 (3825.5408)  loss_ce_1_unscaled: 0.8824 (0.8999)  loss_bbox_1_unscaled: 0.0102 (0.0191)  loss_giou_1_unscaled: 0.3276 (0.4019)  cardinality_error_1_unscaled: 3844.0000 (3826.3625)  loss_ce_enc_unscaled: 0.8693 (0.9128)  loss_bbox_enc_unscaled: 0.0111 (0.0202)  loss_giou_enc_unscaled: 0.3478 (0.4224)  cardinality_error_enc_unscaled: 3844.0000 (3821.4441)  time: 3.2538  data: 0.0100  max mem: 38593
# Epoch: [0]  [340/759]  eta: 0:22:37  lr: 0.001000  class_error: 20.72  loss: 6.4984 (7.2489)  loss_ce: 0.8524 (0.8950)  loss_bbox: 0.0533 (0.0941)  loss_giou: 0.6422 (0.8006)  loss_ce_0: 0.8965 (0.9383)  loss_bbox_0: 0.0558 (0.0930)  loss_giou_0: 0.6444 (0.7830)  loss_ce_1: 0.8618 (0.8990)  loss_bbox_1: 0.0573 (0.0943)  loss_giou_1: 0.6480 (0.7994)  loss_ce_enc: 0.8673 (0.9115)  loss_bbox_enc: 0.0611 (0.0998)  loss_giou_enc: 0.6946 (0.8409)  loss_ce_unscaled: 0.8524 (0.8950)  class_error_unscaled: 35.4204 (47.7509)  loss_bbox_unscaled: 0.0107 (0.0188)  loss_giou_unscaled: 0.3211 (0.4003)  cardinality_error_unscaled: 3832.0000 (3827.9326)  loss_ce_0_unscaled: 0.8965 (0.9383)  loss_bbox_0_unscaled: 0.0112 (0.0186)  loss_giou_0_unscaled: 0.3222 (0.3915)  cardinality_error_0_unscaled: 3832.0000 (3826.0000)  loss_ce_1_unscaled: 0.8618 (0.8990)  loss_bbox_1_unscaled: 0.0115 (0.0189)  loss_giou_1_unscaled: 0.3240 (0.3997)  cardinality_error_1_unscaled: 3832.0000 (3826.7977)  loss_ce_enc_unscaled: 0.8673 (0.9115)  loss_bbox_enc_unscaled: 0.0122 (0.0200)  loss_giou_enc_unscaled: 0.3473 (0.4204)  cardinality_error_enc_unscaled: 3832.0000 (3822.0235)  time: 3.2414  data: 0.0099  max mem: 38593
# Epoch: [0]  [350/759]  eta: 0:22:05  lr: 0.001000  class_error: 34.70  loss: 6.4182 (7.2322)  loss_ce: 0.8647 (0.8963)  loss_bbox: 0.0443 (0.0928)  loss_giou: 0.6250 (0.7963)  loss_ce_0: 0.8989 (0.9396)  loss_bbox_0: 0.0439 (0.0917)  loss_giou_0: 0.6156 (0.7792)  loss_ce_1: 0.8658 (0.9003)  loss_bbox_1: 0.0459 (0.0929)  loss_giou_1: 0.6382 (0.7952)  loss_ce_enc: 0.8711 (0.9122)  loss_bbox_enc: 0.0461 (0.0985)  loss_giou_enc: 0.6946 (0.8373)  loss_ce_unscaled: 0.8647 (0.8963)  class_error_unscaled: 36.1204 (47.5741)  loss_bbox_unscaled: 0.0089 (0.0186)  loss_giou_unscaled: 0.3125 (0.3981)  cardinality_error_unscaled: 3857.0000 (3828.7550)  loss_ce_0_unscaled: 0.8989 (0.9396)  loss_bbox_0_unscaled: 0.0088 (0.0183)  loss_giou_0_unscaled: 0.3078 (0.3896)  cardinality_error_0_unscaled: 3857.0000 (3826.8775)  loss_ce_1_unscaled: 0.8658 (0.9003)  loss_bbox_1_unscaled: 0.0092 (0.0186)  loss_giou_1_unscaled: 0.3191 (0.3976)  cardinality_error_1_unscaled: 3857.0000 (3827.6496)  loss_ce_enc_unscaled: 0.8711 (0.9122)  loss_bbox_enc_unscaled: 0.0092 (0.0197)  loss_giou_enc_unscaled: 0.3473 (0.4186)  cardinality_error_enc_unscaled: 3857.0000 (3823.0142)  time: 3.2325  data: 0.0098  max mem: 38593
# Epoch: [0]  [360/759]  eta: 0:21:33  lr: 0.001000  class_error: 57.58  loss: 6.4501 (7.2160)  loss_ce: 0.8775 (0.8955)  loss_bbox: 0.0481 (0.0920)  loss_giou: 0.6637 (0.7935)  loss_ce_0: 0.9185 (0.9389)  loss_bbox_0: 0.0530 (0.0909)  loss_giou_0: 0.6910 (0.7767)  loss_ce_1: 0.8881 (0.8998)  loss_bbox_1: 0.0490 (0.0922)  loss_giou_1: 0.6726 (0.7925)  loss_ce_enc: 0.9083 (0.9119)  loss_bbox_enc: 0.0571 (0.0976)  loss_giou_enc: 0.7347 (0.8345)  loss_ce_unscaled: 0.8775 (0.8955)  class_error_unscaled: 42.9766 (47.4103)  loss_bbox_unscaled: 0.0096 (0.0184)  loss_giou_unscaled: 0.3318 (0.3968)  cardinality_error_unscaled: 3860.0000 (3829.3186)  loss_ce_0_unscaled: 0.9185 (0.9389)  loss_bbox_0_unscaled: 0.0106 (0.0182)  loss_giou_0_unscaled: 0.3455 (0.3883)  cardinality_error_0_unscaled: 3860.0000 (3827.4792)  loss_ce_1_unscaled: 0.8881 (0.8998)  loss_bbox_1_unscaled: 0.0098 (0.0184)  loss_giou_1_unscaled: 0.3363 (0.3963)  cardinality_error_1_unscaled: 3860.0000 (3828.2410)  loss_ce_enc_unscaled: 0.9083 (0.9119)  loss_bbox_enc_unscaled: 0.0114 (0.0195)  loss_giou_enc_unscaled: 0.3673 (0.4172)  cardinality_error_enc_unscaled: 3860.0000 (3823.7285)  time: 3.2602  data: 0.0103  max mem: 38593
# ...
# Test:  [ 30/124]  eta: 0:00:37  class_error: 17.02  loss: 4.8388 (4.9809)  loss_ce: 0.6641 (0.7114)  loss_bbox: 0.0243 (0.0274)  loss_giou: 0.4951 (0.4982)  loss_ce_0: 0.6680 (0.7175)  loss_bbox_0: 0.0234 (0.0259)  loss_giou_0: 0.4908 (0.5003)  loss_ce_1: 0.6602 (0.7083)  loss_bbox_1: 0.0239 (0.0267)  loss_giou_1: 0.4943 (0.4986)  loss_ce_enc: 0.6719 (0.7138)  loss_bbox_enc: 0.0264 (0.0296)  loss_giou_enc: 0.5151 (0.5232)  loss_ce_unscaled: 0.6641 (0.7114)  class_error_unscaled: 12.3239 (15.6051)  loss_bbox_unscaled: 0.0049 (0.0055)  loss_giou_unscaled: 0.2475 (0.2491)  cardinality_error_unscaled: 199.0000 (198.0645)  loss_ce_0_unscaled: 0.6680 (0.7175)  loss_bbox_0_unscaled: 0.0047 (0.0052)  loss_giou_0_unscaled: 0.2454 (0.2501)  cardinality_error_0_unscaled: 199.0000 (197.9677)  loss_ce_1_unscaled: 0.6602 (0.7083)  loss_bbox_1_unscaled: 0.0048 (0.0053)  loss_giou_1_unscaled: 0.2472 (0.2493)  cardinality_error_1_unscaled: 200.0000 (198.1935)  loss_ce_enc_unscaled: 0.6719 (0.7138)  loss_bbox_enc_unscaled: 0.0053 (0.0059)  loss_giou_enc_unscaled: 0.2576 (0.2616)  cardinality_error_enc_unscaled: 199.0000 (197.3226)  time: 0.3880  data: 0.0251  max mem: 38593
# Test:  [ 40/124]  eta: 0:00:32  class_error: 8.20  loss: 4.8470 (4.9364)  loss_ce: 0.6758 (0.7039)  loss_bbox: 0.0233 (0.0267)  loss_giou: 0.4920 (0.4946)  loss_ce_0: 0.6797 (0.7103)  loss_bbox_0: 0.0222 (0.0256)  loss_giou_0: 0.4958 (0.4962)  loss_ce_1: 0.6719 (0.7006)  loss_bbox_1: 0.0220 (0.0261)  loss_giou_1: 0.4965 (0.4944)  loss_ce_enc: 0.6875 (0.7094)  loss_bbox_enc: 0.0248 (0.0289)  loss_giou_enc: 0.5179 (0.5199)  loss_ce_unscaled: 0.6758 (0.7039)  class_error_unscaled: 13.2353 (14.9546)  loss_bbox_unscaled: 0.0047 (0.0053)  loss_giou_unscaled: 0.2460 (0.2473)  cardinality_error_unscaled: 216.0000 (202.8293)  loss_ce_0_unscaled: 0.6797 (0.7103)  loss_bbox_0_unscaled: 0.0044 (0.0051)  loss_giou_0_unscaled: 0.2479 (0.2481)  cardinality_error_0_unscaled: 215.0000 (202.7561)  loss_ce_1_unscaled: 0.6719 (0.7006)  loss_bbox_1_unscaled: 0.0044 (0.0052)  loss_giou_1_unscaled: 0.2482 (0.2472)  cardinality_error_1_unscaled: 216.0000 (203.0000)  loss_ce_enc_unscaled: 0.6875 (0.7094)  loss_bbox_enc_unscaled: 0.0050 (0.0058)  loss_giou_enc_unscaled: 0.2589 (0.2599)  cardinality_error_enc_unscaled: 215.0000 (202.2195)  time: 0.3698  data: 0.0248  max mem: 38593
# Test:  [ 50/124]  eta: 0:00:26  class_error: 23.91  loss: 4.6355 (4.8513)  loss_ce: 0.6680 (0.6958)  loss_bbox: 0.0204 (0.0254)  loss_giou: 0.4745 (0.4812)  loss_ce_0: 0.6719 (0.7044)  loss_bbox_0: 0.0207 (0.0245)  loss_giou_0: 0.4811 (0.4829)  loss_ce_1: 0.6523 (0.6922)  loss_bbox_1: 0.0202 (0.0250)  loss_giou_1: 0.4775 (0.4807)  loss_ce_enc: 0.6641 (0.7027)  loss_bbox_enc: 0.0244 (0.0281)  loss_giou_enc: 0.5088 (0.5084)  loss_ce_unscaled: 0.6680 (0.6958)  class_error_unscaled: 13.2353 (14.4714)  loss_bbox_unscaled: 0.0041 (0.0051)  loss_giou_unscaled: 0.2372 (0.2406)  cardinality_error_unscaled: 247.0000 (213.8235)  loss_ce_0_unscaled: 0.6719 (0.7044)  loss_bbox_0_unscaled: 0.0041 (0.0049)  loss_giou_0_unscaled: 0.2405 (0.2415)  cardinality_error_0_unscaled: 249.0000 (213.8431)  loss_ce_1_unscaled: 0.6523 (0.6922)  loss_bbox_1_unscaled: 0.0040 (0.0050)  loss_giou_1_unscaled: 0.2387 (0.2403)  cardinality_error_1_unscaled: 250.0000 (214.2745)  loss_ce_enc_unscaled: 0.6641 (0.7027)  loss_bbox_enc_unscaled: 0.0049 (0.0056)  loss_giou_enc_unscaled: 0.2544 (0.2542)  cardinality_error_enc_unscaled: 239.0000 (212.9412)  time: 0.3113  data: 0.0257  max mem: 38593
# Test:  [ 60/124]  eta: 0:00:22  class_error: 14.41  loss: 4.7362 (4.8773)  loss_ce: 0.6758 (0.6970)  loss_bbox: 0.0191 (0.0247)  loss_giou: 0.4660 (0.4858)  loss_ce_0: 0.6953 (0.7066)  loss_bbox_0: 0.0195 (0.0241)  loss_giou_0: 0.4686 (0.4880)  loss_ce_1: 0.6719 (0.6940)  loss_bbox_1: 0.0196 (0.0244)  loss_giou_1: 0.4652 (0.4859)  loss_ce_enc: 0.6914 (0.7049)  loss_bbox_enc: 0.0239 (0.0279)  loss_giou_enc: 0.5086 (0.5141)  loss_ce_unscaled: 0.6758 (0.6970)  class_error_unscaled: 16.6667 (15.2696)  loss_bbox_unscaled: 0.0038 (0.0049)  loss_giou_unscaled: 0.2330 (0.2429)  cardinality_error_unscaled: 252.0000 (215.8689)  loss_ce_0_unscaled: 0.6953 (0.7066)  loss_bbox_0_unscaled: 0.0039 (0.0048)  loss_giou_0_unscaled: 0.2343 (0.2440)  cardinality_error_0_unscaled: 252.0000 (215.8689)  loss_ce_1_unscaled: 0.6719 (0.6940)  loss_bbox_1_unscaled: 0.0039 (0.0049)  loss_giou_1_unscaled: 0.2326 (0.2430)  cardinality_error_1_unscaled: 253.0000 (216.3115)  loss_ce_enc_unscaled: 0.6914 (0.7049)  loss_bbox_enc_unscaled: 0.0048 (0.0056)  loss_giou_enc_unscaled: 0.2543 (0.2570)  cardinality_error_enc_unscaled: 250.0000 (214.9016)  time: 0.3089  data: 0.0271  max mem: 38593
# Test:  [ 70/124]  eta: 0:00:19  class_error: 10.29  loss: 4.7362 (4.8340)  loss_ce: 0.6758 (0.6877)  loss_bbox: 0.0195 (0.0250)  loss_giou: 0.4748 (0.4835)  loss_ce_0: 0.6797 (0.6978)  loss_bbox_0: 0.0195 (0.0244)  loss_giou_0: 0.4765 (0.4860)  loss_ce_1: 0.6719 (0.6853)  loss_bbox_1: 0.0197 (0.0247)  loss_giou_1: 0.4752 (0.4835)  loss_ce_enc: 0.6875 (0.6969)  loss_bbox_enc: 0.0220 (0.0280)  loss_giou_enc: 0.5106 (0.5111)  loss_ce_unscaled: 0.6758 (0.6877)  class_error_unscaled: 15.1515 (14.7501)  loss_bbox_unscaled: 0.0039 (0.0050)  loss_giou_unscaled: 0.2374 (0.2417)  cardinality_error_unscaled: 224.0000 (213.5070)  loss_ce_0_unscaled: 0.6797 (0.6978)  loss_bbox_0_unscaled: 0.0039 (0.0049)  loss_giou_0_unscaled: 0.2382 (0.2430)  cardinality_error_0_unscaled: 224.0000 (213.4930)  loss_ce_1_unscaled: 0.6719 (0.6853)  loss_bbox_1_unscaled: 0.0039 (0.0049)  loss_giou_1_unscaled: 0.2376 (0.2418)  cardinality_error_1_unscaled: 224.0000 (213.9155)  loss_ce_enc_unscaled: 0.6875 (0.6969)  loss_bbox_enc_unscaled: 0.0044 (0.0056)  loss_giou_enc_unscaled: 0.2553 (0.2556)  cardinality_error_enc_unscaled: 223.0000 (212.5775)  time: 0.3520  data: 0.0268  max mem: 38593
# Test:  [ 80/124]  eta: 0:00:15  class_error: 8.21  loss: 4.6366 (4.8357)  loss_ce: 0.6445 (0.6849)  loss_bbox: 0.0210 (0.0249)  loss_giou: 0.4668 (0.4866)  loss_ce_0: 0.6602 (0.6967)  loss_bbox_0: 0.0214 (0.0244)  loss_giou_0: 0.4729 (0.4882)  loss_ce_1: 0.6484 (0.6832)  loss_bbox_1: 0.0210 (0.0247)  loss_giou_1: 0.4671 (0.4867)  loss_ce_enc: 0.6602 (0.6942)  loss_bbox_enc: 0.0232 (0.0278)  loss_giou_enc: 0.4881 (0.5133)  loss_ce_unscaled: 0.6445 (0.6849)  class_error_unscaled: 10.5263 (14.6388)  loss_bbox_unscaled: 0.0042 (0.0050)  loss_giou_unscaled: 0.2334 (0.2433)  cardinality_error_unscaled: 217.0000 (212.6296)  loss_ce_0_unscaled: 0.6602 (0.6967)  loss_bbox_0_unscaled: 0.0043 (0.0049)  loss_giou_0_unscaled: 0.2365 (0.2441)  cardinality_error_0_unscaled: 216.0000 (212.6049)  loss_ce_1_unscaled: 0.6484 (0.6832)  loss_bbox_1_unscaled: 0.0042 (0.0049)  loss_giou_1_unscaled: 0.2335 (0.2434)  cardinality_error_1_unscaled: 217.0000 (212.9753)  loss_ce_enc_unscaled: 0.6602 (0.6942)  loss_bbox_enc_unscaled: 0.0046 (0.0056)  loss_giou_enc_unscaled: 0.2440 (0.2566)  cardinality_error_enc_unscaled: 217.0000 (211.7654)  time: 0.3681  data: 0.0260  max mem: 38593
# Test:  [ 90/124]  eta: 0:00:12  class_error: 21.88  loss: 4.6997 (4.8358)  loss_ce: 0.6797 (0.6890)  loss_bbox: 0.0209 (0.0248)  loss_giou: 0.4568 (0.4826)  loss_ce_0: 0.7109 (0.7003)  loss_bbox_0: 0.0213 (0.0245)  loss_giou_0: 0.4612 (0.4849)  loss_ce_1: 0.6758 (0.6871)  loss_bbox_1: 0.0210 (0.0247)  loss_giou_1: 0.4549 (0.4828)  loss_ce_enc: 0.6875 (0.6965)  loss_bbox_enc: 0.0242 (0.0281)  loss_giou_enc: 0.4757 (0.5103)  loss_ce_unscaled: 0.6797 (0.6890)  class_error_unscaled: 15.5555 (15.0489)  loss_bbox_unscaled: 0.0042 (0.0050)  loss_giou_unscaled: 0.2284 (0.2413)  cardinality_error_unscaled: 232.0000 (216.3846)  loss_ce_0_unscaled: 0.7109 (0.7003)  loss_bbox_0_unscaled: 0.0043 (0.0049)  loss_giou_0_unscaled: 0.2306 (0.2424)  cardinality_error_0_unscaled: 232.0000 (216.3956)  loss_ce_1_unscaled: 0.6758 (0.6871)  loss_bbox_1_unscaled: 0.0042 (0.0049)  loss_giou_1_unscaled: 0.2275 (0.2414)  cardinality_error_1_unscaled: 232.0000 (216.7143)  loss_ce_enc_unscaled: 0.6875 (0.6965)  loss_bbox_enc_unscaled: 0.0048 (0.0056)  loss_giou_enc_unscaled: 0.2378 (0.2552)  cardinality_error_enc_unscaled: 232.0000 (215.4835)  time: 0.3313  data: 0.0257  max mem: 38593
# Test:  [100/124]  eta: 0:00:08  class_error: 24.10  loss: 4.9055 (4.8459)  loss_ce: 0.7188 (0.6912)  loss_bbox: 0.0195 (0.0248)  loss_giou: 0.4772 (0.4828)  loss_ce_0: 0.7109 (0.7026)  loss_bbox_0: 0.0199 (0.0245)  loss_giou_0: 0.4850 (0.4853)  loss_ce_1: 0.7227 (0.6893)  loss_bbox_1: 0.0196 (0.0246)  loss_giou_1: 0.4807 (0.4832)  loss_ce_enc: 0.7070 (0.6993)  loss_bbox_enc: 0.0242 (0.0279)  loss_giou_enc: 0.4995 (0.5104)  loss_ce_unscaled: 0.7188 (0.6912)  class_error_unscaled: 19.2661 (15.3732)  loss_bbox_unscaled: 0.0039 (0.0050)  loss_giou_unscaled: 0.2386 (0.2414)  cardinality_error_unscaled: 242.0000 (217.6634)  loss_ce_0_unscaled: 0.7109 (0.7026)  loss_bbox_0_unscaled: 0.0040 (0.0049)  loss_giou_0_unscaled: 0.2425 (0.2427)  cardinality_error_0_unscaled: 244.0000 (217.6634)  loss_ce_1_unscaled: 0.7227 (0.6893)  loss_bbox_1_unscaled: 0.0039 (0.0049)  loss_giou_1_unscaled: 0.2403 (0.2416)  cardinality_error_1_unscaled: 243.0000 (217.9505)  loss_ce_enc_unscaled: 0.7070 (0.6993)  loss_bbox_enc_unscaled: 0.0048 (0.0056)  loss_giou_enc_unscaled: 0.2498 (0.2552)  cardinality_error_enc_unscaled: 242.0000 (216.7129)  time: 0.3090  data: 0.0254  max mem: 38593
# Test:  [110/124]  eta: 0:00:04  class_error: 14.29  loss: 4.9055 (4.8449)  loss_ce: 0.6914 (0.6908)  loss_bbox: 0.0201 (0.0245)  loss_giou: 0.4880 (0.4830)  loss_ce_0: 0.7266 (0.7041)  loss_bbox_0: 0.0208 (0.0243)  loss_giou_0: 0.4924 (0.4853)  loss_ce_1: 0.6953 (0.6893)  loss_bbox_1: 0.0203 (0.0244)  loss_giou_1: 0.4880 (0.4832)  loss_ce_enc: 0.7344 (0.6991)  loss_bbox_enc: 0.0218 (0.0275)  loss_giou_enc: 0.5011 (0.5092)  loss_ce_unscaled: 0.6914 (0.6908)  class_error_unscaled: 15.8416 (15.3454)  loss_bbox_unscaled: 0.0040 (0.0049)  loss_giou_unscaled: 0.2440 (0.2415)  cardinality_error_unscaled: 228.0000 (216.4054)  loss_ce_0_unscaled: 0.7266 (0.7041)  loss_bbox_0_unscaled: 0.0042 (0.0049)  loss_giou_0_unscaled: 0.2462 (0.2427)  cardinality_error_0_unscaled: 227.0000 (216.4054)  loss_ce_1_unscaled: 0.6953 (0.6893)  loss_bbox_1_unscaled: 0.0041 (0.0049)  loss_giou_1_unscaled: 0.2440 (0.2416)  cardinality_error_1_unscaled: 226.0000 (216.6667)  loss_ce_enc_unscaled: 0.7344 (0.6991)  loss_bbox_enc_unscaled: 0.0044 (0.0055)  loss_giou_enc_unscaled: 0.2505 (0.2546)  cardinality_error_enc_unscaled: 226.0000 (215.4505)  time: 0.3554  data: 0.0253  max mem: 38593
# Test:  [120/124]  eta: 0:00:01  class_error: 21.88  loss: 4.8013 (4.8384)  loss_ce: 0.6641 (0.6892)  loss_bbox: 0.0201 (0.0243)  loss_giou: 0.4768 (0.4830)  loss_ce_0: 0.6836 (0.7023)  loss_bbox_0: 0.0208 (0.0241)  loss_giou_0: 0.4847 (0.4854)  loss_ce_1: 0.6680 (0.6877)  loss_bbox_1: 0.0203 (0.0242)  loss_giou_1: 0.4760 (0.4833)  loss_ce_enc: 0.6914 (0.6983)  loss_bbox_enc: 0.0222 (0.0272)  loss_giou_enc: 0.5011 (0.5096)  loss_ce_unscaled: 0.6641 (0.6892)  class_error_unscaled: 16.1290 (15.4784)  loss_bbox_unscaled: 0.0040 (0.0049)  loss_giou_unscaled: 0.2384 (0.2415)  cardinality_error_unscaled: 223.0000 (216.9256)  loss_ce_0_unscaled: 0.6836 (0.7023)  loss_bbox_0_unscaled: 0.0042 (0.0048)  loss_giou_0_unscaled: 0.2423 (0.2427)  cardinality_error_0_unscaled: 223.0000 (216.9174)  loss_ce_1_unscaled: 0.6680 (0.6877)  loss_bbox_1_unscaled: 0.0041 (0.0048)  loss_giou_1_unscaled: 0.2380 (0.2416)  cardinality_error_1_unscaled: 223.0000 (217.1736)  loss_ce_enc_unscaled: 0.6914 (0.6983)  loss_bbox_enc_unscaled: 0.0044 (0.0054)  loss_giou_enc_unscaled: 0.2505 (0.2548)  cardinality_error_enc_unscaled: 222.0000 (216.0331)  time: 0.3607  data: 0.0255  max mem: 38593
# Test:  [123/124]  eta: 0:00:00  class_error: 23.53  loss: 4.8945 (4.8427)  loss_ce: 0.6875 (0.6909)  loss_bbox: 0.0199 (0.0241)  loss_giou: 0.4768 (0.4826)  loss_ce_0: 0.6914 (0.7038)  loss_bbox_0: 0.0201 (0.0240)  loss_giou_0: 0.4847 (0.4851)  loss_ce_1: 0.6875 (0.6894)  loss_bbox_1: 0.0199 (0.0240)  loss_giou_1: 0.4760 (0.4827)  loss_ce_enc: 0.6953 (0.6998)  loss_bbox_enc: 0.0222 (0.0270)  loss_giou_enc: 0.5011 (0.5093)  loss_ce_unscaled: 0.6875 (0.6909)  class_error_unscaled: 16.6667 (15.6348)  loss_bbox_unscaled: 0.0040 (0.0048)  loss_giou_unscaled: 0.2384 (0.2413)  cardinality_error_unscaled: 232.0000 (217.9113)  loss_ce_0_unscaled: 0.6914 (0.7038)  loss_bbox_0_unscaled: 0.0040 (0.0048)  loss_giou_0_unscaled: 0.2423 (0.2425)  cardinality_error_0_unscaled: 231.0000 (217.9194)  loss_ce_1_unscaled: 0.6875 (0.6894)  loss_bbox_1_unscaled: 0.0040 (0.0048)  loss_giou_1_unscaled: 0.2380 (0.2413)  cardinality_error_1_unscaled: 232.0000 (218.1613)  loss_ce_enc_unscaled: 0.6953 (0.6998)  loss_bbox_enc_unscaled: 0.0044 (0.0054)  loss_giou_enc_unscaled: 0.2505 (0.2546)  cardinality_error_enc_unscaled: 231.0000 (217.0403)  time: 0.3579  data: 0.0254  max mem: 38593
# Test: Total time: 0:00:43 (0.3516 s / it)
# Averaged stats: class_error: 23.53  loss: 4.8945 (4.8427)  loss_ce: 0.6875 (0.6909)  loss_bbox: 0.0199 (0.0241)  loss_giou: 0.4768 (0.4826)  loss_ce_0: 0.6914 (0.7038)  loss_bbox_0: 0.0201 (0.0240)  loss_giou_0: 0.4847 (0.4851)  loss_ce_1: 0.6875 (0.6894)  loss_bbox_1: 0.0199 (0.0240)  loss_giou_1: 0.4760 (0.4827)  loss_ce_enc: 0.6953 (0.6998)  loss_bbox_enc: 0.0222 (0.0270)  loss_giou_enc: 0.5011 (0.5093)  loss_ce_unscaled: 0.6875 (0.6909)  class_error_unscaled: 16.6667 (15.6348)  loss_bbox_unscaled: 0.0040 (0.0048)  loss_giou_unscaled: 0.2384 (0.2413)  cardinality_error_unscaled: 232.0000 (217.9113)  loss_ce_0_unscaled: 0.6914 (0.7038)  loss_bbox_0_unscaled: 0.0040 (0.0048)  loss_giou_0_unscaled: 0.2423 (0.2425)  cardinality_error_0_unscaled: 231.0000 (217.9194)  loss_ce_1_unscaled: 0.6875 (0.6894)  loss_bbox_1_unscaled: 0.0040 (0.0048)  loss_giou_1_unscaled: 0.2380 (0.2413)  cardinality_error_1_unscaled: 232.0000 (218.1613)  loss_ce_enc_unscaled: 0.6953 (0.6998)  loss_bbox_enc_unscaled: 0.0044 (0.0054)  loss_giou_enc_unscaled: 0.2505 (0.2546)  cardinality_error_enc_unscaled: 231.0000 (217.0403)
# Accumulating evaluation results...
# DONE (t=0.39s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.719
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.660
# Training time 21:11:21
# Results saved to output/results.json
# Results saved to output/metrics_plot.png

# %%
from PIL import Image

Image.open("/content/output/metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %% [markdown]
# ## Run inference with fine-tuned model

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(thickness=thickness)
label_annotator = sv.LabelAnnotator(
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    text_thickness=thickness,
    smart_position=True)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
import supervision as sv
from rfdetr import RFDETRBase
from PIL import Image

detections_images = []

for i in range(9):
    path, image, annotations = ds[i]
    image = Image.open(path)

    detections = model.predict(image, threshold=0.5)

    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
    thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

    bbox_annotator = sv.BoxAnnotator(thickness=thickness)
    label_annotator = sv.LabelAnnotator(
        text_color=sv.Color.BLACK,
        text_scale=text_scale,
        text_thickness=thickness,
        smart_position=True)

    detections_labels = [
        f"{ds.classes[class_id]} {confidence:.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    detections_image = image.copy()
    detections_image = bbox_annotator.annotate(detections_image, detections)
    detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

    detections_images.append(detections_image)

sv.plot_images_grid(images=detections_images, grid_size=(3, 3), size=(12, 12))

# %% [markdown]
# ## Evaluate fine-tuned model

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0.5)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 61/61 [00:04<00:00, 13.34it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()

map_result.plot()

# %%
confusion_matrix = sv.ConfusionMatrix.from_detections(
    predictions=predictions,
    targets=targets,
    classes=ds.classes
)

confusion_matrix.plot()
